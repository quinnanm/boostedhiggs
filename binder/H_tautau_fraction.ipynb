# %% [markdown]
# # Make...
# - loads an output pkl file processed by the `trigger_efficiencies_processor.py` June 25th iteration which does not apply the dxy, dz requirements on the Muons but saves them as booleans `muon_dxy`, `muon_dz`
# - checks the effect of the dxy, dz requirements on the trigger efficiency plots

# %%
import glob
import json
import os
import pickle
import pickle as pkl

import hist as hist2
import matplotlib.pyplot as plt
import mplhep as hep
import numpy as np
import pandas as pd
import pyarrow.parquet as pq
import yaml
from hist.intervals import clopper_pearson_interval
from scipy.special import softmax
from sklearn.metrics import auc, roc_curve

import matplotlib.pyplot as plt

import sys
sys.path
sys.path.append("../python/")
import utils
from make_stacked_hists import make_events_dict

pd.options.mode.chained_assignment = None

plt.rcParams.update({"font.size": 20})
plt.style.use(hep.style.CMS)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
 # define your regions here
presel = {
        "mu": {
            "msoftdrop": "fj_mass>40",
        },
        "ele": {
            "msoftdrop": "fj_mass>40",
        },
}

years = ["2017", "2016", "2016APV", "2018"]
channels = ["ele", "mu"]

samples = [
    "ggF", 
    "VBF",  
    "WH",
    "ZH",    
    "ttH",
    "HTauTau",
]

samples_dir = {
    "2016":    "../eos/May31_hww_2016",
    "2016APV": "../eos/May31_hww_2016APV",
    "2017":    "../eos/May31_hww_2017",
    "2018":    "../eos/May31_hww_2018",
}

events_dict = {}
for year in years:
    
    out = make_events_dict([year], channels, samples_dir[year], samples, presel)
    events_dict = {**events_dict, **out}
# Out:
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:Applying msoftdrop selection on 1745 events
# INFO:root:Will fill the VBF dataframe with the remaining 1481 events
# INFO:root:tot event weight 12.413656103948622
#
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Applying msoftdrop selection on 4084 events
# INFO:root:Will fill the WH dataframe with the remaining 3431 events
# INFO:root:tot event weight 2.426111906111235
#
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:Applying msoftdrop selection on 4951 events
# INFO:root:Will fill the ggF dataframe with the remaining 4253 events
# INFO:root:tot event weight 35.44621675087096
#
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Applying msoftdrop selection on 4843 events
# INFO:root:Will fill the WH dataframe with the remaining 4094 events
# INFO:root:tot event weight 4.838212467902326
#
# INFO:root:Finding GluGluHToTauTau samples and should combine them under HTauTau
# INFO:root:Applying msoftdrop selection on 1151 events
# INFO:root:Will fill the HTauTau dataframe with the remaining 1091 events
# INFO:root:tot event weight 9.978288793283655
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Applying msoftdrop selection on 15128 events
# INFO:root:Will fill the ttH dataframe with the remaining 14151 events
# INFO:root:tot event weight 23.15873760310108
#
# INFO:root:Finding GluGluZH_HToWW_M-125_TuneCP5_13TeV-powheg-pythia8 samples and should combine them under ZH
# INFO:root:Applying msoftdrop selection on 11616 events
# INFO:root:Will fill the ZH dataframe with the remaining 10112 events
# INFO:root:tot event weight 0.1298051171240558
#
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:Applying msoftdrop selection on 9507 events
# INFO:root:Will fill the ZH dataframe with the remaining 8309 events
# INFO:root:tot event weight 4.104088668658155
#
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:Applying msoftdrop selection on 2612 events
# INFO:root:Will fill the VBF dataframe with the remaining 2068 events
# INFO:root:tot event weight 17.049373242755692
#
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Applying msoftdrop selection on 5565 events
# INFO:root:Will fill the WH dataframe with the remaining 4576 events
# INFO:root:tot event weight 3.13382333972216
#
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:Applying msoftdrop selection on 7776 events
# INFO:root:Will fill the ggF dataframe with the remaining 6308 events
# INFO:root:tot event weight 50.97429894892902
#
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Applying msoftdrop selection on 6776 events
# INFO:root:Will fill the WH dataframe with the remaining 5515 events
# INFO:root:tot event weight 6.090180074245171
#
# INFO:root:Finding GluGluHToTauTau samples and should combine them under HTauTau
# INFO:root:Applying msoftdrop selection on 309 events
# INFO:root:Will fill the HTauTau dataframe with the remaining 252 events
# INFO:root:tot event weight 2.251483615629309
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Applying msoftdrop selection on 14875 events
# INFO:root:Will fill the ttH dataframe with the remaining 13709 events
# INFO:root:tot event weight 22.182163653910855
#
# INFO:root:Finding GluGluZH_HToWW_M-125_TuneCP5_13TeV-powheg-pythia8 samples and should combine them under ZH
# INFO:root:Applying msoftdrop selection on 13423 events
# INFO:root:Will fill the ZH dataframe with the remaining 10953 events
# INFO:root:tot event weight 0.13896584319893318
#
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:Applying msoftdrop selection on 11783 events
# INFO:root:Will fill the ZH dataframe with the remaining 9789 events
# INFO:root:tot event weight 4.696300729775632
#
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:Applying msoftdrop selection on 822 events
# INFO:root:Will fill the VBF dataframe with the remaining 704 events
# INFO:root:tot event weight 5.3171120885595995
#
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Applying msoftdrop selection on 1077 events
# INFO:root:Will fill the WH dataframe with the remaining 904 events
# INFO:root:tot event weight 0.8884924117879389
#
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:Applying msoftdrop selection on 2111 events
# INFO:root:Will fill the ggF dataframe with the remaining 1764 events
# INFO:root:tot event weight 12.62339506059054
#
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Applying msoftdrop selection on 1374 events
# INFO:root:Will fill the WH dataframe with the remaining 1151 events
# INFO:root:tot event weight 1.694170515972297
#
# INFO:root:Finding GluGluHToTauTau samples and should combine them under HTauTau
# INFO:root:Applying msoftdrop selection on 579 events
# INFO:root:Will fill the HTauTau dataframe with the remaining 557 events
# INFO:root:tot event weight 4.241760329447786
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Applying msoftdrop selection on 6399 events
# INFO:root:Will fill the ttH dataframe with the remaining 6034 events
# INFO:root:tot event weight 8.803766258837113
#
# INFO:root:Finding GluGluZH_HToWW_M-125_TuneCP5_13TeV-powheg-pythia8 samples and should combine them under ZH
# INFO:root:Applying msoftdrop selection on 5015 events
# INFO:root:Will fill the ZH dataframe with the remaining 4348 events
# INFO:root:tot event weight 0.0485042455792409
#
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:Applying msoftdrop selection on 3939 events
# INFO:root:Will fill the ZH dataframe with the remaining 3416 events
# INFO:root:tot event weight 1.4796614801667793
#
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:Applying msoftdrop selection on 1132 events
# INFO:root:Will fill the VBF dataframe with the remaining 909 events
# INFO:root:tot event weight 6.2948722151161975
#
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Applying msoftdrop selection on 1575 events
# INFO:root:Will fill the WH dataframe with the remaining 1294 events
# INFO:root:tot event weight 1.1972386606836602
#
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:Applying msoftdrop selection on 3454 events
# INFO:root:Will fill the ggF dataframe with the remaining 2792 events
# INFO:root:tot event weight 19.478004267735983
#
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Applying msoftdrop selection on 2016 events
# INFO:root:Will fill the WH dataframe with the remaining 1681 events
# INFO:root:tot event weight 2.4609222822667913
#
# INFO:root:Finding GluGluHToTauTau samples and should combine them under HTauTau
# INFO:root:Applying msoftdrop selection on 137 events
# INFO:root:Will fill the HTauTau dataframe with the remaining 115 events
# INFO:root:tot event weight 0.8801687017376383
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Applying msoftdrop selection on 6739 events
# INFO:root:Will fill the ttH dataframe with the remaining 6206 events
# INFO:root:tot event weight 8.671196426596815
#
# INFO:root:Finding GluGluZH_HToWW_M-125_TuneCP5_13TeV-powheg-pythia8 samples and should combine them under ZH
# INFO:root:Applying msoftdrop selection on 5870 events
# INFO:root:Will fill the ZH dataframe with the remaining 4835 events
# INFO:root:tot event weight 0.053285319754695526
#
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:Applying msoftdrop selection on 5228 events
# INFO:root:Will fill the ZH dataframe with the remaining 4314 events
# INFO:root:tot event weight 1.825544041791024
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:Applying msoftdrop selection on 488 events
# INFO:root:Will fill the VBF dataframe with the remaining 414 events
# INFO:root:tot event weight 4.828082732522468
#
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Applying msoftdrop selection on 1463 events
# INFO:root:Will fill the WH dataframe with the remaining 1235 events
# INFO:root:tot event weight 0.9452311438060224
#
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:Applying msoftdrop selection on 2389 events
# INFO:root:Will fill the ggF dataframe with the remaining 2028 events
# INFO:root:tot event weight 13.837643586222953
#
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Applying msoftdrop selection on 1871 events
# INFO:root:Will fill the WH dataframe with the remaining 1560 events
# INFO:root:tot event weight 1.8793883569428007
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Applying msoftdrop selection on 5370 events
# INFO:root:Will fill the ttH dataframe with the remaining 5056 events
# INFO:root:tot event weight 9.471502017044715
#
# INFO:root:Finding GluGluZH_HToWW_M-125_TuneCP5_13TeV-powheg-pythia8 samples and should combine them under ZH
# INFO:root:Applying msoftdrop selection on 5480 events
# INFO:root:Will fill the ZH dataframe with the remaining 4734 events
# INFO:root:tot event weight 0.050458870829838284
#
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:Applying msoftdrop selection on 4220 events
# INFO:root:Will fill the ZH dataframe with the remaining 3604 events
# INFO:root:tot event weight 1.5921769770528713
#
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:Applying msoftdrop selection on 860 events
# INFO:root:Will fill the VBF dataframe with the remaining 680 events
# INFO:root:tot event weight 7.791157543525696
#
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Applying msoftdrop selection on 2079 events
# INFO:root:Will fill the WH dataframe with the remaining 1726 events
# INFO:root:tot event weight 1.2996983234188244
#
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:Applying msoftdrop selection on 3790 events
# INFO:root:Will fill the ggF dataframe with the remaining 3046 events
# INFO:root:tot event weight 20.518957340883023
#
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Applying msoftdrop selection on 2638 events
# INFO:root:Will fill the WH dataframe with the remaining 2175 events
# INFO:root:tot event weight 2.6002785130495103
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Applying msoftdrop selection on 5830 events
# INFO:root:Will fill the ttH dataframe with the remaining 5375 events
# INFO:root:tot event weight 9.944585636970444
#
# INFO:root:Finding GluGluZH_HToWW_M-125_TuneCP5_13TeV-powheg-pythia8 samples and should combine them under ZH
# INFO:root:Applying msoftdrop selection on 6612 events
# INFO:root:Will fill the ZH dataframe with the remaining 5371 events
# INFO:root:tot event weight 0.057044951831209556
#
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:Applying msoftdrop selection on 5636 events
# INFO:root:Will fill the ZH dataframe with the remaining 4671 events
# INFO:root:tot event weight 2.0459683108044944
#
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:Applying msoftdrop selection on 1601 events
# INFO:root:Will fill the VBF dataframe with the remaining 1364 events
# INFO:root:tot event weight 17.924812693248576
#
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Applying msoftdrop selection on 5590 events
# INFO:root:Will fill the WH dataframe with the remaining 4769 events
# INFO:root:tot event weight 3.3439508866952448
#
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:Applying msoftdrop selection on 4742 events
# INFO:root:Will fill the ggF dataframe with the remaining 4004 events
# INFO:root:tot event weight 46.76382328526258
#
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Applying msoftdrop selection on 6220 events
# INFO:root:Will fill the WH dataframe with the remaining 5241 events
# INFO:root:tot event weight 6.3143918232949545
#
# INFO:root:Finding GluGluHToTauTau samples and should combine them under HTauTau
# INFO:root:Applying msoftdrop selection on 1107 events
# INFO:root:Will fill the HTauTau dataframe with the remaining 1044 events
# INFO:root:tot event weight 14.16395489060117
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Applying msoftdrop selection on 5879 events
# INFO:root:Will fill the ttH dataframe with the remaining 5554 events
# INFO:root:tot event weight 32.42076702907596
#
# INFO:root:Finding GluGluZH_HToWW_M-125_TuneCP5_13TeV-powheg-pythia8 samples and should combine them under ZH
# INFO:root:Applying msoftdrop selection on 15502 events
# INFO:root:Will fill the ZH dataframe with the remaining 13436 events
# INFO:root:tot event weight 0.17332476727595594
#
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:Applying msoftdrop selection on 9318 events
# INFO:root:Will fill the ZH dataframe with the remaining 8124 events
# INFO:root:tot event weight 5.524622451156723
#
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:Applying msoftdrop selection on 2473 events
# INFO:root:Will fill the VBF dataframe with the remaining 1980 events
# INFO:root:tot event weight 26.329083589768413
#
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Applying msoftdrop selection on 7423 events
# INFO:root:Will fill the WH dataframe with the remaining 6084 events
# INFO:root:tot event weight 4.340237908111636
#
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:Applying msoftdrop selection on 7341 events
# INFO:root:Will fill the ggF dataframe with the remaining 5898 events
# INFO:root:tot event weight 69.8493155758009
#
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Applying msoftdrop selection on 8428 events
# INFO:root:Will fill the WH dataframe with the remaining 6901 events
# INFO:root:tot event weight 8.432262434824409
#
# INFO:root:Finding GluGluHToTauTau samples and should combine them under HTauTau
# INFO:root:Applying msoftdrop selection on 251 events
# INFO:root:Will fill the HTauTau dataframe with the remaining 194 events
# INFO:root:tot event weight 2.715167815413473
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Applying msoftdrop selection on 5721 events
# INFO:root:Will fill the ttH dataframe with the remaining 5271 events
# INFO:root:tot event weight 30.576877463780445
#
# INFO:root:Finding GluGluZH_HToWW_M-125_TuneCP5_13TeV-powheg-pythia8 samples and should combine them under ZH
# INFO:root:Applying msoftdrop selection on 17325 events
# INFO:root:Will fill the ZH dataframe with the remaining 14034 events
# INFO:root:tot event weight 0.1831908597040599
#
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:Applying msoftdrop selection on 11737 events
# INFO:root:Will fill the ZH dataframe with the remaining 9702 events
# INFO:root:tot event weight 6.6752094053633035

# %%
events_dict["2016APV"]['ele'].keys()
# Out:
# dict_keys(['VBF', 'WH', 'ggF', 'ttH', 'ZH'])

# %%
def make_composition_table_sig(ev, presel):

    from collections import OrderedDict

    all_MCsamples = [
        "ggF", 
        "VBF",
        "ttH",
        "WH",
        "ZH", 
        "HTauTau"
    ]

    sig = ["VBF", "ggF"]         
    bkg = ["ttH", "WH", "ZH", "HTauTau"]

    mass_window = [50, 150]
    
    # make table
    print("\\begin{table}[!ht]")
    print("\\begin{center}")
    
    print("\\caption{Event yield contribution from different Higgs processes at pre-selection level and in the signal-like region, defined by a high tagger score, for the full Run2 dataset. The contribution of H(tau-tau) decays is negligible in both regions.}")
            
    print("\\begin{tabular}{c|ccccc|c}")

    print("& \\multicolumn{5}{c|}{Higgs Signal yields} & \\multicolumn{1}{c}{Higgs Background yields} \\\\\n")
    print("& VBF & ggF & \\ttH & WH & ZH & HTauTau \\\\\n")        
    print("\\hline")
    print("\\hline")

    for region, sel in presel.items():

        sig_dict = OrderedDict({
            "VBF": 0,
            "ggF": 0,     
            "ttH": 0,
            "WH": 0, 
            "ZH": 0,            
        })

        bkg_dict = OrderedDict({

            "HTauTau": 0,
        })

        tot_sig, tot_bkg = 0, 0
        s, b = 0, 0   # in mass window [100, 150]
        for year in years:
            for ch in channels:
                for sample in all_MCsamples:

                    try:
                        df = ev[year][ch][sample]
                    except:
                        continue

                    df = df.query(sel)  

                    if sample in sig_dict:
                        tot_sig += df["event_weight"].sum()                    
                        sig_dict[sample] += df["event_weight"].sum()
                    elif sample in bkg_dict:
                        tot_bkg += df["event_weight"].sum()
                        bkg_dict[sample] += df["event_weight"].sum()
                    else:
                        tot_bkg += df["event_weight"].sum()                        
                        bkg_dict["Others"] += df["event_weight"].sum()                    

                    ######################## soverb start
                    df = df[(df["rec_higgs_m"]>=mass_window[0]) & (df["rec_higgs_m"]<=mass_window[1])]

                    if sample in sig_dict:                
                        s += df["event_weight"].sum()
                    else:
                        b += df["event_weight"].sum()
                    ######################## soverb end


        texdata = region
        for sample in sig_dict:
            texdata += f" & {(sig_dict[sample]):.0f}"
        for sample in bkg_dict:
            texdata += f" & {(bkg_dict[sample]):.0f}"
        
        texdata += " \\\\\n"
        print(texdata)
        print("\\hline")

    print("\\hline")
    print("\\end{tabular}")
    print("\\label{tab:sigproductionmodes}")
    print("\\end{center}")
    print("\\end{table}")

# %%
presel = {
    "Pre-selection": f"THWW>0.5", # dummy
    r"$T_{HWW}> 0.9$": f"THWW>0.9",
}

make_composition_table_sig(events_dict, presel)
# Out:
# \begin{table}[!ht]
# \begin{center}
# \caption{Event yield contribution from different Higgs processes at pre-selection level and in the signal-like region, defined by a high tagger score, for the full Run2 dataset. The contribution of H(tau-tau) decays is negligible in both regions.}
# \begin{tabular}{c|ccccc|c}
# & \multicolumn{5}{c|}{Higgs Signal yields} & \multicolumn{1}{c}{Higgs Background yields} \\
#
# & VBF & ggF & \ttH & WH & ZH & HTauTau \\
#
# \hline
# \hline
# Pre-selection & 56 & 154 & 30 & 27 & 15 & 0 \\
#
# \hline
# $T_{HWW}> 0.9$ & 22 & 54 & 6 & 9 & 5 & 0 \\
#
# \hline
# \hline
# \end{tabular}
# \label{tab:sigproductionmodes}
# \end{center}
# \end{table}
