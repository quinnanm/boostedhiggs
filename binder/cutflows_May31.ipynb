# %% [markdown]
# # Compute the LateX cutflow tables
# - Will load the pkl files that contain the cutflows and the sumgenweight
# - Will scale the events by the cross section
# - Will save the yields in a dictionnary called ```cutflows -> Dict()```
# - Will make the LateX table using the function ```make_composition_table()```

# %%
import glob
import json
import os
import pickle as pkl
import sys

import hist as hist2
import matplotlib.pyplot as plt
import mplhep as hep
import numpy as np
import pandas as pd
import pyarrow
import pyarrow.parquet as pq
import yaml
from scipy.special import softmax
from sklearn.metrics import auc, roc_curve

sys.path
sys.path.append("../python/")

import utils

plt.style.use(hep.style.CMS)
plt.rcParams.update({"font.size": 20})

pd.options.mode.chained_assignment = None

import glob
import os
import json
import pickle
import yaml
import math

import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None
import pyarrow.parquet as pq
from sklearn.metrics import auc, roc_curve
from scipy.special import softmax

import hist as hist2
import matplotlib.pyplot as plt
import mplhep as hep

plt.style.use(hep.style.CMS)

import sys
sys.path
sys.path.append("../python/")

import utils

plt.rcParams.update({"font.size": 20})

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# get lumi
with open("../fileset/luminosity.json") as f:
    luminosity = json.load(f)
    
luminosity
# Out:
# {'ele': {'Run2': 137640.0,
#   '2016APV': 19492.72,
#   '2016': 16809.96,
#   '2017': 41476.02,
#   '2018': 59816.23},
#  'mu': {'Run2': 137640.0,
#   '2016APV': 19436.16,
#   '2016': 16810.81,
#   '2017': 41475.26,
#   '2018': 59781.96},
#  'lep': {'Run2': 137640.0,
#   '2016APV': 19436.16,
#   '2016': 16810.81,
#   '2017': 41475.26,
#   '2018': 59781.96},
#  'had': {'Run2': 137640.0,
#   '2016APV': 19436.16,
#   '2016': 16810.81,
#   '2017': 41475.26,
#   '2018': 59781.96}}

# %%
def get_lumi(years, channels):
    lum_ = 0
    for year in years:
        lum = 0
        for ch in channels:
            lum += luminosity[ch][year] / 1000.0

        lum_ += lum / len(channels)    
    return lum_

# %% [markdown]
# # Read cutflows from pkl

# %%
def get_sum_sumgenweight(pkl_files, year, sample):
    """Load and sum the sumgenweight of each pkl file."""
    
    sum_sumgenweight = 0
    for ifile in pkl_files:
        with open(ifile, "rb") as f:
            metadata = pkl.load(f)            
        sum_sumgenweight = sum_sumgenweight + metadata[sample][year]["sumgenweight"]

    return sum_sumgenweight


def get_xsecweight(pkl_files, year, ch, sample, is_data):
    
    if not is_data:
        # find xsection
        f = open("../fileset/xsec_pfnano.json")
        xsec = json.load(f)
        f.close()
        try:
            xsec = eval(str((xsec[sample])))
        except ValueError:
            print(f"sample {sample} doesn't have xsecs defined in xsec_pfnano.json so will skip it")
            return None

        # get overall weighting of events.. each event has a genweight...
        # sumgenweight sums over events in a chunk... sum_sumgenweight sums over chunks
        xsec_weight = (xsec * luminosity[ch][year]) / get_sum_sumgenweight(pkl_files, year, sample)
    else:
        xsec_weight = 1
    return xsec_weight

def get_cutflow(pkl_files, year, ch, sample, is_data):
    """
    Get cutflow from metadata but multiply by xsec-weight
    """
    xsec_weight = get_xsecweight(pkl_files, year, ch, sample, is_data)
        
    cuts = [
        "sumgenweight",
        "Trigger",
        "METFilters",
        "OneLep",
        "NoTaus",
        "AtLeastOneFatJet",
        "CandidateJetpT",
        "LepInJet",
        "JetLepOverlap",
        "dPhiJetMET",
        "MET",
    ]
        
    if year == "2018":
        cuts += ["HEMCleaning"]
        
    evyield = dict.fromkeys(cuts, 0)
    for ik, pkl_file in enumerate(pkl_files):
        with open(pkl_file, "rb") as f:
            metadata = pkl.load(f)
            
        cutflows = metadata[sample][year]["cutflows"][ch]

        for key in evyield.keys():

            if key == "sumgenweight":
                evyield[key] += metadata[sample][year][key] * xsec_weight
            else:
                evyield[key] += cutflows[key] * xsec_weight        
    return evyield

# %%
! ls ../eos/May31_hww_2018/WJetsToLNu_HT-100To200/outfiles/0-10.pkl
# Out:
# ../eos/May31_hww_2018/WJetsToLNu_HT-100To200/outfiles/0-10.pkl

# %%
with open("../eos/May31_hww_2018/WJetsToLNu_HT-100To200/outfiles/0-10.pkl", "rb") as f:
    metadata = pkl.load(f)
metadata
# Out:
# {'WJetsToLNu_HT-100To200': {'mc': 89,
#   '2018': {'sumgenweight': 860209.0,
#    'sumlheweight': {0: 893759.06,
#     1: 894174.7,
#     2: 888283.2,
#     3: 859625.5,
#     4: 860209.0,
#     5: 854675.94,
#     6: 831615.4,
#     7: 832338.2,
#     8: 827100.1},
#    'sumpdfweight': {},
#    'cutflows': {'ele': {'Trigger': 112333.0,
#      'METFilters': 112304.0,
#      'OneLep': 86555.0,
#      'NoTaus': 86555.0,
#      'AtLeastOneFatJet': 1048.0,
#      'CandidateJetpT': 43.0,
#      'LepInJet': 27.0,
#      'JetLepOverlap': 8.0,
#      'dPhiJetMET': 1.0,
#      'MET': 1.0,
#      'HEMCleaning': 1.0},
#     'mu': {'Trigger': 133416.0,
#      'METFilters': 133390.0,
#      'OneLep': 133079.0,
#      'NoTaus': 112979.0,
#      'AtLeastOneFatJet': 1338.0,
#      'CandidateJetpT': 75.0,
#      'LepInJet': 51.0,
#      'JetLepOverlap': 11.0,
#      'dPhiJetMET': 1.0,
#      'MET': 1.0,
#      'HEMCleaning': 1.0}}}}}

# %% [markdown]
# # Adding a cut from the parquets

# %%
### This is your configuration. specefy which channels, years, samples, and directory of pkl files to use.
channels = ["ele", "mu"]
years = ["2018", "2017", "2016", "2016APV"]

samples = [
    "ggF", 
    "WH",
    "ZH",
    "VBF",
    "ttH",
    "DYJets",
    "WJetsLNu",
    "WZQQ",
    "TTbar",
    "SingleTop",
    "Diboson",
    "Data"
]

samples_dir = {
    "2016":    "../eos/May31_hww_2016",
    "2016APV": "../eos/May31_hww_2016APV",    
    "2017":    "../eos/May31_hww_2017",    
    "2018":    "../eos/May31_hww_2018",    
}

# %%
cutflows = {}
for year in years:
#     if year != "2016":
#         continue
    print(f"Processing year {year}")
    
    cutflows[year] = {}
    
    for ch in channels:
#         if ch != "mu": 
#             continue
        
        print(f"  {ch} channel")
        cutflows[year][ch] = {}

        condor_dir = os.listdir(samples_dir[year])

        for sample in condor_dir:

            # first: check if the sample is in one of combine_samples_by_name
            sample_to_use = None
            for key in utils.combine_samples_by_name:
                if key in sample:
                    sample_to_use = utils.combine_samples_by_name[key]
                    break

            # second: if not, combine under common label
            if sample_to_use is None:
                for key in utils.combine_samples:
                    if key in sample:
                        sample_to_use = utils.combine_samples[key]
                        break
                    else:
                        sample_to_use = sample

            if sample_to_use not in samples:
                continue

            is_data = False
            if sample_to_use == "Data":
                is_data = True

            out_files = f"{samples_dir[year]}/{sample}/outfiles/"
            pkl_files = glob.glob(f"{out_files}/*.pkl")

            if len(pkl_files) == 0:
                continue

            parquet_files = glob.glob(f"{out_files}/*_{ch}.parquet")
            
            try:
                data = pd.read_parquet(parquet_files)
            except pyarrow.lib.ArrowInvalid:
                # empty parquet because no event passed selection
#                 print(f"No parquet file for {sample}")
                continue

            if len(data) == 0:
#                 print(f"Hi, No parquet file for {sample}")
                continue
    
            if sample_to_use not in cutflows[year][ch].keys():
                cutflows[year][ch][sample_to_use] = get_cutflow(pkl_files, year, ch, sample, is_data)
            else:
                temp = get_cutflow(pkl_files, year, ch, sample, is_data)
                for key in cutflows[year][ch][sample_to_use]:
                    cutflows[year][ch][sample_to_use][key] += temp[key]
            
    print(f"------------------------------------------")
# Out:
# Processing year 2018
#   ele channel
#   mu channel
# ------------------------------------------
# Processing year 2017
#   ele channel
#   mu channel
# ------------------------------------------
# Processing year 2016
#   ele channel
#   mu channel
# ------------------------------------------
# Processing year 2016APV
#   ele channel
#   mu channel
# ------------------------------------------

# %%
samples = cutflows["2017"]["ele"].keys()  # samples
samples
# Out:
# dict_keys(['VBF', 'WJetsLNu', 'WH', 'TTbar', 'SingleTop', 'ggF', 'Data', 'Diboson', 'ttH', 'ZH'])

# %%
from make_stacked_hists import make_events_dict

presel = {
        "mu": {
            "THWW>0.50": "THWW>0.50",
        },
        "ele": {
            "THWW>0.50": "THWW>0.50",
        },
}

events_dict = {}
for year in years:
    
    out = make_events_dict([year], channels, samples_dir[year], samples, presel)
    events_dict = {**events_dict, **out}
# Out:
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 1601 events
# INFO:root:Will fill the VBF dataframe with the remaining 774 events
# INFO:root:tot event weight 10.139928859599209
#
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 57 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 3 events
# INFO:root:tot event weight 6.352390849732743
#
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 5590 events
# INFO:root:Will fill the WH dataframe with the remaining 2444 events
# INFO:root:tot event weight 1.700025567778488
#
# INFO:root:Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 161246 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 11766 events
# INFO:root:tot event weight 651.4456017989145
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 356607 events
# INFO:root:Will fill the TTbar dataframe with the remaining 10334 events
# INFO:root:tot event weight 1703.4149238815698
#
# INFO:root:Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 31662 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 471 events
# INFO:root:tot event weight 14.187500436981907
#
# INFO:root:Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# INFO:root:Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 191897 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 8746 events
# INFO:root:tot event weight 123.26919869575448
#
# INFO:root:Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 20284 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 774 events
# INFO:root:tot event weight 387.3207688077881
#
# INFO:root:Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 5477 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 267 events
# INFO:root:tot event weight 62.77363442028947
#
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 4742 events
# INFO:root:Will fill the ggF dataframe with the remaining 2314 events
# INFO:root:tot event weight 26.975773738870302
#
# INFO:root:Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 5308 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 240 events
# INFO:root:tot event weight 57.9177673038184
#
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 6220 events
# INFO:root:Will fill the WH dataframe with the remaining 2764 events
# INFO:root:tot event weight 3.298052165923587
#
# INFO:root:Finding EGamma_Run2018A samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 32586 events
# INFO:root:Will fill the Data dataframe with the remaining 1596 events
# INFO:root:tot event weight 1596.0
#
# INFO:root:Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 17488 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 275 events
# INFO:root:tot event weight 0.867923983636822
#
# INFO:root:Finding SingleMuon_Run2018A samples and should combine them under Data
# INFO:root:Finding WW samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 595 events
# INFO:root:Will fill the Diboson dataframe with the remaining 70 events
# INFO:root:tot event weight 74.16132808198391
#
# INFO:root:Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 12290 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 205 events
# INFO:root:tot event weight 6.884113070594644
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 128508 events
# INFO:root:Will fill the TTbar dataframe with the remaining 2727 events
# INFO:root:tot event weight 136.35596328029897
#
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 312 events
# INFO:root:Will fill the Diboson dataframe with the remaining 7 events
# INFO:root:tot event weight 1.8684873540628213
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 652 events
# INFO:root:Will fill the TTbar dataframe with the remaining 31 events
# INFO:root:tot event weight 7.0131268618995355
#
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 107384 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 9162 events
# INFO:root:tot event weight 1193.0093480728221
#
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 62439 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 920 events
# INFO:root:tot event weight 0.322817567787117
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 5879 events
# INFO:root:Will fill the ttH dataframe with the remaining 1087 events
# INFO:root:tot event weight 6.465917724495714
#
# INFO:root:Finding EGamma_Run2018C samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 15261 events
# INFO:root:Will fill the Data dataframe with the remaining 807 events
# INFO:root:tot event weight 807.0
#
# INFO:root:Finding EGamma_Run2018D samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 69925 events
# INFO:root:Will fill the Data dataframe with the remaining 3589 events
# INFO:root:tot event weight 3589.0
#
# INFO:root:Finding EGamma_Run2018B samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 16456 events
# INFO:root:Will fill the Data dataframe with the remaining 828 events
# INFO:root:tot event weight 828.0
#
# INFO:root:Finding GluGluZH_HToWW_M-125_TuneCP5_13TeV-powheg-pythia8 samples and should combine them under ZH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 15502 events
# INFO:root:Will fill the ZH dataframe with the remaining 6446 events
# INFO:root:tot event weight 0.0828785674003949
#
# INFO:root:Finding SingleMuon_Run2018C samples and should combine them under Data
# INFO:root:Finding SingleMuon_Run2018D samples and should combine them under Data
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 46191 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 3720 events
# INFO:root:tot event weight 1858.5412726705074
#
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 9318 events
# INFO:root:Will fill the ZH dataframe with the remaining 3847 events
# INFO:root:tot event weight 2.5978015630275664
#
# INFO:root:Finding WZ samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 704 events
# INFO:root:Will fill the Diboson dataframe with the remaining 37 events
# INFO:root:tot event weight 12.690625015672772
#
# INFO:root:Finding SingleMuon_Run2018B samples and should combine them under Data
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 2473 events
# INFO:root:Will fill the VBF dataframe with the remaining 1260 events
# INFO:root:tot event weight 16.700830177191825
#
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 74 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 2 events
# INFO:root:tot event weight 4.277669431090988
#
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 7423 events
# INFO:root:Will fill the WH dataframe with the remaining 3720 events
# INFO:root:tot event weight 2.623894072442228
#
# INFO:root:Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 222471 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 19614 events
# INFO:root:tot event weight 1117.6965881069304
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 402523 events
# INFO:root:Will fill the TTbar dataframe with the remaining 12091 events
# INFO:root:tot event weight 2026.470543986699
#
# INFO:root:Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 49731 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 681 events
# INFO:root:tot event weight 21.66149266134449
#
# INFO:root:Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 311 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 7 events
# INFO:root:tot event weight 0.062064636315671426
#
# INFO:root:Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 272793 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 18958 events
# INFO:root:tot event weight 275.51422793405186
#
# INFO:root:Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 23295 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 1105 events
# INFO:root:tot event weight 561.8888933703042
#
# INFO:root:Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 6077 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 324 events
# INFO:root:tot event weight 78.12549636126042
#
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 7341 events
# INFO:root:Will fill the ggF dataframe with the remaining 3878 events
# INFO:root:tot event weight 45.85320951308111
#
# INFO:root:Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 5845 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 289 events
# INFO:root:tot event weight 71.29447639052768
#
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 8428 events
# INFO:root:Will fill the WH dataframe with the remaining 4262 events
# INFO:root:tot event weight 5.182755593059926
#
# INFO:root:Finding EGamma_Run2018A samples and should combine them under Data
# INFO:root:Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 25488 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 433 events
# INFO:root:tot event weight 1.4747400844097793
#
# INFO:root:Finding SingleMuon_Run2018A samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 40106 events
# INFO:root:Will fill the Data dataframe with the remaining 2184 events
# INFO:root:tot event weight 2184.0
#
# INFO:root:Finding WW samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 624 events
# INFO:root:Will fill the Diboson dataframe with the remaining 120 events
# INFO:root:tot event weight 126.99988486033425
#
# INFO:root:Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 19319 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 303 events
# INFO:root:tot event weight 10.683486404998279
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 109129 events
# INFO:root:Will fill the TTbar dataframe with the remaining 2304 events
# INFO:root:tot event weight 117.36269149448287
#
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 160 events
# INFO:root:Will fill the Diboson dataframe with the remaining 17 events
# INFO:root:tot event weight 4.471602692151726
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 3327 events
# INFO:root:Will fill the TTbar dataframe with the remaining 85 events
# INFO:root:tot event weight 18.469823251454986
#
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 145429 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 13661 events
# INFO:root:tot event weight 1824.0314651562364
#
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 89378 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 3277 events
# INFO:root:tot event weight 1.153728772665809
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 5721 events
# INFO:root:Will fill the ttH dataframe with the remaining 1185 events
# INFO:root:tot event weight 6.99929923393184
#
# INFO:root:Finding EGamma_Run2018C samples and should combine them under Data
# INFO:root:Finding EGamma_Run2018D samples and should combine them under Data
# INFO:root:Finding EGamma_Run2018B samples and should combine them under Data
# INFO:root:Finding GluGluZH_HToWW_M-125_TuneCP5_13TeV-powheg-pythia8 samples and should combine them under ZH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 17325 events
# INFO:root:Will fill the ZH dataframe with the remaining 8737 events
# INFO:root:tot event weight 0.11378015752722213
#
# INFO:root:Finding SingleMuon_Run2018C samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 18506 events
# INFO:root:Will fill the Data dataframe with the remaining 1020 events
# INFO:root:tot event weight 1020.0
#
# INFO:root:Finding SingleMuon_Run2018D samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 85292 events
# INFO:root:Will fill the Data dataframe with the remaining 4689 events
# INFO:root:tot event weight 4689.0
#
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 59086 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 5215 events
# INFO:root:tot event weight 2654.8595722581904
#
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 11737 events
# INFO:root:Will fill the ZH dataframe with the remaining 6049 events
# INFO:root:tot event weight 4.154608815691804
#
# INFO:root:Finding WZ samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 468 events
# INFO:root:Will fill the Diboson dataframe with the remaining 48 events
# INFO:root:tot event weight 16.628013789539132
#
# INFO:root:Finding SingleMuon_Run2018B samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 20087 events
# INFO:root:Will fill the Data dataframe with the remaining 1087 events
# INFO:root:tot event weight 1087.0
#
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 1745 events
# INFO:root:Will fill the VBF dataframe with the remaining 854 events
# INFO:root:tot event weight 7.6048678973173125
#
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 87 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 1 events
# INFO:root:tot event weight 1.6639318904239442
#
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 4084 events
# INFO:root:Will fill the WH dataframe with the remaining 1776 events
# INFO:root:tot event weight 1.2128922447289874
#
# INFO:root:Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 112821 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 8414 events
# INFO:root:tot event weight 473.69779394005246
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 359402 events
# INFO:root:Will fill the TTbar dataframe with the remaining 10396 events
# INFO:root:tot event weight 1273.4029151867103
#
# INFO:root:Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 23731 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 353 events
# INFO:root:tot event weight 9.949845060912882
#
# INFO:root:Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 35 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 4 events
# INFO:root:tot event weight 0.05273153687580405
#
# INFO:root:Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 122307 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 5771 events
# INFO:root:tot event weight 89.16661285408131
#
# INFO:root:Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 18679 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 793 events
# INFO:root:tot event weight 331.4822822696332
#
# INFO:root:Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 4097 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 198 events
# INFO:root:tot event weight 48.82243088748564
#
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 4951 events
# INFO:root:Will fill the ggF dataframe with the remaining 2447 events
# INFO:root:tot event weight 19.724354039969896
#
# INFO:root:Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 4086 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 187 events
# INFO:root:tot event weight 42.29619521574885
#
# INFO:root:Finding SingleElectron_Run2017E samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 22746 events
# INFO:root:Will fill the Data dataframe with the remaining 1179 events
# INFO:root:tot event weight 1179.0
#
# INFO:root:Finding SingleElectron_Run2017B samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 9060 events
# INFO:root:Will fill the Data dataframe with the remaining 412 events
# INFO:root:tot event weight 412.0
#
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 4843 events
# INFO:root:Will fill the WH dataframe with the remaining 2096 events
# INFO:root:tot event weight 2.481431735520488
#
# INFO:root:Finding SingleElectron_Run2017C samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 24152 events
# INFO:root:Will fill the Data dataframe with the remaining 1260 events
# INFO:root:tot event weight 1260.0
#
# INFO:root:Finding SingleElectron_Run2017D samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 10914 events
# INFO:root:Will fill the Data dataframe with the remaining 559 events
# INFO:root:tot event weight 559.0
#
# INFO:root:Finding SingleMuon_Run2017C samples and should combine them under Data
# INFO:root:Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 12856 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 219 events
# INFO:root:tot event weight 1.5294663390389132
#
# INFO:root:Finding SingleMuon_Run2017D samples and should combine them under Data
# INFO:root:Finding SingleMuon_Run2017E samples and should combine them under Data
# INFO:root:Finding SingleMuon_Run2017B samples and should combine them under Data
# INFO:root:Finding WW samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 914 events
# INFO:root:Will fill the Diboson dataframe with the remaining 119 events
# INFO:root:tot event weight 56.01981476328125
#
# INFO:root:Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 9636 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 149 events
# INFO:root:tot event weight 4.596566146139161
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 137227 events
# INFO:root:Will fill the TTbar dataframe with the remaining 2822 events
# INFO:root:tot event weight 97.38897248323246
#
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 272 events
# INFO:root:Will fill the Diboson dataframe with the remaining 9 events
# INFO:root:tot event weight 2.2206353133864756
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 662 events
# INFO:root:Will fill the TTbar dataframe with the remaining 41 events
# INFO:root:tot event weight 6.2015633430221415
#
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 83350 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 7121 events
# INFO:root:tot event weight 884.4532386531785
#
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 41130 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 571 events
# INFO:root:tot event weight 0.20525863711983783
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 15128 events
# INFO:root:Will fill the ttH dataframe with the remaining 2690 events
# INFO:root:tot event weight 4.407267979173592
#
# INFO:root:Finding SingleElectron_Run2017F samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 31932 events
# INFO:root:Will fill the Data dataframe with the remaining 1639 events
# INFO:root:tot event weight 1639.0
#
# INFO:root:Finding GluGluZH_HToWW_M-125_TuneCP5_13TeV-powheg-pythia8 samples and should combine them under ZH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 11616 events
# INFO:root:Will fill the ZH dataframe with the remaining 4758 events
# INFO:root:tot event weight 0.059320303587447935
#
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 33953 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 2708 events
# INFO:root:tot event weight 1348.8783830753957
#
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 9507 events
# INFO:root:Will fill the ZH dataframe with the remaining 3900 events
# INFO:root:tot event weight 1.99119224263809
#
# INFO:root:Finding WZ samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 608 events
# INFO:root:Will fill the Diboson dataframe with the remaining 33 events
# INFO:root:tot event weight 9.692000419532416
#
# INFO:root:Finding SingleMuon_Run2017F samples and should combine them under Data
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 2612 events
# INFO:root:Will fill the VBF dataframe with the remaining 1371 events
# INFO:root:tot event weight 11.47192265048626
#
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 107 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 3 events
# INFO:root:tot event weight 4.872620141481636
#
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 5565 events
# INFO:root:Will fill the WH dataframe with the remaining 2727 events
# INFO:root:tot event weight 1.8656891445755954
#
# INFO:root:Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 158739 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 13751 events
# INFO:root:tot event weight 776.2600367463306
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 412828 events
# INFO:root:Will fill the TTbar dataframe with the remaining 12076 events
# INFO:root:tot event weight 1406.0182186643206
#
# INFO:root:Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 38837 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 497 events
# INFO:root:tot event weight 13.876816513865144
#
# INFO:root:Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 267 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 7 events
# INFO:root:tot event weight 0.03581960028177826
#
# INFO:root:Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 176509 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 11941 events
# INFO:root:tot event weight 185.52359195723818
#
# INFO:root:Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 21569 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 1040 events
# INFO:root:tot event weight 449.65724240516033
#
# INFO:root:Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 4545 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 228 events
# INFO:root:tot event weight 50.68422878029831
#
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 7776 events
# INFO:root:Will fill the ggF dataframe with the remaining 4018 events
# INFO:root:tot event weight 32.929079627063295
#
# INFO:root:Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 4366 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 236 events
# INFO:root:tot event weight 53.212045496802084
#
# INFO:root:Finding SingleElectron_Run2017E samples and should combine them under Data
# INFO:root:Finding SingleElectron_Run2017B samples and should combine them under Data
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 6776 events
# INFO:root:Will fill the WH dataframe with the remaining 3286 events
# INFO:root:tot event weight 3.62564090301941
#
# INFO:root:Finding SingleElectron_Run2017C samples and should combine them under Data
# INFO:root:Finding SingleElectron_Run2017D samples and should combine them under Data
# INFO:root:Finding SingleMuon_Run2017C samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 29696 events
# INFO:root:Will fill the Data dataframe with the remaining 1581 events
# INFO:root:tot event weight 1581.0
#
# INFO:root:Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 19040 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 307 events
# INFO:root:tot event weight 0.9981815621110091
#
# INFO:root:Finding SingleMuon_Run2017D samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 13398 events
# INFO:root:Will fill the Data dataframe with the remaining 693 events
# INFO:root:tot event weight 693.0
#
# INFO:root:Finding SingleMuon_Run2017E samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 29299 events
# INFO:root:Will fill the Data dataframe with the remaining 1594 events
# INFO:root:tot event weight 1594.0
#
# INFO:root:Finding SingleMuon_Run2017B samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 14712 events
# INFO:root:Will fill the Data dataframe with the remaining 771 events
# INFO:root:tot event weight 771.0
#
# INFO:root:Finding WW samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 994 events
# INFO:root:Will fill the Diboson dataframe with the remaining 176 events
# INFO:root:tot event weight 83.77501471939864
#
# INFO:root:Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 14797 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 255 events
# INFO:root:tot event weight 7.571683208996101
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 116106 events
# INFO:root:Will fill the TTbar dataframe with the remaining 2436 events
# INFO:root:tot event weight 82.47251591511426
#
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 120 events
# INFO:root:Will fill the Diboson dataframe with the remaining 11 events
# INFO:root:tot event weight 2.686346077496206
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 3464 events
# INFO:root:Will fill the TTbar dataframe with the remaining 81 events
# INFO:root:tot event weight 11.47612213802564
#
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 114579 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 10580 events
# INFO:root:tot event weight 1259.3188869210785
#
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 60793 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 2191 events
# INFO:root:tot event weight 0.8074278307670862
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 14875 events
# INFO:root:Will fill the ttH dataframe with the remaining 3022 events
# INFO:root:tot event weight 5.412215704001309
#
# INFO:root:Finding SingleElectron_Run2017F samples and should combine them under Data
# INFO:root:Finding GluGluZH_HToWW_M-125_TuneCP5_13TeV-powheg-pythia8 samples and should combine them under ZH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 13423 events
# INFO:root:Will fill the ZH dataframe with the remaining 6695 events
# INFO:root:tot event weight 0.08375534444523638
#
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 44134 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 3812 events
# INFO:root:tot event weight 1875.3772553705408
#
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 11783 events
# INFO:root:Will fill the ZH dataframe with the remaining 5906 events
# INFO:root:tot event weight 2.845234375392719
#
# INFO:root:Finding WZ samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 470 events
# INFO:root:Will fill the Diboson dataframe with the remaining 44 events
# INFO:root:tot event weight 12.028768031269665
#
# INFO:root:Finding SingleMuon_Run2017F samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 43194 events
# INFO:root:Will fill the Data dataframe with the remaining 2331 events
# INFO:root:tot event weight 2331.0
#
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 822 events
# INFO:root:Will fill the VBF dataframe with the remaining 384 events
# INFO:root:tot event weight 2.8813089187344154
#
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 19 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding SingleMuon_Run2016H samples and should combine them under Data
# INFO:root:Finding SingleMuon_Run2016F samples and should combine them under Data
# INFO:root:Finding SingleMuon_Run2016G samples and should combine them under Data
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 1077 events
# INFO:root:Will fill the WH dataframe with the remaining 463 events
# INFO:root:tot event weight 0.44847768411290573
#
# INFO:root:Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 43264 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 2704 events
# INFO:root:tot event weight 152.51758673087812
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 357653 events
# INFO:root:Will fill the TTbar dataframe with the remaining 9758 events
# INFO:root:tot event weight 444.10789401490615
#
# INFO:root:Finding SingleElectron_Run2016G samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 18103 events
# INFO:root:Will fill the Data dataframe with the remaining 857 events
# INFO:root:tot event weight 857.0
#
# INFO:root:Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 10913 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 138 events
# INFO:root:tot event weight 3.421504346316823
#
# INFO:root:Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 17 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 60993 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 2394 events
# INFO:root:tot event weight 29.589567915648868
#
# INFO:root:Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 4925 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 155 events
# INFO:root:tot event weight 90.12619434476507
#
# INFO:root:Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 1726 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 84 events
# INFO:root:tot event weight 16.845322570594167
#
# INFO:root:Finding SingleElectron_Run2016H samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 19607 events
# INFO:root:Will fill the Data dataframe with the remaining 900 events
# INFO:root:tot event weight 900.0
#
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 2111 events
# INFO:root:Will fill the ggF dataframe with the remaining 991 events
# INFO:root:tot event weight 7.120795865441716
#
# INFO:root:Finding SingleElectron_Run2016F samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 936 events
# INFO:root:Will fill the Data dataframe with the remaining 49 events
# INFO:root:tot event weight 49.0
#
# INFO:root:Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 1654 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 63 events
# INFO:root:tot event weight 13.330319213628616
#
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 1374 events
# INFO:root:Will fill the WH dataframe with the remaining 581 events
# INFO:root:tot event weight 0.8186692937558132
#
# INFO:root:Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 4871 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 71 events
# INFO:root:tot event weight 0.2404753543155059
#
# INFO:root:Finding WW samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 1367 events
# INFO:root:Will fill the Diboson dataframe with the remaining 201 events
# INFO:root:tot event weight 25.036455334484792
#
# INFO:root:Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 3809 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 59 events
# INFO:root:tot event weight 1.6431998426798051
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 65972 events
# INFO:root:Will fill the TTbar dataframe with the remaining 1382 events
# INFO:root:tot event weight 38.771241516734946
#
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 85 events
# INFO:root:Will fill the Diboson dataframe with the remaining 2 events
# INFO:root:tot event weight 0.5184618651736361
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 725 events
# INFO:root:Will fill the TTbar dataframe with the remaining 30 events
# INFO:root:tot event weight 1.886169729439139
#
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 32347 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 2423 events
# INFO:root:tot event weight 284.11764881724963
#
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 24856 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 288 events
# INFO:root:tot event weight 0.06866596227916173
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 6399 events
# INFO:root:Will fill the ttH dataframe with the remaining 1165 events
# INFO:root:tot event weight 1.7339243467596046
#
# INFO:root:Finding GluGluZH_HToWW_M-125_TuneCP5_13TeV-powheg-pythia8 samples and should combine them under ZH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 5015 events
# INFO:root:Will fill the ZH dataframe with the remaining 1920 events
# INFO:root:tot event weight 0.02123487114411741
#
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 12162 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 849 events
# INFO:root:tot event weight 442.225291580335
#
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 3939 events
# INFO:root:Will fill the ZH dataframe with the remaining 1507 events
# INFO:root:tot event weight 0.6524317148022487
#
# INFO:root:Finding WZ samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 672 events
# INFO:root:Will fill the Diboson dataframe with the remaining 37 events
# INFO:root:tot event weight 3.425023812561253
#
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 1132 events
# INFO:root:Will fill the VBF dataframe with the remaining 609 events
# INFO:root:tot event weight 4.349013416544524
#
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:Finding SingleMuon_Run2016H samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 25175 events
# INFO:root:Will fill the Data dataframe with the remaining 1420 events
# INFO:root:tot event weight 1420.0
#
# INFO:root:Finding SingleMuon_Run2016F samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 1201 events
# INFO:root:Will fill the Data dataframe with the remaining 52 events
# INFO:root:tot event weight 52.0
#
# INFO:root:Finding SingleMuon_Run2016G samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 22084 events
# INFO:root:Will fill the Data dataframe with the remaining 1201 events
# INFO:root:tot event weight 1201.0
#
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:---> Using already stored event weight
# ...
#
# INFO:root:Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 1474 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 65 events
# INFO:root:tot event weight 16.653447545050696
#
# INFO:root:Finding SingleMuon_Run2016F_HIPM samples and should combine them under Data
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 1871 events
# INFO:root:Will fill the WH dataframe with the remaining 750 events
# INFO:root:tot event weight 0.913194431377892
#
# INFO:root:Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 4584 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 70 events
# INFO:root:tot event weight 0.31437755534336964
#
# INFO:root:Finding SingleElectron_Run2016F_HIPM samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 5658 events
# INFO:root:Will fill the Data dataframe with the remaining 299 events
# INFO:root:tot event weight 299.0
#
# INFO:root:Finding WW samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 1157 events
# INFO:root:Will fill the Diboson dataframe with the remaining 155 events
# INFO:root:tot event weight 24.371178662733627
#
# INFO:root:Finding SingleMuon_Run2016D_HIPM samples and should combine them under Data
# INFO:root:Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 3763 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 52 events
# INFO:root:tot event weight 1.802387001815584
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 58556 events
# INFO:root:Will fill the TTbar dataframe with the remaining 1260 events
# INFO:root:tot event weight 40.92227604160077
#
# INFO:root:Finding SingleElectron_Run2016E_HIPM samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 8915 events
# INFO:root:Will fill the Data dataframe with the remaining 464 events
# INFO:root:tot event weight 464.0
#
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 119 events
# INFO:root:Will fill the Diboson dataframe with the remaining 5 events
# INFO:root:tot event weight 1.2380142549470847
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 818 events
# INFO:root:Will fill the TTbar dataframe with the remaining 47 events
# INFO:root:tot event weight 2.4544536230438885
#
# INFO:root:Finding SingleElectron_Run2016D_HIPM samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 9499 events
# INFO:root:Will fill the Data dataframe with the remaining 512 events
# INFO:root:tot event weight 512.0
#
# INFO:root:Finding SingleMuon_Run2016B_ver2_HIPM samples and should combine them under Data
# INFO:root:Finding SingleMuon_Run2016E_HIPM samples and should combine them under Data
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 32368 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 2452 events
# INFO:root:tot event weight 315.66147043166563
#
# INFO:root:Finding SingleElectron_Run2016C_HIPM samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 5696 events
# INFO:root:Will fill the Data dataframe with the remaining 285 events
# INFO:root:tot event weight 285.0
#
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 27093 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 346 events
# INFO:root:tot event weight 0.07951089351742188
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 5370 events
# INFO:root:Will fill the ttH dataframe with the remaining 924 events
# INFO:root:tot event weight 1.767643177312243
#
# INFO:root:Finding GluGluZH_HToWW_M-125_TuneCP5_13TeV-powheg-pythia8 samples and should combine them under ZH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 5480 events
# INFO:root:Will fill the ZH dataframe with the remaining 2118 events
# INFO:root:tot event weight 0.02280585108129316
#
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 13089 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 924 events
# INFO:root:tot event weight 474.9830653970952
#
# INFO:root:Finding SingleMuon_Run2016C_HIPM samples and should combine them under Data
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 4220 events
# INFO:root:Will fill the ZH dataframe with the remaining 1655 events
# INFO:root:tot event weight 0.7436050148433648
#
# INFO:root:Finding WZ samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 687 events
# INFO:root:Will fill the Diboson dataframe with the remaining 29 events
# INFO:root:tot event weight 3.0253963504397117
#
# INFO:root:Finding SingleElectron_Run2016B_ver2_HIPM samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 13459 events
# INFO:root:Will fill the Data dataframe with the remaining 758 events
# INFO:root:tot event weight 758.0
#
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 860 events
# INFO:root:Will fill the VBF dataframe with the remaining 457 events
# INFO:root:tot event weight 5.258700412513424
#
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 19 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 2 events
# INFO:root:tot event weight 2.723830439617679
#
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 2079 events
# INFO:root:Will fill the WH dataframe with the remaining 1044 events
# INFO:root:tot event weight 0.7760342405824139
#
# INFO:root:Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 77194 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 6548 events
# INFO:root:tot event weight 337.91161202618457
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 400063 events
# INFO:root:Will fill the TTbar dataframe with the remaining 13476 events
# INFO:root:tot event weight 702.2993890355266
#
# INFO:root:Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 14713 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 228 events
# INFO:root:tot event weight 6.91074438588835
#
# INFO:root:Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 93 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 5 events
# INFO:root:tot event weight 0.0188646108426851
#
# INFO:root:Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 89879 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 6031 events
# INFO:root:tot event weight 83.9589129982126
#
# INFO:root:Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 6299 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 305 events
# INFO:root:tot event weight 151.2550324430297
#
# INFO:root:Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 1735 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 88 events
# INFO:root:tot event weight 22.26792901502057
#
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 3790 events
# INFO:root:Will fill the ggF dataframe with the remaining 1970 events
# INFO:root:tot event weight 13.337919847511376
#
# INFO:root:Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 1745 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 81 events
# INFO:root:tot event weight 20.512272089738868
#
# INFO:root:Finding SingleMuon_Run2016F_HIPM samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 7245 events
# INFO:root:Will fill the Data dataframe with the remaining 449 events
# INFO:root:tot event weight 449.0
#
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 2638 events
# INFO:root:Will fill the WH dataframe with the remaining 1317 events
# INFO:root:tot event weight 1.5956984740596831
#
# INFO:root:Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 7282 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 145 events
# INFO:root:tot event weight 0.5982306970722233
#
# INFO:root:Finding SingleElectron_Run2016F_HIPM samples and should combine them under Data
# INFO:root:Finding WW samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 1332 events
# INFO:root:Will fill the Diboson dataframe with the remaining 265 events
# INFO:root:tot event weight 41.83492787939296
#
# INFO:root:Finding SingleMuon_Run2016D_HIPM samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 11331 events
# INFO:root:Will fill the Data dataframe with the remaining 712 events
# INFO:root:tot event weight 712.0
#
# INFO:root:Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 6161 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 124 events
# INFO:root:tot event weight 4.430427690580624
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 53014 events
# INFO:root:Will fill the TTbar dataframe with the remaining 1336 events
# INFO:root:tot event weight 43.23506078058332
#
# INFO:root:Finding SingleElectron_Run2016E_HIPM samples and should combine them under Data
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 50 events
# INFO:root:Will fill the Diboson dataframe with the remaining 1 events
# INFO:root:tot event weight 0.26298850755808867
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 3706 events
# INFO:root:Will fill the TTbar dataframe with the remaining 108 events
# INFO:root:tot event weight 5.654946564349404
#
# INFO:root:Finding SingleElectron_Run2016D_HIPM samples and should combine them under Data
# INFO:root:Finding SingleMuon_Run2016B_ver2_HIPM samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 15726 events
# INFO:root:Will fill the Data dataframe with the remaining 925 events
# INFO:root:tot event weight 925.0
#
# INFO:root:Finding SingleMuon_Run2016E_HIPM samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 10634 events
# INFO:root:Will fill the Data dataframe with the remaining 632 events
# INFO:root:tot event weight 632.0
#
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 47533 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 4609 events
# INFO:root:tot event weight 591.5883331453501
#
# INFO:root:Finding SingleElectron_Run2016C_HIPM samples and should combine them under Data
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 42508 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 1497 events
# INFO:root:tot event weight 0.35288594527157113
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 5830 events
# INFO:root:Will fill the ttH dataframe with the remaining 1263 events
# INFO:root:tot event weight 2.3672423671595597
#
# INFO:root:Finding GluGluZH_HToWW_M-125_TuneCP5_13TeV-powheg-pythia8 samples and should combine them under ZH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 6612 events
# INFO:root:Will fill the ZH dataframe with the remaining 3357 events
# INFO:root:tot event weight 0.035796387770670984
#
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 17843 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 1556 events
# INFO:root:tot event weight 788.9972982373508
#
# INFO:root:Finding SingleMuon_Run2016C_HIPM samples and should combine them under Data
# INFO:root:Applying THWW>0.50 selection on 6972 events
# INFO:root:Will fill the Data dataframe with the remaining 413 events
# INFO:root:tot event weight 413.0
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 5636 events
# INFO:root:Will fill the ZH dataframe with the remaining 2848 events
# INFO:root:tot event weight 1.2484352460366552
#
# INFO:root:Finding WZ samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.50 selection on 476 events
# INFO:root:Will fill the Diboson dataframe with the remaining 69 events
# INFO:root:tot event weight 7.369328647100005
#
# INFO:root:Finding SingleElectron_Run2016B_ver2_HIPM samples and should combine them under Data

# %%
for ch in channels:
    for cut, sel in list(presel[ch].items()):
        for sample in samples:
            for year in years:
                try:
                    df = events_dict[year][ch][sample]
                    df = df.query(sel)
                    w = df["event_weight"]
                except:
                    print(year, ch, sample, "is not present so will fill with 0")
                    w = df["event_weight"]

                cutflows[year][ch][sample][cut] = w.sum()

# %%
cutflows["2016APV"]["mu"]["WJetsLNu"]     # take a quick look
# Out:
# {'sumgenweight': 32148205.541996155,
#  'Trigger': 5052102.989037976,
#  'METFilters': 5049012.531204127,
#  'OneLep': 5031057.850622146,
#  'NoTaus': 4271447.470579825,
#  'AtLeastOneFatJet': 461978.1002925532,
#  'CandidateJetpT': 196124.03115179407,
#  'LepInJet': 68289.06508691012,
#  'JetLepOverlap': 26003.119346261694,
#  'dPhiJetMET': 18333.833322064966,
#  'MET': 16980.930607238028,
#  'THWW>0.50': 1956.787905235017}

# %%
cutflows["2016APV"]["ele"]["WJetsLNu"]     # take a quick look
# Out:
# {'sumgenweight': 32241758.10101272,
#  'Trigger': 4454643.38131529,
#  'METFilters': 4451955.991847101,
#  'OneLep': 3062734.5054372367,
#  'NoTaus': 3062734.5054372367,
#  'AtLeastOneFatJet': 364780.748501086,
#  'CandidateJetpT': 153895.86376889877,
#  'LepInJet': 58938.59730123174,
#  'JetLepOverlap': 19206.882023214886,
#  'dPhiJetMET': 13362.535289163337,
#  'MET': 12293.663142455729,
#  'THWW>0.50': 1087.679157780676}

# %% [markdown]
# # Combine different channels

# %%
common_cuts = cutflows["2018"]["mu"]["WJetsLNu"]
common_cuts
# Out:
# {'sumgenweight': 98881812.96014196,
#  'Trigger': 15774784.39789099,
#  'METFilters': 15767863.42776784,
#  'OneLep': 15714197.698371835,
#  'NoTaus': 13365974.316493511,
#  'AtLeastOneFatJet': 1419110.9803375734,
#  'CandidateJetpT': 638940.285300165,
#  'LepInJet': 226599.5724394703,
#  'JetLepOverlap': 85527.28589072316,
#  'dPhiJetMET': 59905.32513231152,
#  'MET': 55958.024490644915,
#  'HEMCleaning': 53830.13943811133,
#  'THWW>0.50': 6439.42214502947}

# %%
def combine_channels(cutflows):

    # combine both channels
    cutflows_new = {}
    for year in cutflows.keys():
        cutflows_new[year] = {}
        cutflows_new[year]["lep"] = {}
        
        for ch in ["mu", "ele"]:
            for sample in cutflows[year][ch]:
                                
                if sample not in cutflows_new[year]["lep"]:
                    cutflows_new[year]["lep"][sample] = {}
                
                for cut in cutflows[year][ch][sample]:
                    
                    if (year != "2018") and (cut == "HEMCleaning"):
                        continue
                    
                    if cut not in cutflows_new[year]["lep"][sample]:
                        cutflows_new[year]["lep"][sample][cut] = cutflows[year][ch][sample][cut]
                    else:
                        cutflows_new[year]["lep"][sample][cut] += cutflows[year][ch][sample][cut]
        cutflows[year] = {**cutflows[year], **cutflows_new[year]}
        
    return cutflows

# %%
cutflows = combine_channels(cutflows)

# %%
cutflows["2018"].keys()
# Out:
# dict_keys(['ele', 'mu', 'lep'])

# %%
cutflows["2018"]["ele"]["WJetsLNu"]
# Out:
# {'sumgenweight': 98938496.94524625,
#  'Trigger': 13452100.702478617,
#  'METFilters': 13446122.536571965,
#  'OneLep': 10365996.09355191,
#  'NoTaus': 10365996.09355191,
#  'AtLeastOneFatJet': 1175735.568559565,
#  'CandidateJetpT': 527612.6926960349,
#  'LepInJet': 203272.06535077497,
#  'JetLepOverlap': 67484.52509185502,
#  'dPhiJetMET': 46443.27286250808,
#  'MET': 43163.8827737948,
#  'HEMCleaning': 41487.080689958166,
#  'THWW>0.50': 4220.261398463306}

# %%
cutflows["2018"]["mu"]["WJetsLNu"]
# Out:
# {'sumgenweight': 98881812.96014196,
#  'Trigger': 15774784.39789099,
#  'METFilters': 15767863.42776784,
#  'OneLep': 15714197.698371835,
#  'NoTaus': 13365974.316493511,
#  'AtLeastOneFatJet': 1419110.9803375734,
#  'CandidateJetpT': 638940.285300165,
#  'LepInJet': 226599.5724394703,
#  'JetLepOverlap': 85527.28589072316,
#  'dPhiJetMET': 59905.32513231152,
#  'MET': 55958.024490644915,
#  'HEMCleaning': 53830.13943811133,
#  'THWW>0.50': 6439.42214502947}

# %%
cutflows["2018"]["lep"]["WJetsLNu"]
# Out:
# {'sumgenweight': 197820309.9053882,
#  'Trigger': 29226885.10036961,
#  'METFilters': 29213985.964339804,
#  'OneLep': 26080193.791923746,
#  'NoTaus': 23731970.410045423,
#  'AtLeastOneFatJet': 2594846.548897139,
#  'CandidateJetpT': 1166552.9779961999,
#  'LepInJet': 429871.63779024524,
#  'JetLepOverlap': 153011.81098257817,
#  'dPhiJetMET': 106348.5979948196,
#  'MET': 99121.90726443971,
#  'HEMCleaning': 95317.22012806949,
#  'THWW>0.50': 10659.683543492776}

# %% [markdown]
# # Combine different years

# %%
def combine_years(cutflows):
    """Will remove the HEM cleaning cutflow from 2018 first."""
    
    whatever_year = list(cutflows.keys())[0]
    channels = cutflows[whatever_year].keys()
    
    # combine all years
    cutflows_new = {}
    cutflows_new["Run2"] = {}
    
    for ch in channels:
        cutflows_new["Run2"][ch] = {}
        
        for year in cutflows:
            for sample in cutflows[year][ch]:
                
                if sample not in cutflows_new["Run2"][ch]:
                    cutflows_new["Run2"][ch][sample] = {}

                for cut in cutflows[year][ch][sample]:
                    if "HEM" in cut:
                        continue
                    if cut not in cutflows_new["Run2"][ch][sample]:
                        cutflows_new["Run2"][ch][sample][cut] = cutflows[year][ch][sample][cut]
                    else:
                        cutflows_new["Run2"][ch][sample][cut] += cutflows[year][ch][sample][cut]

    cutflows = {**cutflows, **cutflows_new}

    return cutflows

# %%
cutflows = combine_years(cutflows)

# %%
cutflows["2016"]["ele"].keys()
# Out:
# dict_keys(['VBF', 'WJetsLNu', 'WH', 'TTbar', 'Data', 'SingleTop', 'ggF', 'Diboson', 'ttH', 'ZH'])

# %%
cutflows.keys()
# Out:
# dict_keys(['2018', '2017', '2016', '2016APV', 'Run2'])

# %%
cutflows["Run2"].keys()
# Out:
# dict_keys(['ele', 'mu', 'lep'])

# %% [markdown]
# # Combine non-dominant backgrounds

# %%
# combine non-dominant backgrounds under others
dominant_bkgs = ["WJetsLNu", "TTbar"]
signals = ["ggF", "VH", "WH", "ZH", "ttH"]

for year in cutflows:
    for ch in cutflows[year]:
        cutflows[year][ch]["Others"] = dict.fromkeys(cutflows[year][ch]["WJetsLNu"], 0)
        for sample in cutflows[year][ch]:
            if sample == "Data":
                continue
            if sample not in signals+dominant_bkgs:
                for cut in cutflows[year][ch][sample]:
                    cutflows[year][ch]["Others"][cut] += cutflows[year][ch][sample][cut]

# %%
cutflows["2018"]["ele"].keys()
# Out:
# dict_keys(['VBF', 'WJetsLNu', 'WH', 'TTbar', 'SingleTop', 'ggF', 'Data', 'Diboson', 'ttH', 'ZH', 'Others'])

# %%
cutflows["2018"]["lep"]["Others"]
# Out:
# {'sumgenweight': 103288174.06980732,
#  'Trigger': 7360679.539628845,
#  'METFilters': 7357757.191103395,
#  'OneLep': 6136757.41099368,
#  'NoTaus': 5316573.641202256,
#  'AtLeastOneFatJet': 394505.280369409,
#  'CandidateJetpT': 196489.79830350704,
#  'LepInJet': 78448.07078503745,
#  'JetLepOverlap': 38007.13455693741,
#  'dPhiJetMET': 25207.602441683914,
#  'MET': 23642.381395779146,
#  'HEMCleaning': 22754.01652855556,
#  'THWW>0.50': 1179.1867931694264}

# %% [markdown]
# # LateX cutflow table

# %%
cuts = [
    "sumgenweight",
    "Trigger",
    "METFilters",
    "OneLep",        
    "NoTaus",
    "AtLeastOneFatJet",
    "CandidateJetpT",
    "LepInJet",
    "JetLepOverlap",
    "dPhiJetMET",
    "MET",
    "HEMCleaning",   
]

for cut in presel["mu"]:
    cuts += [cut]

# %%
cut_to_label = {
    "sumgenweight": "sumgenweight",        
    "HEMCleaning": "HEMCleaning",    
    "Trigger": "Trigger",
    "METFilters": "METFilters",
    "OneLep": "n Leptons = 1",
    "NoTaus": "n Taus = 0",
    "AtLeastOneFatJet": r"n FatJets $>=$ 1",
    "CandidateJetpT": r"j $p_T > 250$GeV",
    "LepInJet": r"$\Delta R(j, \ell) < 0.8$",
    "JetLepOverlap": r"$\Delta R(j, \ell) > 0.03$",
    "dPhiJetMET": r"$\Delta \phi(\mathrm{MET}, j)<1.57$",
    "MET": r"$\mathrm{MET}>20$",
    
    "None": "None",

    "THWW>0.50": r"$\ensuremath{T_{\text{HWW}}^{\ell\nu qq}} > 0.50$",
}

# %%
parquet_to_latex = {
    "WJetsLNu": "$\PW(\Pell\PGn)$+",
    "TTbar": "\\ttbar",
    "Others": "Other MC",

    "ggF": "ggF",
    "VBF": "VBF",
    "WH": "WH",
    "ZH": "ZH",    
    "ttH": "$t\\bar{t}H$",    
    
    "Data": "Data",
}

def make_latex_cutflow_table(cutflows_dict, year, ch, add_data=False, add_sumgenweight=False):
    """Will use the cutflows dictionary to make the LateX table we have in the AN."""
    
    samples_bkg = ["WJetsLNu", "TTbar", "Others"]
    samples_sig = ["ggF","VBF", "WH", "ZH", "ttH"]

    ### backgrounds
    headers = [parquet_to_latex[s] for s in samples_bkg]
    
    textabular = f"l{'r'*len(headers)}"
    textabular += "|r"
    
    texheader = "\\textbf{Inclusive Selection}" + " & " + " & ".join(headers) + " & Total MC "
    if add_data:
        textabular += "|r"
        texheader += "& Data "
    texheader += "\\\\"
    texdata = "\\hline\n"
    
    data = dict()
    
    for cut in cuts: 
        if (year != "2018") and (cut == "HEMCleaning"):
            continue
            
        if not add_sumgenweight and cut == "sumgenweight":
            continue
    
        data[cut] = []

        for sample in samples_bkg:            
            data[cut].append(round(cutflows_dict[year][ch][sample][cut]))
            
        totalmc = 0
        for sample in (samples_bkg + samples_sig):
            totalmc += round(cutflows_dict[year][ch][sample][cut])
            
        data[cut].append(totalmc)
        
        if add_data:
            data[cut].append(round(cutflows_dict[year][ch]["Data"][cut]))

    for label in data:
        if label == "z":
            texdata += "\\hline\n"
        texdata += f"{cut_to_label[label]} & {' & '.join(map(str,data[label]))} \\\\\n"
        
    texdata += "\\hline\n"    

    ### signal
    headers2 = [parquet_to_latex[s] for s in samples_sig]
    texheader2 = " & " + " & ".join(headers2) + "\\\\"
    texdata2 = "\\hline\n"

    textabular2 = f"l{'r'*len(headers2)}"
    
    data = dict()
    for cut in cuts:
        if (year != "2018") and (cut == "HEMCleaning"):
            continue
            
        data[cut] = []

        for sample in samples_sig:
            data[cut].append(round(cutflows_dict[year][ch][sample][cut]))
        
    for label in data:
        if label == "z":
            texdata += "\\hline\n"
        texdata2 += f"{cut_to_label[label]} & {' & '.join(map(str,data[label]))} \\\\\n"    

    # make table
    print("\\begin{table}[!htp]")
    print("\\begin{center}")
    
    print("\\begin{tabular}{"+textabular+"}")
    print(texheader)
    print(texdata,end="")
    print("\\end{tabular}")

    print("\\begin{tabular}{"+textabular2+"}")
    print(texheader2)
    print(texdata2,end="")
    print("\\end{tabular}")
    
    
    if ch == "lep":
        print("\\caption{Event yield of " + year + " Monte Carlo samples normalized to " + str(round(get_lumi([year], [ch]))) + "\\fbinv.}")        
    else:
        print("\\caption{Event yield of " + ch + " channel " + year + " Monte Carlo samples normalized to " + str(round(get_lumi([year], [ch]))) + "\\fbinv.}")
        
    print("\\label{sel-tab-cutflow" + year + "}")
    print("\\end{center}")
    print("\\end{table}")

# %%
make_latex_cutflow_table(cutflows, "2018", "lep", add_data=True, add_sumgenweight=True)
# Out:
# \begin{table}[!htp]
# \begin{center}
# \begin{tabular}{lrrr|r|r}
# \textbf{Inclusive Selection} & $\PW(\Pell\PGn)$+ & \ttbar & Other MC & Total MC & Data \\
# \hline
# sumgenweight & 197820310 & 99476871 & 103288174 & 400775883 & 2276244440 \\
# Trigger & 29226885 & 10530862 & 7360680 & 47135028 & 1174738710 \\
# METFilters & 29213986 & 10525258 & 7357757 & 47113588 & 1173476723 \\
# n Leptons = 1 & 26080194 & 8802028 & 6136757 & 41032249 & 656865738 \\
# n Taus = 0 & 23731970 & 7031360 & 5316574 & 36090550 & 632124064 \\
# n FatJets $>=$ 1 & 2594847 & 1264303 & 394505 & 4256058 & 6978889 \\
# j $p_T > 250$GeV & 1166553 & 642826 & 196490 & 2007188 & 2825338 \\
# $\Delta R(j, \ell) < 0.8$ & 429872 & 283927 & 78448 & 792939 & 1392226 \\
# $\Delta R(j, \ell) > 0.03$ & 153012 & 245916 & 38007 & 437557 & 640994 \\
# $\Delta \phi(\mathrm{MET}, j)<1.57$ & 106349 & 155612 & 25208 & 287591 & 359014 \\
# $\mathrm{MET}>20$ & 99122 & 146620 & 23642 & 269777 & 326733 \\
# HEMCleaning & 95317 & 140577 & 22754 & 258971 & 298219 \\
# $\ensuremath{T_{\text{HWW}}^{\ell\nu qq}} > 0.50$ & 10660 & 4009 & 1179 & 15981 & 15800 \\
# \hline
# \end{tabular}
# \begin{tabular}{lrrrrr}
#  & ggF & VBF & WH & ZH & $t\bar{t}H$\\
# \hline
# sumgenweight & 12053 & 96661 & 36203 & 20484 & 25127 \\
# Trigger & 1273 & 6192 & 3766 & 1674 & 3696 \\
# METFilters & 1271 & 6187 & 3764 & 1673 & 3692 \\
# n Leptons = 1 & 1032 & 5191 & 3026 & 1228 & 2793 \\
# n Taus = 0 & 894 & 4374 & 2435 & 1011 & 1932 \\
# n FatJets $>=$ 1 & 738 & 424 & 273 & 110 & 858 \\
# j $p_T > 250$GeV & 416 & 194 & 142 & 59 & 508 \\
# $\Delta R(j, \ell) < 0.8$ & 245 & 112 & 67 & 34 & 234 \\
# $\Delta R(j, \ell) > 0.03$ & 229 & 104 & 45 & 31 & 213 \\
# $\Delta \phi(\mathrm{MET}, j)<1.57$ & 165 & 75 & 31 & 17 & 134 \\
# $\mathrm{MET}>20$ & 151 & 69 & 29 & 16 & 128 \\
# HEMCleaning & 146 & 66 & 27 & 15 & 69 \\
# $\ensuremath{T_{\text{HWW}}^{\ell\nu qq}} > 0.50$ & 73 & 27 & 13 & 7 & 13 \\
# \end{tabular}
# \caption{Event yield of 2018 Monte Carlo samples normalized to 60\fbinv.}
# \label{sel-tab-cutflow2018}
# \end{center}
# \end{table}
