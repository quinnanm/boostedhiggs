# %% [markdown]
# # Compute the LateX cutflow tables
# - Will load the pkl files that contain the cutflows and the sumgenweight
# - Will scale the events by the cross section
# - Will save the yields in a dictionnary called ```cutflows -> Dict()```
# - Will make the LateX table using the function ```make_composition_table()```

# %%
import glob
import json
import os
import pickle as pkl
import sys

import hist as hist2
import matplotlib.pyplot as plt
import mplhep as hep
import numpy as np
import pandas as pd
import pyarrow
import pyarrow.parquet as pq
import yaml
from scipy.special import softmax
from sklearn.metrics import auc, roc_curve

sys.path
sys.path.append("../python/")

import utils

plt.style.use(hep.style.CMS)
plt.rcParams.update({"font.size": 20})

pd.options.mode.chained_assignment = None

import glob
import os
import json
import pickle
import yaml
import math

import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None
import pyarrow.parquet as pq
from sklearn.metrics import auc, roc_curve
from scipy.special import softmax

import hist as hist2
import matplotlib.pyplot as plt
import mplhep as hep

plt.style.use(hep.style.CMS)

import sys
sys.path
sys.path.append("../python/")

import utils

plt.rcParams.update({"font.size": 20})

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# get lumi
with open("../fileset/luminosity.json") as f:
    luminosity = json.load(f)
    
luminosity
# Out:
# {'ele': {'Run2': 137640.0,
#   '2016APV': 19492.72,
#   '2016': 16809.96,
#   '2017': 41476.02,
#   '2018': 59816.23},
#  'mu': {'Run2': 137640.0,
#   '2016APV': 19436.16,
#   '2016': 16810.81,
#   '2017': 41475.26,
#   '2018': 59781.96},
#  'lep': {'Run2': 137640.0,
#   '2016APV': 19436.16,
#   '2016': 16810.81,
#   '2017': 41475.26,
#   '2018': 59781.96},
#  'had': {'Run2': 137640.0,
#   '2016APV': 19436.16,
#   '2016': 16810.81,
#   '2017': 41475.26,
#   '2018': 59781.96}}

# %%
def get_lumi(years, channels):
    lum_ = 0
    for year in years:
        lum = 0
        for ch in channels:
            lum += luminosity[ch][year] / 1000.0

        lum_ += lum / len(channels)    
    return lum_

# %% [markdown]
# # Read cutflows from pkl

# %%
def get_sum_sumgenweight(pkl_files, year, sample):
    """Load and sum the sumgenweight of each pkl file."""
    
    sum_sumgenweight = 0
    for ifile in pkl_files:
        with open(ifile, "rb") as f:
            metadata = pkl.load(f)            
        sum_sumgenweight = sum_sumgenweight + metadata[sample][year]["sumgenweight"]

    return sum_sumgenweight


def get_xsecweight(pkl_files, year, ch, sample, is_data):
    
    if not is_data:
        # find xsection
        f = open("../fileset/xsec_pfnano.json")
        xsec = json.load(f)
        f.close()
        try:
            xsec = eval(str((xsec[sample])))
        except ValueError:
            print(f"sample {sample} doesn't have xsecs defined in xsec_pfnano.json so will skip it")
            return None

        # get overall weighting of events.. each event has a genweight...
        # sumgenweight sums over events in a chunk... sum_sumgenweight sums over chunks
        xsec_weight = (xsec * luminosity[ch][year]) / get_sum_sumgenweight(pkl_files, year, sample)
    else:
        xsec_weight = 1
    return xsec_weight

def get_cutflow(pkl_files, year, ch, sample, is_data):
    """
    Get cutflow from metadata but multiply by xsec-weight
    """
    xsec_weight = get_xsecweight(pkl_files, year, ch, sample, is_data)
        
    cuts = [
        "sumgenweight",
        "Trigger",
        "METFilters",
        "OneLep",
        "NoTaus",
        "AtLeastOneFatJet",
        "CandidateJetpT",
        "LepInJet",
        "JetLepOverlap",
        "dPhiJetMET",
        "MET",
    ]
        
    if year == "2018":
        cuts += ["HEMCleaning"]
        
    evyield = dict.fromkeys(cuts, 0)
    for ik, pkl_file in enumerate(pkl_files):
        with open(pkl_file, "rb") as f:
            metadata = pkl.load(f)
            
        cutflows = metadata[sample][year]["cutflows"][ch]

        for key in evyield.keys():

            if key == "sumgenweight":
                evyield[key] += metadata[sample][year][key] * xsec_weight
            else:
                evyield[key] += cutflows[key] * xsec_weight        
    return evyield

# %%
! ls ../eos/May31_hww_2018/WJetsToLNu_HT-100To200/outfiles/0-10.pkl
# Out:
# ../eos/May31_hww_2018/WJetsToLNu_HT-100To200/outfiles/0-10.pkl

# %%
with open("../eos/May31_hww_2018/WJetsToLNu_HT-100To200/outfiles/0-10.pkl", "rb") as f:
    metadata = pkl.load(f)
metadata
# Out:
# {'WJetsToLNu_HT-100To200': {'mc': 89,
#   '2018': {'sumgenweight': 860209.0,
#    'sumlheweight': {0: 893759.06,
#     1: 894174.7,
#     2: 888283.2,
#     3: 859625.5,
#     4: 860209.0,
#     5: 854675.94,
#     6: 831615.4,
#     7: 832338.2,
#     8: 827100.1},
#    'sumpdfweight': {},
#    'cutflows': {'ele': {'Trigger': 112333.0,
#      'METFilters': 112304.0,
#      'OneLep': 86555.0,
#      'NoTaus': 86555.0,
#      'AtLeastOneFatJet': 1048.0,
#      'CandidateJetpT': 43.0,
#      'LepInJet': 27.0,
#      'JetLepOverlap': 8.0,
#      'dPhiJetMET': 1.0,
#      'MET': 1.0,
#      'HEMCleaning': 1.0},
#     'mu': {'Trigger': 133416.0,
#      'METFilters': 133390.0,
#      'OneLep': 133079.0,
#      'NoTaus': 112979.0,
#      'AtLeastOneFatJet': 1338.0,
#      'CandidateJetpT': 75.0,
#      'LepInJet': 51.0,
#      'JetLepOverlap': 11.0,
#      'dPhiJetMET': 1.0,
#      'MET': 1.0,
#      'HEMCleaning': 1.0}}}}}

# %% [markdown]
# # Adding a cut from the parquets

# %%
### This is your configuration. specefy which channels, years, samples, and directory of pkl files to use.
channels = ["ele", "mu"]
years = ["2018", "2017", "2016", "2016APV"]

samples = [
    "ggF", 
    "WH",
    "ZH",
    "VBF",
    "ttH",
    "DYJets",
    "WJetsLNu",
    "WZQQ",
    "TTbar",
    "SingleTop",
    "Diboson",
    "Data"
]

samples_dir = {
    "2016":    "../eos/May31_hww_2016",
    "2016APV": "../eos/May31_hww_2016APV",    
    "2017":    "../eos/May31_hww_2017",    
    "2018":    "../eos/May31_hww_2018",    
}

# %%
cutflows = {}
for year in years:
#     if year != "2016":
#         continue
    print(f"Processing year {year}")
    
    cutflows[year] = {}
    
    for ch in channels:
#         if ch != "mu": 
#             continue
        
        print(f"  {ch} channel")
        cutflows[year][ch] = {}

        condor_dir = os.listdir(samples_dir[year])

        for sample in condor_dir:

            # first: check if the sample is in one of combine_samples_by_name
            sample_to_use = None
            for key in utils.combine_samples_by_name:
                if key in sample:
                    sample_to_use = utils.combine_samples_by_name[key]
                    break

            # second: if not, combine under common label
            if sample_to_use is None:
                for key in utils.combine_samples:
                    if key in sample:
                        sample_to_use = utils.combine_samples[key]
                        break
                    else:
                        sample_to_use = sample

            if sample_to_use not in samples:
                continue

            is_data = False
            if sample_to_use == "Data":
                is_data = True

            out_files = f"{samples_dir[year]}/{sample}/outfiles/"
            pkl_files = glob.glob(f"{out_files}/*.pkl")

            if len(pkl_files) == 0:
                continue

            parquet_files = glob.glob(f"{out_files}/*_{ch}.parquet")
            
            try:
                data = pd.read_parquet(parquet_files)
            except pyarrow.lib.ArrowInvalid:
                # empty parquet because no event passed selection
#                 print(f"No parquet file for {sample}")
                continue

            if len(data) == 0:
#                 print(f"Hi, No parquet file for {sample}")
                continue
    
            if sample_to_use not in cutflows[year][ch].keys():
                cutflows[year][ch][sample_to_use] = get_cutflow(pkl_files, year, ch, sample, is_data)
            else:
                temp = get_cutflow(pkl_files, year, ch, sample, is_data)
                for key in cutflows[year][ch][sample_to_use]:
                    cutflows[year][ch][sample_to_use][key] += temp[key]
            
    print(f"------------------------------------------")
# Out:
# Processing year 2018
#   ele channel
#   mu channel
# ------------------------------------------
# Processing year 2017
#   ele channel
#   mu channel
# ------------------------------------------
# Processing year 2016
#   ele channel
#   mu channel
# ------------------------------------------
# Processing year 2016APV
#   ele channel
#   mu channel
# ------------------------------------------

# %%
samples = cutflows["2017"]["ele"].keys()  # samples
samples
# Out:
# dict_keys(['VBF', 'WJetsLNu', 'WH', 'TTbar', 'SingleTop', 'ggF', 'DYJets', 'Data', 'Diboson', 'WZQQ', 'ttH', 'ZH'])

# %%
from make_stacked_hists import make_events_dict

presel = {
        "mu": {
#             "fj_mass": "fj_mass>40",
#             "THWW>0.50": "THWW>0.50",
        },
        "ele": {
#             "fj_mass": "fj_mass>40",            
#             "THWW>0.50": "THWW>0.50",
        },
}

events_dict = {}
for year in years:
    
    out = make_events_dict([year], channels, samples_dir[year], samples, presel)
    events_dict = {**events_dict, **out}
# Out:
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:Will fill the VBF dataframe with the remaining 1601 events
# INFO:root:tot event weight 21.074064183517688
#
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 57 events
# INFO:root:tot event weight 124.66253855083318
#
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Will fill the WH dataframe with the remaining 5590 events
# INFO:root:tot event weight 3.9114648725696095
#
# INFO:root:Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 161246 events
# INFO:root:tot event weight 8964.872882030751
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 356607 events
# INFO:root:tot event weight 58101.02961883718
#
# INFO:root:Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 31662 events
# INFO:root:tot event weight 969.7022024087099
#
# INFO:root:Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# INFO:root:Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 191897 events
# INFO:root:tot event weight 2752.727250997397
#
# INFO:root:Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 20284 events
# INFO:root:tot event weight 10041.128571832562
#
# INFO:root:Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 5477 events
# INFO:root:tot event weight 1297.043998407319
#
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:Will fill the ggF dataframe with the remaining 4742 events
# INFO:root:tot event weight 55.46630913585513
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-650ToInf samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 220601 events
# INFO:root:tot event weight 131.31124667728224
#
# INFO:root:Finding WJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 5308 events
# INFO:root:tot event weight 1298.9735810734937
#
# INFO:root:Finding ZJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Will fill the WH dataframe with the remaining 6220 events
# INFO:root:tot event weight 7.50421744171726
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-100To250 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 64445 events
# INFO:root:tot event weight 4445.604482352278
#
# INFO:root:Finding EGamma_Run2018A samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 32586 events
# INFO:root:tot event weight 32586.0
#
# INFO:root:Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 17488 events
# INFO:root:tot event weight 56.61437585053912
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-50To100 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 3969 events
# INFO:root:tot event weight 834.093638849035
#
# INFO:root:Finding SingleMuon_Run2018A samples and should combine them under Data
# INFO:root:Finding WW samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 595 events
# INFO:root:tot event weight 630.5837487069734
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-250To400 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 710489 events
# INFO:root:tot event weight 5747.168703577734
#
# INFO:root:Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 12290 events
# INFO:root:tot event weight 422.61927890110724
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 128508 events
# INFO:root:tot event weight 6441.929508899041
#
# INFO:root:Finding ZJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 58 events
# INFO:root:tot event weight 43.45463549304682
#
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 312 events
# INFO:root:tot event weight 81.26090139486593
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 652 events
# INFO:root:tot event weight 144.6379840524565
#
# INFO:root:Finding WJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 767 events
# INFO:root:tot event weight 136.5226133192931
#
# INFO:root:Finding ZJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 333 events
# INFO:root:tot event weight 63.687975774912005
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-400To650 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 198729 events
# INFO:root:tot event weight 1425.8993286775788
#
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 107384 events
# INFO:root:tot event weight 13940.976775407215
#
# INFO:root:Finding WJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 456 events
# INFO:root:tot event weight 172.69356189506277
#
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 62439 events
# INFO:root:tot event weight 22.550160913969844
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Will fill the ttH dataframe with the remaining 5879 events
# INFO:root:tot event weight 34.396404934879286
#
# INFO:root:Finding ZJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 512 events
# INFO:root:tot event weight 60.63556818372514
#
# INFO:root:Finding EGamma_Run2018C samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 15261 events
# INFO:root:tot event weight 15261.0
#
# INFO:root:Finding EGamma_Run2018D samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 69925 events
# INFO:root:tot event weight 69925.0
#
# INFO:root:Finding EGamma_Run2018B samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 16456 events
# INFO:root:tot event weight 16456.0
#
# INFO:root:Finding GluGluZH_HToWW_M-125_TuneCP5_13TeV-powheg-pythia8 samples and should combine them under ZH
# INFO:root:Will fill the ZH dataframe with the remaining 15502 events
# INFO:root:tot event weight 0.2003368944356042
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-0To50 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 992 events
# INFO:root:tot event weight 424.2142333017813
#
# INFO:root:Finding SingleMuon_Run2018C samples and should combine them under Data
# INFO:root:Finding WJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 64 events
# INFO:root:tot event weight 192.47129350317093
# INFO:root:Finding SingleMuon_Run2018D samples and should combine them under Data
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 46191 events
# INFO:root:tot event weight 22920.58776421901
#
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:Will fill the ZH dataframe with the remaining 9318 events
# INFO:root:tot event weight 6.3439819732651905
#
# INFO:root:Finding WZ samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 704 events
# INFO:root:tot event weight 243.4683272178351
#
# INFO:root:Finding SingleMuon_Run2018B samples and should combine them under Data
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:Will fill the VBF dataframe with the remaining 2473 events
# INFO:root:tot event weight 32.91738752949709
#
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 74 events
# INFO:root:tot event weight 162.8014591321981
#
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Will fill the WH dataframe with the remaining 7423 events
# INFO:root:tot event weight 5.291285755829196
#
# INFO:root:Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 222471 events
# INFO:root:tot event weight 12675.090876540398
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 402523 events
# INFO:root:tot event weight 66392.48220666483
#
# INFO:root:Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 49731 events
# INFO:root:tot event weight 1551.8713763681326
#
# INFO:root:Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 311 events
# INFO:root:tot event weight 2.5093450010706793
#
# INFO:root:Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 272793 events
# INFO:root:tot event weight 4005.2181380444067
#
# INFO:root:Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 23295 events
# INFO:root:tot event weight 11671.75487338502
#
# INFO:root:Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 6077 events
# INFO:root:tot event weight 1456.501799080249
#
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:Will fill the ggF dataframe with the remaining 7341 events
# INFO:root:tot event weight 87.0796407739135
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-650ToInf samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 116461 events
# INFO:root:tot event weight 69.62541539267228
#
# INFO:root:Finding WJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 5845 events
# INFO:root:tot event weight 1441.8254954503282
#
# INFO:root:Finding ZJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Will fill the WH dataframe with the remaining 8428 events
# INFO:root:tot event weight 10.27763904582957
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-100To250 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 43513 events
# INFO:root:tot event weight 3121.880472619706
#
# INFO:root:Finding EGamma_Run2018A samples and should combine them under Data
# INFO:root:Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 25488 events
# INFO:root:tot event weight 83.6228938172836
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-50To100 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 4479 events
# INFO:root:tot event weight 952.8358826816936
#
# INFO:root:Finding SingleMuon_Run2018A samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 40106 events
# INFO:root:tot event weight 40106.0
#
# INFO:root:Finding WW samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 624 events
# INFO:root:tot event weight 665.5453848966413
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-250To400 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 165761 events
# INFO:root:tot event weight 1328.6089311180053
#
# INFO:root:Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 19319 events
# INFO:root:tot event weight 671.2402601890902
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 109129 events
# INFO:root:tot event weight 5546.1726037587905
#
# INFO:root:Finding ZJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 99 events
# INFO:root:tot event weight 72.87026412553513
#
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 160 events
# INFO:root:tot event weight 41.78763915568997
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 3327 events
# INFO:root:tot event weight 731.6849923754332
#
# INFO:root:Finding WJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 1172 events
# INFO:root:tot event weight 201.79581481330467
#
# INFO:root:Finding ZJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 1005 events
# INFO:root:tot event weight 188.53227173460397
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-400To650 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 47342 events
# INFO:root:tot event weight 344.52647769730424
#
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 145429 events
# INFO:root:tot event weight 19351.36650661318
#
# INFO:root:Finding WJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 437 events
# INFO:root:tot event weight 162.92643577824938
#
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 89378 events
# INFO:root:tot event weight 32.89066035535227
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Will fill the ttH dataframe with the remaining 5721 events
# INFO:root:tot event weight 33.2811860646585
#
# INFO:root:Finding ZJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 1871 events
# INFO:root:tot event weight 210.5518044389124
#
# INFO:root:Finding EGamma_Run2018C samples and should combine them under Data
# INFO:root:Finding EGamma_Run2018D samples and should combine them under Data
# INFO:root:Finding EGamma_Run2018B samples and should combine them under Data
# INFO:root:Finding GluGluZH_HToWW_M-125_TuneCP5_13TeV-powheg-pythia8 samples and should combine them under ZH
# INFO:root:Will fill the ZH dataframe with the remaining 17325 events
# INFO:root:tot event weight 0.22628385875866708
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-0To50 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 833 events
# INFO:root:tot event weight 327.39428983169194
#
# INFO:root:Finding SingleMuon_Run2018C samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 18506 events
# INFO:root:tot event weight 18506.0
#
# INFO:root:Finding WJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Finding SingleMuon_Run2018D samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 85292 events
# INFO:root:tot event weight 85292.0
#
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 59086 events
# INFO:root:tot event weight 29955.479012571286
#
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:Will fill the ZH dataframe with the remaining 11737 events
# INFO:root:tot event weight 8.072974704944812
#
# INFO:root:Finding WZ samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 468 events
# INFO:root:tot event weight 162.76963851039972
#
# INFO:root:Finding SingleMuon_Run2018B samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 20087 events
# INFO:root:tot event weight 20087.0
#
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:Will fill the VBF dataframe with the remaining 1745 events
# INFO:root:tot event weight 14.771772068589947
#
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 87 events
# INFO:root:tot event weight 133.06982099952822
#
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Will fill the WH dataframe with the remaining 4084 events
# INFO:root:tot event weight 2.8625874216643155
#
# INFO:root:Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 112821 events
# INFO:root:tot event weight 6247.907115617004
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 359402 events
# INFO:root:tot event weight 42484.01735364143
#
# INFO:root:Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 23731 events
# INFO:root:tot event weight 654.6877353330026
#
# INFO:root:Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 35 events
# INFO:root:tot event weight 0.2654681851784302
#
# INFO:root:Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 122307 events
# INFO:root:tot event weight 1953.2985651175777
#
# INFO:root:Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 18679 events
# INFO:root:tot event weight 8227.312972793961
#
# INFO:root:Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 4097 events
# INFO:root:tot event weight 944.0915577483557
#
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:Will fill the ggF dataframe with the remaining 4951 events
# INFO:root:tot event weight 40.94875292327576
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-650ToInf samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 236765 events
# INFO:root:tot event weight 97.86528083288626
#
# INFO:root:Finding WJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 4086 events
# INFO:root:tot event weight 963.337487994272
#
# INFO:root:Finding ZJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding SingleElectron_Run2017E samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 22746 events
# INFO:root:tot event weight 22746.0
#
# INFO:root:Finding SingleElectron_Run2017B samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 9060 events
# INFO:root:tot event weight 9060.0
#
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Will fill the WH dataframe with the remaining 4843 events
# INFO:root:tot event weight 5.609704953647668
#
# INFO:root:Finding SingleElectron_Run2017C samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 24152 events
# INFO:root:tot event weight 24152.0
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-100To250 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 62810 events
# INFO:root:tot event weight 3349.9939789328732
#
# INFO:root:Finding SingleElectron_Run2017D samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 10914 events
# INFO:root:tot event weight 10914.0
#
# INFO:root:Finding SingleMuon_Run2017C samples and should combine them under Data
# INFO:root:Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 12856 events
# INFO:root:tot event weight 42.911263068403414
#
# INFO:root:Finding SingleMuon_Run2017D samples and should combine them under Data
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-50To100 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 3323 events
# INFO:root:tot event weight 721.0630692368625
#
# INFO:root:Finding SingleMuon_Run2017E samples and should combine them under Data
# INFO:root:Finding SingleMuon_Run2017B samples and should combine them under Data
# INFO:root:Finding WW samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 914 events
# INFO:root:tot event weight 438.3958883113615
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-250To400 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 762441 events
# INFO:root:tot event weight 4103.634328800298
#
# INFO:root:Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 9636 events
# INFO:root:tot event weight 309.7394989575566
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 137227 events
# INFO:root:tot event weight 4804.0749060672215
#
# INFO:root:Finding ZJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 73 events
# INFO:root:tot event weight 33.67335145258906
#
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 272 events
# INFO:root:tot event weight 64.40279849167939
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 662 events
# INFO:root:tot event weight 97.57108153425844
#
# INFO:root:Finding WJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 876 events
# INFO:root:tot event weight 90.96750700761501
#
# INFO:root:Finding ZJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 325 events
# INFO:root:tot event weight 41.013269115067146
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-400To650 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 191943 events
# INFO:root:tot event weight 1047.0600333533107
#
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 83350 events
# INFO:root:tot event weight 9642.69066005765
#
# INFO:root:Finding WJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 534 events
# INFO:root:tot event weight 118.59646285331937
#
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 41130 events
# INFO:root:tot event weight 15.584969758500025
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Will fill the ttH dataframe with the remaining 15128 events
# INFO:root:tot event weight 24.740680744509536
#
# INFO:root:Finding ZJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 478 events
# INFO:root:tot event weight 36.3821313506601
#
# INFO:root:Finding SingleElectron_Run2017F samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 31932 events
# INFO:root:tot event weight 31932.0
#
# INFO:root:Finding GluGluZH_HToWW_M-125_TuneCP5_13TeV-powheg-pythia8 samples and should combine them under ZH
# INFO:root:Will fill the ZH dataframe with the remaining 11616 events
# INFO:root:tot event weight 0.1487907534622439
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-0To50 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 684 events
# INFO:root:tot event weight 220.5014149809549
#
# INFO:root:Finding WJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 42 events
# INFO:root:tot event weight 96.16439396055642
#
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 33953 events
# INFO:root:tot event weight 16403.092941696075
#
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:Will fill the ZH dataframe with the remaining 9507 events
# INFO:root:tot event weight 4.781833259338158
#
# INFO:root:Finding WZ samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 608 events
# INFO:root:tot event weight 163.90907064996327
#
# INFO:root:Finding SingleMuon_Run2017F samples and should combine them under Data
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:Will fill the VBF dataframe with the remaining 2612 events
# INFO:root:tot event weight 21.62324376641849
#
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 107 events
# INFO:root:tot event weight 172.75161749230702
#
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Will fill the WH dataframe with the remaining 5565 events
# INFO:root:tot event weight 3.7958832790061012
#
# INFO:root:Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 158739 events
# INFO:root:tot event weight 8953.5317042282
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 412828 events
# INFO:root:tot event weight 48576.268338104644
#
# INFO:root:Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 38837 events
# INFO:root:tot event weight 1096.1648296450883
#
# INFO:root:Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 267 events
# INFO:root:tot event weight 1.8156266766227398
#
# INFO:root:Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 176509 events
# INFO:root:tot event weight 2846.2507652613763
#
# INFO:root:Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 21569 events
# INFO:root:tot event weight 9473.546439433938
#
# INFO:root:Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 4545 events
# INFO:root:tot event weight 1056.3897248114629
#
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:Will fill the ggF dataframe with the remaining 7776 events
# INFO:root:tot event weight 62.50844628577522
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-650ToInf samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 122224 events
# INFO:root:tot event weight 49.079623977744134
#
# INFO:root:Finding WJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 4366 events
# INFO:root:tot event weight 988.4614467347437
#
# INFO:root:Finding ZJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding SingleElectron_Run2017E samples and should combine them under Data
# INFO:root:Finding SingleElectron_Run2017B samples and should combine them under Data
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Will fill the WH dataframe with the remaining 6776 events
# INFO:root:tot event weight 7.683415825370579
#
# INFO:root:Finding SingleElectron_Run2017C samples and should combine them under Data
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-100To250 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 42669 events
# INFO:root:tot event weight 2320.920304703184
#
# INFO:root:Finding SingleElectron_Run2017D samples and should combine them under Data
# INFO:root:Finding SingleMuon_Run2017C samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 29696 events
# INFO:root:tot event weight 29696.0
#
# INFO:root:Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 19040 events
# INFO:root:tot event weight 58.14804164573229
#
# INFO:root:Finding SingleMuon_Run2017D samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 13398 events
# INFO:root:tot event weight 13398.0
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-50To100 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 3943 events
# INFO:root:tot event weight 774.5005599032963
#
# INFO:root:Finding SingleMuon_Run2017E samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 29299 events
# INFO:root:tot event weight 29299.0
#
# INFO:root:Finding SingleMuon_Run2017B samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 14712 events
# INFO:root:tot event weight 14712.0
#
# INFO:root:Finding WW samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 994 events
# INFO:root:tot event weight 468.15579489240355
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-250To400 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 174042 events
# INFO:root:tot event weight 938.0761844675327
#
# INFO:root:Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 14797 events
# INFO:root:tot event weight 467.27229502395187
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 116106 events
# INFO:root:tot event weight 3999.3481376684326
#
# INFO:root:Finding ZJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 129 events
# INFO:root:tot event weight 60.98035626845987
#
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 120 events
# INFO:root:tot event weight 29.535019260246155
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 3464 events
# INFO:root:tot event weight 499.91235167797913
#
# INFO:root:Finding WJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 1388 events
# INFO:root:tot event weight 140.99948074345917
#
# INFO:root:Finding ZJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 1055 events
# INFO:root:tot event weight 136.6848119375914
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-400To650 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 44488 events
# INFO:root:tot event weight 242.87629246313833
#
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 114579 events
# INFO:root:tot event weight 13568.886796149476
#
# INFO:root:Finding WJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 546 events
# INFO:root:tot event weight 123.59486294804256
#
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 60793 events
# INFO:root:tot event weight 23.03249598421183
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Will fill the ttH dataframe with the remaining 14875 events
# INFO:root:tot event weight 24.032903002344582
#
# INFO:root:Finding ZJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 2027 events
# INFO:root:tot event weight 165.25894263454106
#
# INFO:root:Finding SingleElectron_Run2017F samples and should combine them under Data
# INFO:root:Finding GluGluZH_HToWW_M-125_TuneCP5_13TeV-powheg-pythia8 samples and should combine them under ZH
# INFO:root:Will fill the ZH dataframe with the remaining 13423 events
# INFO:root:tot event weight 0.1698445014887735
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-0To50 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 605 events
# INFO:root:tot event weight 270.58889485047024
#
# INFO:root:Finding WJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 27 events
# INFO:root:tot event weight 61.24953745879669
#
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 44134 events
# INFO:root:tot event weight 21816.25105454742
#
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:Will fill the ZH dataframe with the remaining 11783 events
# INFO:root:tot event weight 5.647836525276068
#
# INFO:root:Finding WZ samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 470 events
# INFO:root:tot event weight 130.11912079774328
#
# INFO:root:Finding SingleMuon_Run2017F samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 43194 events
# INFO:root:tot event weight 43194.0
#
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:Will fill the VBF dataframe with the remaining 822 events
# INFO:root:tot event weight 6.14060672344256
#
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 19 events
# INFO:root:tot event weight 30.688204597510268
#
# INFO:root:Finding SingleMuon_Run2016H samples and should combine them under Data
# INFO:root:Finding SingleMuon_Run2016F samples and should combine them under Data
# INFO:root:Finding SingleMuon_Run2016G samples and should combine them under Data
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Will fill the WH dataframe with the remaining 1077 events
# INFO:root:tot event weight 1.0595516669964347
#
# INFO:root:Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 43264 events
# INFO:root:tot event weight 2444.7572952947944
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 357653 events
# INFO:root:tot event weight 16195.568428084447
#
# INFO:root:Finding SingleElectron_Run2016G samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 18103 events
# INFO:root:tot event weight 18103.0
#
# INFO:root:Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 10913 events
# INFO:root:tot event weight 256.3462023134698
#
# INFO:root:Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 17 events
# INFO:root:tot event weight 0.18191821471177275
#
# INFO:root:Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 60993 events
# INFO:root:tot event weight 762.9350937106717
#
# INFO:root:Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 4925 events
# INFO:root:tot event weight 2770.08989443243
#
# INFO:root:Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 1726 events
# INFO:root:tot event weight 371.3617281441227
#
# INFO:root:Finding SingleElectron_Run2016H samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 19607 events
# INFO:root:tot event weight 19607.0
#
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:Will fill the ggF dataframe with the remaining 2111 events
# INFO:root:tot event weight 15.197564815446151
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-650ToInf samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 120699 events
# INFO:root:tot event weight 40.87441204471368
#
# INFO:root:Finding SingleElectron_Run2016F samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 936 events
# INFO:root:tot event weight 936.0
#
# INFO:root:Finding WJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 1654 events
# INFO:root:tot event weight 345.639850967778
#
# INFO:root:Finding ZJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Will fill the WH dataframe with the remaining 1374 events
# INFO:root:tot event weight 2.0368565291959775
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-100To250 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 28508 events
# INFO:root:tot event weight 1197.0645987490143
#
# INFO:root:Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 4871 events
# INFO:root:tot event weight 15.210369945368548
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-50To100 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 1632 events
# INFO:root:tot event weight 195.22249488395653
#
# INFO:root:Finding WW samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 1367 events
# INFO:root:tot event weight 168.3075012581141
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-250To400 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 369409 events
# INFO:root:tot event weight 1684.3079718996246
#
# INFO:root:Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 3809 events
# INFO:root:tot event weight 111.48047527604412
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 65972 events
# INFO:root:tot event weight 1789.3108616479235
#
# INFO:root:Finding ZJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 39 events
# INFO:root:tot event weight 14.861265206084063
#
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 85 events
# INFO:root:tot event weight 21.49617884012242
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 725 events
# INFO:root:tot event weight 46.82757055827781
#
# INFO:root:Finding WJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 405 events
# INFO:root:tot event weight 41.181652778051756
#
# INFO:root:Finding ZJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 212 events
# INFO:root:tot event weight 20.7494829556611
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-400To650 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 112129 events
# INFO:root:tot event weight 429.27862431187907
#
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 32347 events
# INFO:root:tot event weight 3736.554765597907
#
# INFO:root:Finding WJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 226 events
# INFO:root:tot event weight 42.42586624867034
#
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 24856 events
# INFO:root:tot event weight 6.146684033681111
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Will fill the ttH dataframe with the remaining 6399 events
# INFO:root:tot event weight 9.351681286007413
#
# INFO:root:Finding ZJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 315 events
# INFO:root:tot event weight 18.317010675424317
#
# INFO:root:Finding GluGluZH_HToWW_M-125_TuneCP5_13TeV-powheg-pythia8 samples and should combine them under ZH
# INFO:root:Will fill the ZH dataframe with the remaining 5015 events
# INFO:root:tot event weight 0.056161044072942416
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-0To50 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 402 events
# INFO:root:tot event weight 107.92428483330899
#
# INFO:root:Finding WJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 35 events
# INFO:root:tot event weight 51.85003124138465
#
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 12162 events
# INFO:root:tot event weight 6190.985722432472
#
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:Will fill the ZH dataframe with the remaining 3939 events
# INFO:root:tot event weight 1.705975574509082
#
# INFO:root:Finding WZ samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 672 events
# INFO:root:tot event weight 68.66395818779549
#
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:Will fill the VBF dataframe with the remaining 1132 events
# INFO:root:tot event weight 7.920334525941993
#
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:Finding SingleMuon_Run2016H samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 25175 events
# INFO:root:tot event weight 25175.0
#
# INFO:root:Finding SingleMuon_Run2016F samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 1201 events
# INFO:root:tot event weight 1201.0
#
# INFO:root:Finding SingleMuon_Run2016G samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 22084 events
# INFO:root:tot event weight 22084.0
#
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Will fill the WH dataframe with the remaining 1575 events
# INFO:root:tot event weight 1.461320629576111
#
# INFO:root:Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 62782 events
# INFO:root:tot event weight 3566.487465493327
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 426909 events
# INFO:root:tot event weight 18904.54300826934
#
# INFO:root:Finding SingleElectron_Run2016G samples and should combine them under Data
# INFO:root:Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 18024 events
# INFO:root:tot event weight 416.6791548347558
#
# INFO:root:Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 92 events
# INFO:root:tot event weight 0.6131757762581929
#
# INFO:root:Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 91268 events
# INFO:root:tot event weight 1132.5031351295816
#
# INFO:root:Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 5582 events
# ...
# INFO:root:Finding SingleMuon_Run2016F_HIPM samples and should combine them under Data
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Will fill the WH dataframe with the remaining 1871 events
# INFO:root:tot event weight 2.2520914843335937
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-100To250 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 29709 events
# INFO:root:tot event weight 1299.7254999623638
#
# INFO:root:Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 4584 events
# INFO:root:tot event weight 16.342963167151225
#
# INFO:root:Finding SingleElectron_Run2016F_HIPM samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 5658 events
# INFO:root:tot event weight 5658.0
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-50To100 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 1663 events
# INFO:root:tot event weight 233.3779847159708
#
# INFO:root:Finding WW samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 1157 events
# INFO:root:tot event weight 179.87556048997786
#
# INFO:root:Finding SingleMuon_Run2016D_HIPM samples and should combine them under Data
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-250To400 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 384630 events
# INFO:root:tot event weight 1904.4272122713855
#
# INFO:root:Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 3763 events
# INFO:root:tot event weight 124.84618397699583
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 58556 events
# INFO:root:tot event weight 1911.9373727971654
#
# INFO:root:Finding SingleElectron_Run2016E_HIPM samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 8915 events
# INFO:root:tot event weight 8915.0
#
# INFO:root:Finding ZJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 48 events
# INFO:root:tot event weight 14.284770019172196
#
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 119 events
# INFO:root:tot event weight 27.761318929516833
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 818 events
# INFO:root:tot event weight 45.16209335685002
#
# INFO:root:Finding SingleElectron_Run2016D_HIPM samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 9499 events
# INFO:root:tot event weight 9499.0
#
# INFO:root:Finding WJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 543 events
# INFO:root:tot event weight 39.452733851065545
#
# INFO:root:Finding ZJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 180 events
# INFO:root:tot event weight 17.41616297055893
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-400To650 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 119545 events
# INFO:root:tot event weight 483.6415107877603
#
# INFO:root:Finding SingleMuon_Run2016B_ver2_HIPM samples and should combine them under Data
# INFO:root:Finding SingleMuon_Run2016E_HIPM samples and should combine them under Data
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 32368 events
# INFO:root:tot event weight 4112.910735030609
#
# INFO:root:Finding SingleElectron_Run2016C_HIPM samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 5696 events
# INFO:root:tot event weight 5696.0
#
# INFO:root:Finding WJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 364 events
# INFO:root:tot event weight 50.86775833254061
#
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 27093 events
# INFO:root:tot event weight 6.536815278638946
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Will fill the ttH dataframe with the remaining 5370 events
# INFO:root:tot event weight 10.061017910584688
#
# INFO:root:Finding ZJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 172 events
# INFO:root:tot event weight 14.563782306067374
#
# INFO:root:Finding GluGluZH_HToWW_M-125_TuneCP5_13TeV-powheg-pythia8 samples and should combine them under ZH
# INFO:root:Will fill the ZH dataframe with the remaining 5480 events
# INFO:root:tot event weight 0.05842716729677739
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-0To50 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 386 events
# INFO:root:tot event weight 94.2691210517655
#
# INFO:root:Finding WJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 48 events
# INFO:root:tot event weight 41.19028697483272
#
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 13089 events
# INFO:root:tot event weight 6517.213701492647
#
# INFO:root:Finding SingleMuon_Run2016C_HIPM samples and should combine them under Data
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:Will fill the ZH dataframe with the remaining 4220 events
# INFO:root:tot event weight 1.862077265577437
#
# INFO:root:Finding WZ samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 687 events
# INFO:root:tot event weight 73.36362033498504
#
# INFO:root:Finding SingleElectron_Run2016B_ver2_HIPM samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 13459 events
# INFO:root:tot event weight 13459.0
#
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:Will fill the VBF dataframe with the remaining 860 events
# INFO:root:tot event weight 9.831317405229466
#
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 19 events
# INFO:root:tot event weight 29.16198361066045
#
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Will fill the WH dataframe with the remaining 2079 events
# INFO:root:tot event weight 1.5592559300644435
#
# INFO:root:Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 77194 events
# INFO:root:tot event weight 3980.686018901937
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 400063 events
# INFO:root:tot event weight 20666.79047196468
#
# INFO:root:Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 14713 events
# INFO:root:tot event weight 441.5973565937305
#
# INFO:root:Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 93 events
# INFO:root:tot event weight 0.8996340531815487
#
# INFO:root:Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 89879 events
# INFO:root:tot event weight 1267.681297254617
#
# INFO:root:Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 6299 events
# INFO:root:tot event weight 3044.913847412983
#
# INFO:root:Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 1735 events
# INFO:root:tot event weight 447.65424629762356
#
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:Will fill the ggF dataframe with the remaining 3790 events
# INFO:root:tot event weight 25.535340721962413
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-650ToInf samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 59042 events
# INFO:root:tot event weight 22.388234644241667
#
# INFO:root:Finding WJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 1745 events
# INFO:root:tot event weight 445.7561608012769
#
# INFO:root:Finding ZJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding SingleMuon_Run2016F_HIPM samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 7245 events
# INFO:root:tot event weight 7245.0
#
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Will fill the WH dataframe with the remaining 2638 events
# INFO:root:tot event weight 3.1573676369138655
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-100To250 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 19041 events
# INFO:root:tot event weight 864.295842859952
#
# INFO:root:Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 7282 events
# INFO:root:tot event weight 25.79266916487618
#
# INFO:root:Finding SingleElectron_Run2016F_HIPM samples and should combine them under Data
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-50To100 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 2058 events
# INFO:root:tot event weight 256.1751243418308
#
# INFO:root:Finding WW samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 1332 events
# INFO:root:tot event weight 206.715688953896
#
# INFO:root:Finding SingleMuon_Run2016D_HIPM samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 11331 events
# INFO:root:tot event weight 11331.0
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-250To400 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 86587 events
# INFO:root:tot event weight 417.8388037717471
#
# INFO:root:Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 6161 events
# INFO:root:tot event weight 194.83731136781682
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 53014 events
# INFO:root:tot event weight 1721.2802719345718
#
# INFO:root:Finding SingleElectron_Run2016E_HIPM samples and should combine them under Data
# INFO:root:Finding ZJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 66 events
# INFO:root:tot event weight 20.184655542104554
#
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 50 events
# INFO:root:tot event weight 12.366942412964107
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 3706 events
# INFO:root:tot event weight 204.04113871032746
#
# INFO:root:Finding SingleElectron_Run2016D_HIPM samples and should combine them under Data
# INFO:root:Finding WJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 912 events
# INFO:root:tot event weight 62.401427819717895
#
# INFO:root:Finding ZJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 567 events
# INFO:root:tot event weight 53.40089130678109
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-400To650 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 27428 events
# INFO:root:tot event weight 109.32226570780152
#
# INFO:root:Finding SingleMuon_Run2016B_ver2_HIPM samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 15726 events
# INFO:root:tot event weight 15726.0
#
# INFO:root:Finding SingleMuon_Run2016E_HIPM samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 10634 events
# INFO:root:tot event weight 10634.0
#
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 47533 events
# INFO:root:tot event weight 6055.73584856738
#
# INFO:root:Finding SingleElectron_Run2016C_HIPM samples and should combine them under Data
# INFO:root:Finding WJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 386 events
# INFO:root:tot event weight 52.59580550732363
#
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 42508 events
# INFO:root:tot event weight 10.29548576175899
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Will fill the ttH dataframe with the remaining 5830 events
# INFO:root:tot event weight 10.818181787107465
#
# INFO:root:Finding ZJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 814 events
# INFO:root:tot event weight 65.65610060496687
#
# INFO:root:Finding GluGluZH_HToWW_M-125_TuneCP5_13TeV-powheg-pythia8 samples and should combine them under ZH
# INFO:root:Will fill the ZH dataframe with the remaining 6612 events
# INFO:root:tot event weight 0.07021342328580049
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-0To50 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 360 events
# INFO:root:tot event weight 87.68892858949958
#
# INFO:root:Finding WJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 28 events
# INFO:root:tot event weight 24.11872675887311
#
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 17843 events
# INFO:root:tot event weight 8922.883722603197
#
# INFO:root:Finding SingleMuon_Run2016C_HIPM samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 6972 events
# INFO:root:tot event weight 6972.0
#
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:Will fill the ZH dataframe with the remaining 5636 events
# INFO:root:tot event weight 2.4633688319996816
#
# INFO:root:Finding WZ samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 476 events
# INFO:root:tot event weight 51.23189956809631
#
# INFO:root:Finding SingleElectron_Run2016B_ver2_HIPM samples and should combine them under Data

# %%
# for top pt reweighting
for year in years:
    out = make_events_dict([year], channels, f"../eos/June19_topptreweighting_{year}", ["TTbar"], presel)
    for ch in channels:
        events_dict[year][ch]["TTbar"] = out[year][ch]["TTbar"]    
        
        events_dict[year][ch]["TTbar"]["event_weight"] *= events_dict[year][ch]["TTbar"]["top_reweighting"]
# Out:
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 356607 events
# INFO:root:tot event weight 58101.02961883718
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 128508 events
# INFO:root:tot event weight 6441.929508899041
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 652 events
# INFO:root:tot event weight 144.6379840524565
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 402523 events
# INFO:root:tot event weight 66392.48220666483
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 109129 events
# INFO:root:tot event weight 5546.1726037587905
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 3327 events
# INFO:root:tot event weight 731.6849923754332
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 359402 events
# INFO:root:tot event weight 42484.01735364143
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 137227 events
# INFO:root:tot event weight 4804.0749060672215
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 662 events
# INFO:root:tot event weight 97.57108153425844
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 412828 events
# INFO:root:tot event weight 48576.268338104644
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 116106 events
# INFO:root:tot event weight 3999.3481376684326
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 3464 events
# INFO:root:tot event weight 499.91235167797913
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 357653 events
# INFO:root:tot event weight 16195.568428084447
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 65972 events
# INFO:root:tot event weight 1789.3108616479235
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 725 events
# INFO:root:tot event weight 46.82757055827781
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 426909 events
# INFO:root:tot event weight 18904.54300826934
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 58417 events
# INFO:root:tot event weight 1552.197287788421
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 3281 events
# INFO:root:tot event weight 198.64533251951588
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 330497 events
# INFO:root:tot event weight 17212.908136298673
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 58556 events
# INFO:root:tot event weight 1911.9373727971654
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 818 events
# INFO:root:tot event weight 45.16209335685002
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 400063 events
# INFO:root:tot event weight 20666.79047196468
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 53014 events
# INFO:root:tot event weight 1721.2802719345718
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 3706 events
# INFO:root:tot event weight 204.04113871032746

# %%
# for ttH
for year in years:
    out = make_events_dict([year], channels, f"../eos/June24_ttH_{year}", ["ttH"], presel)
    for ch in channels:
        events_dict[year][ch]["ttH"] = out[year][ch]["ttH"]
# Out:
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Will fill the ttH dataframe with the remaining 5879 events
# INFO:root:tot event weight 28.894488523326892
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Will fill the ttH dataframe with the remaining 5721 events
# INFO:root:tot event weight 27.941044647589177
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Will fill the ttH dataframe with the remaining 15128 events
# INFO:root:tot event weight 20.785803577364916
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Will fill the ttH dataframe with the remaining 14875 events
# INFO:root:tot event weight 20.172903133687527
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Will fill the ttH dataframe with the remaining 6399 events
# INFO:root:tot event weight 7.856841278992003
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Will fill the ttH dataframe with the remaining 6739 events
# INFO:root:tot event weight 7.906434090752869
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Will fill the ttH dataframe with the remaining 5370 events
# INFO:root:tot event weight 8.449854661015376
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Will fill the ttH dataframe with the remaining 5830 events
# INFO:root:tot event weight 9.079147033658778

# %% [markdown]
# # Add the cut to the curflow dict

# %%
presel = {
        "mu": {
            "fj_mass": "fj_mass>40",
            "THWW>0.50": "fj_mass>40 & THWW>0.50",
        },
        "ele": {
            "fj_mass": "fj_mass>40",            
            "THWW>0.50": "fj_mass>40 & THWW>0.50",
        },
}

# %%
for ch in channels:
    for cut, sel in list(presel[ch].items()):
        for sample in samples:
            for year in years:

                df = events_dict[year][ch][sample]
                df = df.query(sel)
                
                w = df["event_weight"]

                cutflows[year][ch][sample][cut] = w.sum()

# %%
cutflows["2016APV"]["mu"]["WJetsLNu"]     # take a quick look
# Out:
# {'sumgenweight': 32148205.541996155,
#  'Trigger': 5052102.989037976,
#  'METFilters': 5049012.531204127,
#  'OneLep': 5031057.850622146,
#  'NoTaus': 4271447.470579825,
#  'AtLeastOneFatJet': 461978.1002925532,
#  'CandidateJetpT': 196124.03115179407,
#  'LepInJet': 68289.06508691012,
#  'JetLepOverlap': 26003.119346261694,
#  'dPhiJetMET': 18333.833322064966,
#  'MET': 16980.930607238028,
#  'fj_mass': 19712.190480170426,
#  'THWW>0.50': 1786.8056123349772}

# %%
cutflows["2016APV"]["ele"]["WJetsLNu"]     # take a quick look
# Out:
# {'sumgenweight': 32241758.10101272,
#  'Trigger': 4454643.38131529,
#  'METFilters': 4451955.991847101,
#  'OneLep': 3062734.5054372367,
#  'NoTaus': 3062734.5054372367,
#  'AtLeastOneFatJet': 364780.748501086,
#  'CandidateJetpT': 153895.86376889877,
#  'LepInJet': 58938.59730123174,
#  'JetLepOverlap': 19206.882023214886,
#  'dPhiJetMET': 13362.535289163337,
#  'MET': 12293.663142455729,
#  'fj_mass': 14469.813211324976,
#  'THWW>0.50': 1028.3379540147976}

# %% [markdown]
# # Combine different channels

# %%
common_cuts = cutflows["2018"]["mu"]["WJetsLNu"]
common_cuts
# Out:
# {'sumgenweight': 98881812.96014196,
#  'Trigger': 15774784.39789099,
#  'METFilters': 15767863.42776784,
#  'OneLep': 15714197.698371835,
#  'NoTaus': 13365974.316493511,
#  'AtLeastOneFatJet': 1419110.9803375734,
#  'CandidateJetpT': 638940.285300165,
#  'LepInJet': 226599.5724394703,
#  'JetLepOverlap': 85527.28589072316,
#  'dPhiJetMET': 59905.32513231152,
#  'MET': 55958.024490644915,
#  'HEMCleaning': 53830.13943811133,
#  'fj_mass': 64916.787913753265,
#  'THWW>0.50': 5889.4662877647515}

# %%
def combine_channels(cutflows):

    # combine both channels
    cutflows_new = {}
    for year in cutflows.keys():
        cutflows_new[year] = {}
        cutflows_new[year]["lep"] = {}
        
        for ch in ["mu", "ele"]:
            for sample in cutflows[year][ch]:
                                
                if sample not in cutflows_new[year]["lep"]:
                    cutflows_new[year]["lep"][sample] = {}
                
                for cut in cutflows[year][ch][sample]:
                    
                    if (year != "2018") and (cut == "HEMCleaning"):
                        continue
                    
                    if cut not in cutflows_new[year]["lep"][sample]:
                        cutflows_new[year]["lep"][sample][cut] = cutflows[year][ch][sample][cut]
                    else:
                        cutflows_new[year]["lep"][sample][cut] += cutflows[year][ch][sample][cut]
        cutflows[year] = {**cutflows[year], **cutflows_new[year]}
        
    return cutflows

# %%
cutflows = combine_channels(cutflows)

# %%
cutflows["2018"].keys()
# Out:
# dict_keys(['ele', 'mu', 'lep'])

# %%
cutflows["2018"]["ele"]["WJetsLNu"]
# Out:
# {'sumgenweight': 98938496.94524625,
#  'Trigger': 13452100.702478617,
#  'METFilters': 13446122.536571965,
#  'OneLep': 10365996.09355191,
#  'NoTaus': 10365996.09355191,
#  'AtLeastOneFatJet': 1175735.568559565,
#  'CandidateJetpT': 527612.6926960349,
#  'LepInJet': 203272.06535077497,
#  'JetLepOverlap': 67484.52509185502,
#  'dPhiJetMET': 46443.27286250808,
#  'MET': 43163.8827737948,
#  'HEMCleaning': 41487.080689958166,
#  'fj_mass': 50050.8234756848,
#  'THWW>0.50': 4000.2243417807776}

# %%
cutflows["2018"]["mu"]["WJetsLNu"]
# Out:
# {'sumgenweight': 98881812.96014196,
#  'Trigger': 15774784.39789099,
#  'METFilters': 15767863.42776784,
#  'OneLep': 15714197.698371835,
#  'NoTaus': 13365974.316493511,
#  'AtLeastOneFatJet': 1419110.9803375734,
#  'CandidateJetpT': 638940.285300165,
#  'LepInJet': 226599.5724394703,
#  'JetLepOverlap': 85527.28589072316,
#  'dPhiJetMET': 59905.32513231152,
#  'MET': 55958.024490644915,
#  'HEMCleaning': 53830.13943811133,
#  'fj_mass': 64916.787913753265,
#  'THWW>0.50': 5889.4662877647515}

# %%
cutflows["2018"]["lep"]["WJetsLNu"]
# Out:
# {'sumgenweight': 197820309.9053882,
#  'Trigger': 29226885.10036961,
#  'METFilters': 29213985.964339804,
#  'OneLep': 26080193.791923746,
#  'NoTaus': 23731970.410045423,
#  'AtLeastOneFatJet': 2594846.548897139,
#  'CandidateJetpT': 1166552.9779961999,
#  'LepInJet': 429871.63779024524,
#  'JetLepOverlap': 153011.81098257817,
#  'dPhiJetMET': 106348.5979948196,
#  'MET': 99121.90726443971,
#  'HEMCleaning': 95317.22012806949,
#  'fj_mass': 114967.61138943807,
#  'THWW>0.50': 9889.69062954553}

# %% [markdown]
# # Combine different years

# %%
def combine_years(cutflows):
    """Will remove the HEM cleaning cutflow from 2018 first."""
    
    whatever_year = list(cutflows.keys())[0]
    channels = cutflows[whatever_year].keys()
    
    # combine all years
    cutflows_new = {}
    cutflows_new["Run2"] = {}
    
    for ch in channels:
        cutflows_new["Run2"][ch] = {}
        
        for year in cutflows:
            for sample in cutflows[year][ch]:
                
                if sample not in cutflows_new["Run2"][ch]:
                    cutflows_new["Run2"][ch][sample] = {}

                for cut in cutflows[year][ch][sample]:
                    if "HEM" in cut:
                        continue
                    if cut not in cutflows_new["Run2"][ch][sample]:
                        cutflows_new["Run2"][ch][sample][cut] = cutflows[year][ch][sample][cut]
                    else:
                        cutflows_new["Run2"][ch][sample][cut] += cutflows[year][ch][sample][cut]

    cutflows = {**cutflows, **cutflows_new}

    return cutflows

# %%
cutflows = combine_years(cutflows)

# %%
cutflows["2016"]["ele"].keys()
# Out:
# dict_keys(['VBF', 'WJetsLNu', 'WH', 'TTbar', 'Data', 'SingleTop', 'ggF', 'DYJets', 'Diboson', 'WZQQ', 'ttH', 'ZH'])

# %%
cutflows.keys()
# Out:
# dict_keys(['2018', '2017', '2016', '2016APV', 'Run2'])

# %%
cutflows["Run2"].keys()
# Out:
# dict_keys(['ele', 'mu', 'lep'])

# %% [markdown]
# # Combine non-dominant backgrounds

# %%
# combine non-dominant backgrounds under others
dominant_bkgs = ["WJetsLNu", "TTbar"]
signals = ["ggF", "VH", "WH", "ZH", "ttH"]

for year in cutflows:
    for ch in cutflows[year]:
        cutflows[year][ch]["Others"] = dict.fromkeys(cutflows[year][ch]["WJetsLNu"], 0)
        for sample in cutflows[year][ch]:
            if sample == "Data":
                continue
            if sample not in signals+dominant_bkgs:
                for cut in cutflows[year][ch][sample]:
                    cutflows[year][ch]["Others"][cut] += cutflows[year][ch][sample][cut]

# %%
cutflows["2018"]["ele"].keys()
# Out:
# dict_keys(['VBF', 'WJetsLNu', 'WH', 'TTbar', 'SingleTop', 'ggF', 'DYJets', 'Data', 'Diboson', 'WZQQ', 'ttH', 'ZH', 'Others'])

# %%
cutflows["2018"]["lep"]["Others"]
# Out:
# {'sumgenweight': 668515574.5433018,
#  'Trigger': 103769656.76601362,
#  'METFilters': 103740200.79278867,
#  'OneLep': 67364162.19056934,
#  'NoTaus': 62798852.69165327,
#  'AtLeastOneFatJet': 1428588.2718346894,
#  'CandidateJetpT': 629382.4591807507,
#  'LepInJet': 325756.18353619706,
#  'JetLepOverlap': 136762.9796512334,
#  'dPhiJetMET': 80830.95972504909,
#  'MET': 69526.14957935995,
#  'HEMCleaning': 66447.65557764274,
#  'fj_mass': 55096.4173328926,
#  'THWW>0.50': 2400.17659219509}

# %% [markdown]
# # LateX cutflow table

# %%
cuts = [
    "sumgenweight",
    "Trigger",
    "METFilters",
    "OneLep",        
    "NoTaus",
    "AtLeastOneFatJet",
    "CandidateJetpT",
    "LepInJet",
    "JetLepOverlap",
    "dPhiJetMET",
    "MET",
    "HEMCleaning",
]

for cut in presel["mu"]:
    cuts += [cut]

# %%
cut_to_label = {
    "sumgenweight": "sumgenweight",        
    "HEMCleaning": "HEMCleaning",    
    "Trigger": "Trigger",
    "METFilters": "METFilters",
    "OneLep": "n Leptons = 1",
    "NoTaus": "n Taus = 0",
    "AtLeastOneFatJet": r"n FatJets $>=$ 1",
    "CandidateJetpT": r"j $p_T > 250$GeV",
    "LepInJet": r"$\Delta R(j, \ell) < 0.8$",
    "JetLepOverlap": r"$\Delta R(j, \ell) > 0.03$",
    "dPhiJetMET": r"$\Delta \phi(\mathrm{MET}, j)<1.57$",
    "MET": r"$\mathrm{MET}>20$",
    
    "None": "None",

    "fj_mass": r"j $\mathrm{softdrop} > 40$GeV",
    
    "THWW>0.50": r"$\ensuremath{T_{\text{HWW}}^{\ell\nu qq}} > 0.50$",
}

# %%
parquet_to_latex = {
    "WJetsLNu": "$\PW(\Pell\PGn)$+",
    "TTbar": "\\ttbar",
    "Others": "Other MC",

    "ggF": "ggF",
    "VBF": "VBF",
    "WH": "WH",
    "ZH": "ZH",    
    "ttH": "$t\\bar{t}H$",    
    
    "Data": "Data",
}

def make_latex_cutflow_table(cutflows_dict, year, ch, add_data=False, add_sumgenweight=False):
    """Will use the cutflows dictionary to make the LateX table we have in the AN."""
    
    samples_bkg = ["WJetsLNu", "TTbar", "Others"]
    samples_sig = ["ggF","VBF", "WH", "ZH", "ttH"]

    ### backgrounds
    headers = [parquet_to_latex[s] for s in samples_bkg]
    
    textabular = f"l{'r'*len(headers)}"
    textabular += "|r"
    
    texheader = "\\textbf{Inclusive Selection}" + " & " + " & ".join(headers) + " & Total MC "
    if add_data:
        textabular += "|r"
        texheader += "& Data "
    texheader += "\\\\"
    texdata = "\\hline\n"
    
    data = dict()
    
    for cut in cuts: 
        if (year != "2018") and (cut == "HEMCleaning"):
            continue
            
        if not add_sumgenweight and cut == "sumgenweight":
            continue
    
        data[cut] = []

        for sample in samples_bkg:            
            data[cut].append(round(cutflows_dict[year][ch][sample][cut]))
            
        totalmc = 0
        for sample in (samples_bkg + samples_sig):
            totalmc += round(cutflows_dict[year][ch][sample][cut])
            
        data[cut].append(totalmc)
        
        if add_data:
            data[cut].append(round(cutflows_dict[year][ch]["Data"][cut]))

    for label in data:
        if label == "z":
            texdata += "\\hline\n"
        texdata += f"{cut_to_label[label]} & {' & '.join(map(str,data[label]))} \\\\\n"
        
    texdata += "\\hline\n"    

    ### signal
    headers2 = [parquet_to_latex[s] for s in samples_sig]
    texheader2 = " & " + " & ".join(headers2) + "\\\\"
    texdata2 = "\\hline\n"

    textabular2 = f"l{'r'*len(headers2)}"
    
    data = dict()
    for cut in cuts:
        if (year != "2018") and (cut == "HEMCleaning"):
            continue
            
        data[cut] = []

        for sample in samples_sig:
            data[cut].append(round(cutflows_dict[year][ch][sample][cut]))
        
    for label in data:
        if label == "z":
            texdata += "\\hline\n"
        texdata2 += f"{cut_to_label[label]} & {' & '.join(map(str,data[label]))} \\\\\n"    

    # make table
    print("\\begin{table}[!htp]")
    print("\\begin{center}")
    
    print("\\begin{tabular}{"+textabular+"}")
    print(texheader)
    print(texdata,end="")
    print("\\end{tabular}")

    print("\\begin{tabular}{"+textabular2+"}")
    print(texheader2)
    print(texdata2,end="")
    print("\\end{tabular}")
    
    
    if ch == "lep":
        print("\\caption{Event yield of " + year + " Monte Carlo samples normalized to " + str(round(get_lumi([year], [ch]))) + "\\fbinv.}")        
    else:
        print("\\caption{Event yield of " + ch + " channel " + year + " Monte Carlo samples normalized to " + str(round(get_lumi([year], [ch]))) + "\\fbinv.}")
        
    print("\\label{sel-tab-cutflow" + year + "}")
    print("\\end{center}")
    print("\\end{table}")

# %%
make_latex_cutflow_table(cutflows, "2018", "lep", add_data=True, add_sumgenweight=True)
# Out:
# \begin{table}[!htp]
# \begin{center}
# \begin{tabular}{lrrr|r|r}
# \textbf{Inclusive Selection} & $\PW(\Pell\PGn)$+ & \ttbar & Other MC & Total MC & Data \\
# \hline
# sumgenweight & 197820310 & 99476871 & 668515575 & 966003284 & 2276244440 \\
# Trigger & 29226885 & 10530862 & 103769657 & 143544005 & 1174738710 \\
# METFilters & 29213986 & 10525258 & 103740201 & 143496032 & 1173476723 \\
# n Leptons = 1 & 26080194 & 8802028 & 67364162 & 102259654 & 656865738 \\
# n Taus = 0 & 23731970 & 7031360 & 62798853 & 93572829 & 632124064 \\
# n FatJets $>=$ 1 & 2594847 & 1264303 & 1428588 & 5290141 & 6978889 \\
# j $p_T > 250$GeV & 1166553 & 642826 & 629382 & 2440080 & 2825338 \\
# $\Delta R(j, \ell) < 0.8$ & 429872 & 283927 & 325756 & 1040247 & 1392226 \\
# $\Delta R(j, \ell) > 0.03$ & 153012 & 245916 & 136763 & 536313 & 640994 \\
# $\Delta \phi(\mathrm{MET}, j)<1.57$ & 106349 & 155612 & 80831 & 343214 & 359014 \\
# $\mathrm{MET}>20$ & 99122 & 146620 & 69526 & 315661 & 326733 \\
# HEMCleaning & 95317 & 140577 & 66448 & 302665 & 298219 \\
# j $\mathrm{softdrop} > 40$GeV & 114968 & 116851 & 55096 & 287164 & 250305 \\
# $\ensuremath{T_{\text{HWW}}^{\ell\nu qq}} > 0.50$ & 9890 & 3584 & 2400 & 15995 & 14540 \\
# \hline
# \end{tabular}
# \begin{tabular}{lrrrrr}
#  & ggF & VBF & WH & ZH & $t\bar{t}H$\\
# \hline
# sumgenweight & 12053 & 96661 & 36203 & 20484 & 25127 \\
# Trigger & 1273 & 6192 & 3766 & 1674 & 3696 \\
# METFilters & 1271 & 6187 & 3764 & 1673 & 3692 \\
# n Leptons = 1 & 1032 & 5191 & 3026 & 1228 & 2793 \\
# n Taus = 0 & 894 & 4374 & 2435 & 1011 & 1932 \\
# n FatJets $>=$ 1 & 738 & 424 & 273 & 110 & 858 \\
# j $p_T > 250$GeV & 416 & 194 & 142 & 59 & 508 \\
# $\Delta R(j, \ell) < 0.8$ & 245 & 112 & 67 & 34 & 234 \\
# $\Delta R(j, \ell) > 0.03$ & 229 & 104 & 45 & 31 & 213 \\
# $\Delta \phi(\mathrm{MET}, j)<1.57$ & 165 & 75 & 31 & 17 & 134 \\
# $\mathrm{MET}>20$ & 151 & 69 & 29 & 16 & 128 \\
# HEMCleaning & 146 & 66 & 27 & 15 & 69 \\
# j $\mathrm{softdrop} > 40$GeV & 117 & 44 & 22 & 13 & 53 \\
# $\ensuremath{T_{\text{HWW}}^{\ell\nu qq}} > 0.50$ & 67 & 25 & 12 & 6 & 11 \\
# \end{tabular}
# \caption{Event yield of 2018 Monte Carlo samples normalized to 60\fbinv.}
# \label{sel-tab-cutflow2018}
# \end{center}
# \end{table}
