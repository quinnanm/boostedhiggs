# %% [markdown]
# # Compute the LateX cutflow tables
# - Will load the pkl files that contain the cutflows and the sumgenweight
# - Will scale the events by the cross section
# - Will save the yields in a dictionnary called ```cutflows -> Dict()```
# - Will make the LateX table using the function ```make_composition_table()```

# %%
import glob
import json
import os
import pickle as pkl
import sys

import hist as hist2
import matplotlib.pyplot as plt
import mplhep as hep
import numpy as np
import pandas as pd
import pyarrow
import pyarrow.parquet as pq
import yaml
from scipy.special import softmax
from sklearn.metrics import auc, roc_curve

sys.path
sys.path.append("../python/")

import utils

plt.style.use(hep.style.CMS)
plt.rcParams.update({"font.size": 20})

pd.options.mode.chained_assignment = None

import glob
import os
import json
import pickle
import yaml
import math

import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None
import pyarrow.parquet as pq
from sklearn.metrics import auc, roc_curve
from scipy.special import softmax

import hist as hist2
import matplotlib.pyplot as plt
import mplhep as hep

plt.style.use(hep.style.CMS)

import sys
sys.path
sys.path.append("../python/")

import utils

plt.rcParams.update({"font.size": 20})

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# get lumi
with open("../fileset/luminosity.json") as f:
    luminosity = json.load(f)
    
luminosity
# Out:
# {'ele': {'Run2': 137640.0,
#   '2016APV': 19492.72,
#   '2016': 16809.96,
#   '2017': 41476.02,
#   '2018': 59816.23},
#  'mu': {'Run2': 137640.0,
#   '2016APV': 19436.16,
#   '2016': 16810.81,
#   '2017': 41475.26,
#   '2018': 59781.96},
#  'lep': {'Run2': 137640.0,
#   '2016APV': 19436.16,
#   '2016': 16810.81,
#   '2017': 41475.26,
#   '2018': 59781.96},
#  'had': {'Run2': 137640.0,
#   '2016APV': 19436.16,
#   '2016': 16810.81,
#   '2017': 41475.26,
#   '2018': 59781.96}}

# %%
def get_lumi(years, channels):
    lum_ = 0
    for year in years:
        lum = 0
        for ch in channels:
            lum += luminosity[ch][year] / 1000.0

        lum_ += lum / len(channels)    
    return lum_

# %% [markdown]
# # Read cutflows from pkl

# %%
"""
For ../eos/Dec7_2016

cuts["mu"] += [
        "Trigger",
        "METFilters",
        "OneLep",
        "NoTaus",
        "LepIso",
        "LepMiniIso",
        "OneCandidateJet",
        "CandidateJetpT",
        "LepInJet",
        "JetLepOverlap",
        "dPhiJetMETCut",
]
cuts["ele"] += [
        "Trigger",
        "METFilters",
        "OneLep",
        "NoTaus",
        "LepIso",
        "OneCandidateJet",
        "CandidateJetpT",
        "LepInJet",
        "JetLepOverlap",
        "dPhiJetMETCut",
]
"""
# Out:
# '\nFor ../eos/Dec7_2016\n\ncuts["mu"] += [\n        "Trigger",\n        "METFilters",\n        "OneLep",\n        "NoTaus",\n        "LepIso",\n        "LepMiniIso",\n        "OneCandidateJet",\n        "CandidateJetpT",\n        "LepInJet",\n        "JetLepOverlap",\n        "dPhiJetMETCut",\n]\ncuts["ele"] += [\n        "Trigger",\n        "METFilters",\n        "OneLep",\n        "NoTaus",\n        "LepIso",\n        "OneCandidateJet",\n        "CandidateJetpT",\n        "LepInJet",\n        "JetLepOverlap",\n        "dPhiJetMETCut",\n]\n'

# %%
def get_sum_sumgenweight(pkl_files, year, sample):
    """Load and sum the sumgenweight of each pkl file."""
    
    sum_sumgenweight = 0
    for ifile in pkl_files:
        with open(ifile, "rb") as f:
            metadata = pkl.load(f)            
        sum_sumgenweight = sum_sumgenweight + metadata[sample][year]["sumgenweight"]

    return sum_sumgenweight


def get_xsecweight(pkl_files, year, ch, sample, is_data):
    
    if not is_data:
        # find xsection
        f = open("../fileset/xsec_pfnano.json")
        xsec = json.load(f)
        f.close()
        try:
            xsec = eval(str((xsec[sample])))
        except ValueError:
            print(f"sample {sample} doesn't have xsecs defined in xsec_pfnano.json so will skip it")
            return None

        # get overall weighting of events.. each event has a genweight...
        # sumgenweight sums over events in a chunk... sum_sumgenweight sums over chunks
        xsec_weight = (xsec * luminosity[ch][year]) / get_sum_sumgenweight(pkl_files, year, sample)
    else:
        xsec_weight = 1
    return xsec_weight

def get_cutflow(pkl_files, year, ch, sample, is_data):
    """
    Get cutflow from metadata but multiply by xsec-weight
    """
    xsec_weight = get_xsecweight(pkl_files, year, ch, sample, is_data)

    cuts = {
        "mu": ["sumgenweight"],
        "ele": ["sumgenweight"],
    }
        
    cuts["mu"] += [
        "Trigger",
        "METFilters",
        "OneLep",
        "LepMiniIso",        
        "NoTaus",
        "AtLeastOneFatJet",
        "CandidateJetpT",
        "LepInJet",
        "JetLepOverlap",
        "dPhiJetMET",
        "MET",        
    ]
    cuts["ele"] += [
        "Trigger",
        "METFilters",
        "OneLep",
        "NoTaus",
        "AtLeastOneFatJet",
        "CandidateJetpT",
        "LepInJet",
        "JetLepOverlap",
        "dPhiJetMET",
        "MET",
    ]
        
    if year == "2018":
        cuts["mu"] += ["HEMCleaning"]
        cuts["ele"] += ["HEMCleaning"]
        
    evyield = dict.fromkeys(cuts[ch], 0)
    for ik, pkl_file in enumerate(pkl_files):
        with open(pkl_file, "rb") as f:
            metadata = pkl.load(f)
            
        cutflows = metadata[sample][year]["cutflows"][ch]

        for key in evyield.keys():

            if key == "sumgenweight":
                evyield[key] += metadata[sample][year][key] * xsec_weight
            else:
                
#                 try:
                evyield[key] += cutflows[key] * xsec_weight
#                 except KeyError:
#                     evyield[key] += cutflows["AtLeastOneFatJet"] * xsec_weight            
    return evyield

# %%
! ls ../eos/Feb9_2018/WJetsToLNu_HT-100To200/outfiles/0-10.pkl
# Out:
# ../eos/Feb9_2018/WJetsToLNu_HT-100To200/outfiles/0-10.pkl

# %%
with open("../eos/Feb9_2018/QCD_Pt_170to300/outfiles/0-10.pkl", "rb") as f:
    metadata = pkl.load(f)
metadata
# Out:
# {'QCD_Pt_170to300': {'mc': 48,
#   '2018': {'sumgenweight': 485000.0,
#    'sumlheweight': {},
#    'sumpdfweight': {},
#    'cutflows': {'ele': {'Trigger': 2652.0,
#      'METFilters': 2644.0,
#      'OneLep': 55.0,
#      'NoTaus': 55.0,
#      'AtLeastOneFatJet': 45.0,
#      'CandidateJetpT': 22.0,
#      'LepInJet': 15.0,
#      'JetLepOverlap': 4.0,
#      'dPhiJetMET': 2.0,
#      'MET': 2.0,
#      'HEMCleaning': 2.0,
#      'single_weight_pileup': 2.0},
#     'mu': {'Trigger': 1452.0,
#      'METFilters': 1450.0,
#      'OneLep': 458.0,
#      'LepMiniIso': 46.0,
#      'NoTaus': 43.0,
#      'AtLeastOneFatJet': 29.0,
#      'CandidateJetpT': 11.0,
#      'LepInJet': 5.0,
#      'JetLepOverlap': 3.0,
#      'dPhiJetMET': 3.0,
#      'MET': 3.0,
#      'HEMCleaning': 3.0,
#      'single_weight_pileup': 3.0}}}}}

# %%
with open("../eos/Feb9_2018/WJetsToLNu_HT-100To200/outfiles/0-10.pkl", "rb") as f:
    metadata = pkl.load(f)
metadata
# Out:
# {'WJetsToLNu_HT-100To200': {'mc': 89,
#   '2018': {'sumgenweight': 860209.0,
#    'sumlheweight': {0: 893759.06,
#     1: 894174.7,
#     2: 888283.2,
#     3: 859625.5,
#     4: 860209.0,
#     5: 854675.94,
#     6: 831615.4,
#     7: 832338.2,
#     8: 827100.1},
#    'sumpdfweight': {},
#    'cutflows': {'ele': {'Trigger': 112451.0,
#      'METFilters': 112422.0,
#      'OneLep': 84815.0,
#      'NoTaus': 84815.0,
#      'AtLeastOneFatJet': 1026.0,
#      'CandidateJetpT': 30.0,
#      'LepInJet': 19.0,
#      'JetLepOverlap': 7.0,
#      'dPhiJetMET': 1.0,
#      'MET': 1.0,
#      'HEMCleaning': 1.0,
#      'single_weight_pileup': 1.0},
#     'mu': {'Trigger': 155966.0,
#      'METFilters': 155920.0,
#      'OneLep': 129309.0,
#      'LepMiniIso': 128996.0,
#      'NoTaus': 109515.0,
#      'AtLeastOneFatJet': 1301.0,
#      'CandidateJetpT': 58.0,
#      'LepInJet': 39.0,
#      'JetLepOverlap': 10.0,
#      'dPhiJetMET': 1.0,
#      'MET': 1.0,
#      'HEMCleaning': 1.0,
#      'single_weight_pileup': 1.0}}}}}

# %% [markdown]
# # Adding a cut from the parquets

# %%
### This is your configuration. specefy which channels, years, samples, and directory of pkl files to use.
channels = ["ele", "mu"]
years = ["2018", "2017", "2016", "2016APV"]

samples = [
    "ggF", 
    "VH",
    "VBF",
    "ttH",
    "QCD",
    "DYJets",
    "WJetsLNu",
    "WZQQ",
    "TTbar",
    "SingleTop",
    "Diboson",
    "Data"
]

samples_dir = {
    "2016":    "../eos/Feb9_2016",
    "2016APV": "../eos/Feb9_2016APV",    
    "2017":    "../eos/Feb9_2017",    
    "2018":    "../eos/Feb9_2018",    
}

# %%
cutflows = {}
for year in years:
#     if year != "2016":
#         continue
    print(f"Processing year {year}")
    
    cutflows[year] = {}
    
    for ch in channels:
#         if ch != "mu": 
#             continue
        
        print(f"  {ch} channel")
        cutflows[year][ch] = {}

        condor_dir = os.listdir(samples_dir[year])

        for sample in condor_dir:

            # first: check if the sample is in one of combine_samples_by_name
            sample_to_use = None
            for key in utils.combine_samples_by_name:
                if key in sample:
                    sample_to_use = utils.combine_samples_by_name[key]
                    break

            # second: if not, combine under common label
            if sample_to_use is None:
                for key in utils.combine_samples:
                    if key in sample:
                        sample_to_use = utils.combine_samples[key]
                        break
                    else:
                        sample_to_use = sample

            if sample_to_use not in samples:
                continue

            is_data = False
            if sample_to_use == "Data":
                is_data = True

            out_files = f"{samples_dir[year]}/{sample}/outfiles/"
            pkl_files = glob.glob(f"{out_files}/*.pkl")

            if len(pkl_files) == 0:
                continue

            parquet_files = glob.glob(f"{out_files}/*_{ch}.parquet")
            
            try:
                data = pd.read_parquet(parquet_files)
            except pyarrow.lib.ArrowInvalid:
                # empty parquet because no event passed selection
#                 print(f"No parquet file for {sample}")
                continue

            if len(data) == 0:
#                 print(f"Hi, No parquet file for {sample}")
                continue
    
            if sample_to_use not in cutflows[year][ch].keys():
                cutflows[year][ch][sample_to_use] = get_cutflow(pkl_files, year, ch, sample, is_data)
            else:
                temp = get_cutflow(pkl_files, year, ch, sample, is_data)
                for key in cutflows[year][ch][sample_to_use]:
                    cutflows[year][ch][sample_to_use][key] += temp[key]
            
    print(f"------------------------------------------")
# Out:
# Processing year 2018
#   ele channel
#   mu channel
# ------------------------------------------
# Processing year 2017
#   ele channel
#   mu channel
# ------------------------------------------
# Processing year 2016
#   ele channel
#   mu channel
# ------------------------------------------
# Processing year 2016APV
#   ele channel
#   mu channel
# ------------------------------------------

# %%
samples = cutflows["2017"]["ele"].keys()  # samples
samples
# Out:
# dict_keys(['VBF', 'WJetsLNu', 'TTbar', 'SingleTop', 'ggF', 'Data', 'QCD', 'Diboson', 'ttH'])

# %%
from make_stacked_hists import make_events_dict

presel = {
        "mu": {
            "THWW>0.80": "THWW>0.80",
#             "msoftdrop": "fj_mass>40",
#             "met": "met_pt>35", 0.2
        },
        "ele": {
            "THWW>0.80": "THWW>0.80",
#             "msoftdrop": "fj_mass>40",
#             "met": "met_pt>55",
#             "lepmiso": "(lep_pt<120) | ( (lep_pt>120) & (lep_misolation<0.2))",
        },
}

events_dict = {}
for year in years:
    
    out = make_events_dict([year], channels, samples_dir[year], samples, presel)
    events_dict = {**events_dict, **out}
# Out:
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 1514 events
# INFO:root:Will fill the VBF dataframe with the remaining 472 events
# INFO:root:tot event weight 6.175103436284349
#
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 34 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 1 events
# INFO:root:tot event weight 2.1619583307401005
#
# INFO:root:Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 159607 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 2498 events
# INFO:root:tot event weight 137.70089602705804
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 349864 events
# INFO:root:Will fill the TTbar dataframe with the remaining 2670 events
# INFO:root:tot event weight 437.96058948523125
#
# INFO:root:Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 31158 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 90 events
# INFO:root:tot event weight 2.451903147131022
#
# INFO:root:Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# INFO:root:Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 191329 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 1771 events
# INFO:root:tot event weight 24.681152453396205
#
# INFO:root:Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 18076 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 111 events
# INFO:root:tot event weight 55.7877762822703
#
# INFO:root:Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 5367 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 79 events
# INFO:root:tot event weight 18.288417746437506
#
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 4523 events
# INFO:root:Will fill the ggF dataframe with the remaining 1363 events
# INFO:root:tot event weight 15.83365808263488
#
# INFO:root:Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 5196 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 71 events
# INFO:root:tot event weight 16.924984732585852
#
# INFO:root:Finding QCD_Pt_3200toInf samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 39 events
# INFO:root:Will fill the QCD dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding EGamma_Run2018A samples and should combine them under Data
# INFO:root:Applying THWW>0.80 selection on 31550 events
# INFO:root:Will fill the Data dataframe with the remaining 349 events
# INFO:root:tot event weight 349.0
#
# INFO:root:Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 17372 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 40 events
# INFO:root:tot event weight 0.15414257934453698
#
# INFO:root:Finding QCD_Pt_1800to2400 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 376 events
# INFO:root:Will fill the QCD dataframe with the remaining 1 events
# INFO:root:tot event weight 0.0007791196747029377
#
# INFO:root:Finding SingleMuon_Run2018A samples and should combine them under Data
# INFO:root:Finding WW samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 569 events
# INFO:root:Will fill the Diboson dataframe with the remaining 24 events
# INFO:root:tot event weight 24.86200660660667
#
# INFO:root:Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 12111 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 50 events
# INFO:root:tot event weight 1.4676501055147633
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 125631 events
# INFO:root:Will fill the TTbar dataframe with the remaining 495 events
# INFO:root:tot event weight 25.034725809864085
#
# INFO:root:Finding QCD_Pt_2400to3200 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 222 events
# INFO:root:Will fill the QCD dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 227 events
# INFO:root:Will fill the Diboson dataframe with the remaining 3 events
# INFO:root:tot event weight 0.7883929326548531
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 629 events
# INFO:root:Will fill the TTbar dataframe with the remaining 7 events
# INFO:root:tot event weight 1.6335323467613976
#
# INFO:root:Finding QCD_Pt_1000to1400 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 1090 events
# INFO:root:Will fill the QCD dataframe with the remaining 6 events
# INFO:root:tot event weight 0.13031163756970957
#
# INFO:root:Finding QCD_Pt_600to800 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 841 events
# INFO:root:Will fill the QCD dataframe with the remaining 6 events
# INFO:root:tot event weight 2.8277487326070103
#
# INFO:root:Finding QCD_Pt_300to470 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 503 events
# INFO:root:Will fill the QCD dataframe with the remaining 3 events
# INFO:root:tot event weight 59.04729919774242
#
# INFO:root:Finding QCD_Pt_170to300 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 95 events
# INFO:root:Will fill the QCD dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 105226 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 1995 events
# INFO:root:tot event weight 259.2877229412578
#
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 62868 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 180 events
# INFO:root:tot event weight 0.062241863899262
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 5869 events
# INFO:root:Will fill the ttH dataframe with the remaining 488 events
# INFO:root:tot event weight 2.8781466082373344
#
# INFO:root:Finding EGamma_Run2018C samples and should combine them under Data
# INFO:root:Applying THWW>0.80 selection on 14770 events
# INFO:root:Will fill the Data dataframe with the remaining 156 events
# INFO:root:tot event weight 156.0
#
# INFO:root:Finding EGamma_Run2018D samples and should combine them under Data
# INFO:root:Applying THWW>0.80 selection on 67956 events
# INFO:root:Will fill the Data dataframe with the remaining 791 events
# INFO:root:tot event weight 791.0
#
# INFO:root:Finding QCD_Pt_800to1000 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 963 events
# INFO:root:Will fill the QCD dataframe with the remaining 3 events
# INFO:root:tot event weight 0.232886603917689
#
# INFO:root:Finding EGamma_Run2018B samples and should combine them under Data
# INFO:root:Applying THWW>0.80 selection on 15939 events
# INFO:root:Will fill the Data dataframe with the remaining 176 events
# INFO:root:tot event weight 176.0
#
# INFO:root:Finding SingleMuon_Run2018C samples and should combine them under Data
# INFO:root:Finding SingleMuon_Run2018D samples and should combine them under Data
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 43872 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 769 events
# INFO:root:tot event weight 383.2767140083902
#
# INFO:root:Finding QCD_Pt_470to600 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 503 events
# INFO:root:Will fill the QCD dataframe with the remaining 3 events
# INFO:root:tot event weight 7.628794162726599
#
# INFO:root:Finding WZ samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 601 events
# INFO:root:Will fill the Diboson dataframe with the remaining 6 events
# INFO:root:tot event weight 2.0912234154581655
#
# INFO:root:Finding QCD_Pt_1400to1800 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 707 events
# INFO:root:Will fill the QCD dataframe with the remaining 1 events
# INFO:root:tot event weight 0.0034535473237380255
#
# INFO:root:Finding SingleMuon_Run2018B samples and should combine them under Data
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 2336 events
# INFO:root:Will fill the VBF dataframe with the remaining 779 events
# INFO:root:tot event weight 10.27211516133846
#
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 58 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 210651 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 4461 events
# INFO:root:tot event weight 253.5930395402769
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 366309 events
# INFO:root:Will fill the TTbar dataframe with the remaining 3040 events
# INFO:root:tot event weight 512.6520594788815
#
# INFO:root:Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 44464 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 111 events
# INFO:root:tot event weight 3.1232587928530937
#
# INFO:root:Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 125 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 258011 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 4244 events
# INFO:root:tot event weight 61.22826326477773
#
# INFO:root:Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 20709 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 140 events
# INFO:root:tot event weight 71.66345437984378
#
# INFO:root:Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 5518 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 91 events
# INFO:root:tot event weight 21.90221974611809
#
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 6929 events
# INFO:root:Will fill the ggF dataframe with the remaining 2220 events
# INFO:root:tot event weight 26.22525315861163
#
# INFO:root:Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 5300 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 76 events
# INFO:root:tot event weight 18.6929716218572
#
# INFO:root:Finding QCD_Pt_3200toInf samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 27 events
# INFO:root:Will fill the QCD dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding EGamma_Run2018A samples and should combine them under Data
# INFO:root:Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 22094 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 61 events
# INFO:root:tot event weight 0.2066764006911057
#
# INFO:root:Finding QCD_Pt_1800to2400 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 332 events
# INFO:root:Will fill the QCD dataframe with the remaining 3 events
# INFO:root:tot event weight 0.002824552111612358
#
# INFO:root:Finding SingleMuon_Run2018A samples and should combine them under Data
# INFO:root:Applying THWW>0.80 selection on 33219 events
# INFO:root:Will fill the Data dataframe with the remaining 433 events
# INFO:root:tot event weight 433.0
#
# INFO:root:Finding WW samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 580 events
# INFO:root:Will fill the Diboson dataframe with the remaining 50 events
# INFO:root:tot event weight 52.72599288223789
#
# INFO:root:Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 17238 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 40 events
# INFO:root:tot event weight 1.6006516461721774
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 99305 events
# INFO:root:Will fill the TTbar dataframe with the remaining 424 events
# INFO:root:tot event weight 21.601337408256448
#
# INFO:root:Finding QCD_Pt_2400to3200 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 192 events
# INFO:root:Will fill the QCD dataframe with the remaining 1 events
# INFO:root:tot event weight 0.00010456539048648485
#
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 129 events
# INFO:root:Will fill the Diboson dataframe with the remaining 5 events
# INFO:root:tot event weight 1.3102336386393223
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 1386 events
# INFO:root:Will fill the TTbar dataframe with the remaining 16 events
# INFO:root:tot event weight 3.593248243292888
#
# INFO:root:Finding QCD_Pt_1000to1400 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 1111 events
# INFO:root:Will fill the QCD dataframe with the remaining 4 events
# INFO:root:tot event weight 0.08340227851885937
#
# INFO:root:Finding QCD_Pt_600to800 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 863 events
# INFO:root:Will fill the QCD dataframe with the remaining 7 events
# INFO:root:tot event weight 3.2410291548625105
#
# INFO:root:Finding QCD_Pt_300to470 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 519 events
# INFO:root:Will fill the QCD dataframe with the remaining 1 events
# INFO:root:tot event weight 18.82620975038334
#
# INFO:root:Finding QCD_Pt_170to300 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 63 events
# INFO:root:Will fill the QCD dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 137683 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 2799 events
# INFO:root:tot event weight 373.4337214822873
#
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 84095 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 744 events
# INFO:root:tot event weight 0.2604130856709293
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 5265 events
# INFO:root:Will fill the ttH dataframe with the remaining 543 events
# INFO:root:tot event weight 3.240101078429748
#
# INFO:root:Finding EGamma_Run2018C samples and should combine them under Data
# INFO:root:Finding EGamma_Run2018D samples and should combine them under Data
# INFO:root:Finding QCD_Pt_800to1000 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 992 events
# INFO:root:Will fill the QCD dataframe with the remaining 5 events
# INFO:root:tot event weight 0.3781367418276237
#
# INFO:root:Finding EGamma_Run2018B samples and should combine them under Data
# INFO:root:Finding SingleMuon_Run2018C samples and should combine them under Data
# INFO:root:Applying THWW>0.80 selection on 15318 events
# INFO:root:Will fill the Data dataframe with the remaining 185 events
# INFO:root:tot event weight 185.0
#
# INFO:root:Finding SingleMuon_Run2018D samples and should combine them under Data
# INFO:root:Applying THWW>0.80 selection on 71666 events
# INFO:root:Will fill the Data dataframe with the remaining 952 events
# INFO:root:tot event weight 952.0
#
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 55015 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 926 events
# INFO:root:tot event weight 472.6789789285216
#
# INFO:root:Finding QCD_Pt_470to600 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 513 events
# INFO:root:Will fill the QCD dataframe with the remaining 9 events
# INFO:root:tot event weight 21.418103457912053
#
# INFO:root:Finding WZ samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 424 events
# INFO:root:Will fill the Diboson dataframe with the remaining 20 events
# INFO:root:tot event weight 7.088347208740368
#
# INFO:root:Finding QCD_Pt_1400to1800 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 616 events
# INFO:root:Will fill the QCD dataframe with the remaining 6 events
# INFO:root:tot event weight 0.021479277731272277
#
# INFO:root:Finding SingleMuon_Run2018B samples and should combine them under Data
# INFO:root:Applying THWW>0.80 selection on 16683 events
# INFO:root:Will fill the Data dataframe with the remaining 227 events
# INFO:root:tot event weight 227.0
#
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 1663 events
# INFO:root:Will fill the VBF dataframe with the remaining 547 events
# INFO:root:tot event weight 4.696861253440979
#
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 69 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 111882 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 1770 events
# INFO:root:tot event weight 96.1318155198199
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 355362 events
# INFO:root:Will fill the TTbar dataframe with the remaining 2685 events
# INFO:root:tot event weight 310.8701040078332
#
# INFO:root:Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 23539 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 75 events
# INFO:root:tot event weight 1.9547471243908718
#
# INFO:root:Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 35 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 1 events
# INFO:root:tot event weight 0.01188817758708425
#
# INFO:root:Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 122417 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 1215 events
# INFO:root:tot event weight 18.30081199992576
#
# INFO:root:Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 17205 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 123 events
# INFO:root:tot event weight 52.46959597235144
#
# INFO:root:Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 4028 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 59 events
# INFO:root:tot event weight 13.237529768933085
#
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 4741 events
# INFO:root:Will fill the ggF dataframe with the remaining 1483 events
# INFO:root:tot event weight 11.827494166377425
#
# INFO:root:Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 4009 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 56 events
# INFO:root:tot event weight 12.288184758124583
#
# INFO:root:Finding SingleElectron_Run2017E samples and should combine them under Data
# INFO:root:Applying THWW>0.80 selection on 22127 events
# INFO:root:Will fill the Data dataframe with the remaining 263 events
# INFO:root:tot event weight 263.0
#
# INFO:root:Finding SingleElectron_Run2017B samples and should combine them under Data
# INFO:root:Applying THWW>0.80 selection on 8739 events
# INFO:root:Will fill the Data dataframe with the remaining 67 events
# INFO:root:tot event weight 67.0
#
# INFO:root:Finding QCD_Pt_3200toInf samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 79 events
# INFO:root:Will fill the QCD dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding SingleElectron_Run2017C samples and should combine them under Data
# INFO:root:Applying THWW>0.80 selection on 23575 events
# INFO:root:Will fill the Data dataframe with the remaining 271 events
# INFO:root:tot event weight 271.0
#
# INFO:root:Finding SingleElectron_Run2017D samples and should combine them under Data
# INFO:root:Applying THWW>0.80 selection on 10649 events
# INFO:root:Will fill the Data dataframe with the remaining 134 events
# INFO:root:tot event weight 134.0
#
# INFO:root:Finding SingleMuon_Run2017C samples and should combine them under Data
# INFO:root:Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 12856 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 49 events
# INFO:root:tot event weight 0.15089582650400532
#
# INFO:root:Finding SingleMuon_Run2017D samples and should combine them under Data
# INFO:root:Finding QCD_Pt_1800to2400 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 368 events
# INFO:root:Will fill the QCD dataframe with the remaining 2 events
# INFO:root:tot event weight 0.0012852018982372143
#
# INFO:root:Finding SingleMuon_Run2017E samples and should combine them under Data
# INFO:root:Finding SingleMuon_Run2017B samples and should combine them under Data
# INFO:root:Finding WW samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 876 events
# INFO:root:Will fill the Diboson dataframe with the remaining 38 events
# INFO:root:tot event weight 17.69861894214658
#
# INFO:root:Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 9552 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 30 events
# INFO:root:tot event weight 1.0922823875135348
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 132362 events
# INFO:root:Will fill the TTbar dataframe with the remaining 505 events
# INFO:root:tot event weight 17.042372992583935
#
# INFO:root:Finding QCD_Pt_2400to3200 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 261 events
# INFO:root:Will fill the QCD dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 199 events
# INFO:root:Will fill the Diboson dataframe with the remaining 3 events
# INFO:root:tot event weight 0.7025759274739519
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 644 events
# INFO:root:Will fill the TTbar dataframe with the remaining 12 events
# INFO:root:tot event weight 1.7899743571656284
#
# INFO:root:Finding QCD_Pt_1000to1400 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 1046 events
# INFO:root:Will fill the QCD dataframe with the remaining 3 events
# INFO:root:tot event weight 0.04944967881655228
#
# INFO:root:Finding QCD_Pt_600to800 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 862 events
# INFO:root:Will fill the QCD dataframe with the remaining 3 events
# INFO:root:tot event weight 0.9374732644182744
#
# INFO:root:Finding QCD_Pt_300to470 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 563 events
# INFO:root:Will fill the QCD dataframe with the remaining 7 events
# INFO:root:tot event weight 97.400453302121
#
# INFO:root:Finding QCD_Pt_170to300 samples and should combine them under QCD
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 81980 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 1641 events
# INFO:root:tot event weight 189.40394690514253
#
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 41782 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 100 events
# INFO:root:tot event weight 0.03656165673428133
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 14945 events
# INFO:root:Will fill the ttH dataframe with the remaining 1201 events
# INFO:root:tot event weight 1.9322003575815234
#
# INFO:root:Finding SingleElectron_Run2017F samples and should combine them under Data
# INFO:root:Applying THWW>0.80 selection on 31134 events
# INFO:root:Will fill the Data dataframe with the remaining 370 events
# INFO:root:tot event weight 370.0
#
# INFO:root:Finding QCD_Pt_800to1000 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 898 events
# INFO:root:Will fill the QCD dataframe with the remaining 3 events
# INFO:root:tot event weight 0.15749318787404734
#
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 32684 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 543 events
# INFO:root:tot event weight 261.33248786569595
#
# INFO:root:Finding QCD_Pt_470to600 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 772 events
# INFO:root:Will fill the QCD dataframe with the remaining 4 events
# INFO:root:tot event weight 4.46505899213753
#
# INFO:root:Finding QCD_Pt_1400to1800 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 709 events
# INFO:root:Will fill the QCD dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding SingleMuon_Run2017F samples and should combine them under Data
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 2479 events
# INFO:root:Will fill the VBF dataframe with the remaining 823 events
# INFO:root:tot event weight 6.747568749962209
#
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 79 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 148852 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 3064 events
# INFO:root:tot event weight 167.51474469176915
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 375217 events
# INFO:root:Will fill the TTbar dataframe with the remaining 2917 events
# INFO:root:tot event weight 335.03825668522484
#
# INFO:root:Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 34606 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 86 events
# INFO:root:tot event weight 2.139930183272667
#
# INFO:root:Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 107 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 1 events
# INFO:root:tot event weight 0.01225490210344433
#
# INFO:root:Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 165051 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 2735 events
# INFO:root:tot event weight 42.14391314344968
#
# INFO:root:Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 19527 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 151 events
# INFO:root:tot event weight 65.76173560268512
#
# INFO:root:Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 4057 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 62 events
# INFO:root:tot event weight 13.711308177259646
#
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 7334 events
# INFO:root:Will fill the ggF dataframe with the remaining 2283 events
# INFO:root:tot event weight 17.784992356632713
#
# INFO:root:Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 3944 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 68 events
# INFO:root:tot event weight 14.895132054892482
#
# INFO:root:Finding SingleElectron_Run2017E samples and should combine them under Data
# INFO:root:Finding SingleElectron_Run2017B samples and should combine them under Data
# INFO:root:Finding QCD_Pt_3200toInf samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 48 events
# INFO:root:Will fill the QCD dataframe with the remaining 1 events
# INFO:root:tot event weight 5.368432784360692e-06
#
# INFO:root:Finding SingleElectron_Run2017C samples and should combine them under Data
# INFO:root:Finding SingleElectron_Run2017D samples and should combine them under Data
# INFO:root:Finding SingleMuon_Run2017C samples and should combine them under Data
# INFO:root:Applying THWW>0.80 selection on 25136 events
# INFO:root:Will fill the Data dataframe with the remaining 325 events
# INFO:root:tot event weight 325.0
#
# INFO:root:Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 16447 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 56 events
# INFO:root:tot event weight 0.2272773398402756
#
# INFO:root:Finding SingleMuon_Run2017D samples and should combine them under Data
# INFO:root:Applying THWW>0.80 selection on 11271 events
# INFO:root:Will fill the Data dataframe with the remaining 141 events
# INFO:root:tot event weight 141.0
#
# INFO:root:Finding QCD_Pt_1800to2400 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 328 events
# INFO:root:Will fill the QCD dataframe with the remaining 1 events
# INFO:root:tot event weight 0.0006452755893998451
#
# INFO:root:Finding SingleMuon_Run2017E samples and should combine them under Data
# INFO:root:Applying THWW>0.80 selection on 24145 events
# INFO:root:Will fill the Data dataframe with the remaining 317 events
# INFO:root:tot event weight 317.0
#
# INFO:root:Finding SingleMuon_Run2017B samples and should combine them under Data
# INFO:root:Applying THWW>0.80 selection on 12183 events
# INFO:root:Will fill the Data dataframe with the remaining 165 events
# INFO:root:tot event weight 165.0
#
# INFO:root:Finding WW samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 942 events
# INFO:root:Will fill the Diboson dataframe with the remaining 69 events
# INFO:root:tot event weight 32.874515720335985
#
# INFO:root:Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 13132 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 30 events
# INFO:root:tot event weight 1.023609131482551
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 105329 events
# INFO:root:Will fill the TTbar dataframe with the remaining 421 events
# INFO:root:tot event weight 14.061363261336831
#
# INFO:root:Finding QCD_Pt_2400to3200 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 149 events
# INFO:root:Will fill the QCD dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 89 events
# INFO:root:Will fill the Diboson dataframe with the remaining 3 events
# INFO:root:tot event weight 0.7326810083078061
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 1348 events
# INFO:root:Will fill the TTbar dataframe with the remaining 11 events
# INFO:root:tot event weight 1.6803877556057456
#
# INFO:root:Finding QCD_Pt_1000to1400 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 1145 events
# INFO:root:Will fill the QCD dataframe with the remaining 8 events
# INFO:root:tot event weight 0.12073467727992329
#
# INFO:root:Finding QCD_Pt_600to800 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 949 events
# INFO:root:Will fill the QCD dataframe with the remaining 5 events
# INFO:root:tot event weight 1.623035893467876
#
# INFO:root:Finding QCD_Pt_300to470 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 458 events
# INFO:root:Will fill the QCD dataframe with the remaining 2 events
# INFO:root:tot event weight 26.039066066019018
#
# INFO:root:Finding QCD_Pt_170to300 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 81 events
# INFO:root:Will fill the QCD dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 107655 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 2230 events
# INFO:root:tot event weight 261.29979531791184
#
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 56498 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 472 events
# INFO:root:tot event weight 0.1619133996101132
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 13697 events
# INFO:root:Will fill the ttH dataframe with the remaining 1298 events
# INFO:root:tot event weight 2.0599319914736407
#
# INFO:root:Finding SingleElectron_Run2017F samples and should combine them under Data
# INFO:root:Finding QCD_Pt_800to1000 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 1021 events
# INFO:root:Will fill the QCD dataframe with the remaining 4 events
# INFO:root:tot event weight 0.20878393020195202
#
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 41161 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 715 events
# INFO:root:tot event weight 351.971245390504
#
# INFO:root:Finding QCD_Pt_470to600 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 767 events
# INFO:root:Will fill the QCD dataframe with the remaining 6 events
# INFO:root:tot event weight 6.238960837722133
#
# INFO:root:Finding QCD_Pt_1400to1800 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 651 events
# INFO:root:Will fill the QCD dataframe with the remaining 8 events
# INFO:root:tot event weight 0.019362689738943402
#
# INFO:root:Finding SingleMuon_Run2017F samples and should combine them under Data
# INFO:root:Applying THWW>0.80 selection on 35806 events
# INFO:root:Will fill the Data dataframe with the remaining 509 events
# INFO:root:tot event weight 509.0
#
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 784 events
# INFO:root:Will fill the VBF dataframe with the remaining 233 events
# INFO:root:tot event weight 1.7773436523988708
#
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 16 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding SingleMuon_Run2016H samples and should combine them under Data
# INFO:root:Finding SingleMuon_Run2016F samples and should combine them under Data
# INFO:root:Finding SingleMuon_Run2016G samples and should combine them under Data
# INFO:root:Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 42945 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 597 events
# INFO:root:tot event weight 34.25338488516294
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 353131 events
# INFO:root:Will fill the TTbar dataframe with the remaining 2270 events
# INFO:root:tot event weight 102.46032327742031
#
# INFO:root:Finding SingleElectron_Run2016G samples and should combine them under Data
# INFO:root:Applying THWW>0.80 selection on 17638 events
# INFO:root:Will fill the Data dataframe with the remaining 189 events
# INFO:root:tot event weight 189.0
#
# INFO:root:Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 10797 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 22 events
# INFO:root:tot event weight 0.5405839443356449
#
# INFO:root:Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 17 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 60956 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 481 events
# INFO:root:tot event weight 5.814978745722973
#
# INFO:root:Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 4544 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 30 events
# INFO:root:tot event weight 19.909535408848903
#
# INFO:root:Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 1696 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 22 events
# INFO:root:tot event weight 4.451200060473644
#
# INFO:root:Finding SingleElectron_Run2016H samples and should combine them under Data
# INFO:root:Applying THWW>0.80 selection on 19081 events
# INFO:root:Will fill the Data dataframe with the remaining 193 events
# INFO:root:tot event weight 193.0
#
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 2025 events
# INFO:root:Will fill the ggF dataframe with the remaining 581 events
# INFO:root:tot event weight 4.075615755591655
#
# INFO:root:Finding SingleElectron_Run2016F samples and should combine them under Data
# INFO:root:Applying THWW>0.80 selection on 908 events
# INFO:root:Will fill the Data dataframe with the remaining 9 events
# INFO:root:tot event weight 9.0
#
# INFO:root:Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 1643 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 19 events
# INFO:root:tot event weight 4.075600589485983
#
# ...
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 792 events
# INFO:root:Will fill the TTbar dataframe with the remaining 13 events
# INFO:root:tot event weight 0.5467170283883858
#
# INFO:root:Finding QCD_Pt_1000to1400 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 982 events
# INFO:root:Will fill the QCD dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding SingleElectron_Run2016D_HIPM samples and should combine them under Data
# INFO:root:Applying THWW>0.80 selection on 9163 events
# INFO:root:Will fill the Data dataframe with the remaining 130 events
# INFO:root:tot event weight 130.0
#
# INFO:root:Finding QCD_Pt_600to800 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 2380 events
# INFO:root:Will fill the QCD dataframe with the remaining 16 events
# INFO:root:tot event weight 0.8389011600139771
#
# INFO:root:Finding QCD_Pt_300to470 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 1448 events
# INFO:root:Will fill the QCD dataframe with the remaining 5 events
# INFO:root:tot event weight 11.590967643344623
#
# INFO:root:Finding SingleMuon_Run2016B_ver2_HIPM samples and should combine them under Data
# INFO:root:Finding SingleMuon_Run2016E_HIPM samples and should combine them under Data
# INFO:root:Finding QCD_Pt_170to300 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 111 events
# INFO:root:Will fill the QCD dataframe with the remaining 1 events
# INFO:root:tot event weight 80.22918764202859
#
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 31871 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 554 events
# INFO:root:tot event weight 70.43605749550505
#
# INFO:root:Finding SingleElectron_Run2016C_HIPM samples and should combine them under Data
# INFO:root:Applying THWW>0.80 selection on 5489 events
# INFO:root:Will fill the Data dataframe with the remaining 69 events
# INFO:root:tot event weight 69.0
#
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 27349 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 56 events
# INFO:root:tot event weight 0.013250265733720295
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 5330 events
# INFO:root:Will fill the ttH dataframe with the remaining 403 events
# INFO:root:tot event weight 0.7657171769718965
#
# INFO:root:Finding QCD_Pt_800to1000 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 1656 events
# INFO:root:Will fill the QCD dataframe with the remaining 1 events
# INFO:root:tot event weight 0.01561145482948878
#
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 12611 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 178 events
# INFO:root:tot event weight 89.95992412964699
#
# INFO:root:Finding QCD_Pt_470to600 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 1703 events
# INFO:root:Will fill the QCD dataframe with the remaining 6 events
# INFO:root:tot event weight 1.0970122905496826
#
# INFO:root:Finding SingleMuon_Run2016C_HIPM samples and should combine them under Data
# INFO:root:Finding WZ samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 555 events
# INFO:root:Will fill the Diboson dataframe with the remaining 11 events
# INFO:root:tot event weight 1.1934935539666396
#
# INFO:root:Finding QCD_Pt_1400to1800 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 701 events
# INFO:root:Will fill the QCD dataframe with the remaining 1 events
# INFO:root:tot event weight 0.0011792570983472802
#
# INFO:root:Finding SingleElectron_Run2016B_ver2_HIPM samples and should combine them under Data
# INFO:root:Applying THWW>0.80 selection on 13038 events
# INFO:root:Will fill the Data dataframe with the remaining 181 events
# INFO:root:tot event weight 181.0
#
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 816 events
# INFO:root:Will fill the VBF dataframe with the remaining 272 events
# INFO:root:tot event weight 3.0642479572353483
#
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 17 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 73854 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 1434 events
# INFO:root:tot event weight 74.38228050911545
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 368486 events
# INFO:root:Will fill the TTbar dataframe with the remaining 3331 events
# INFO:root:tot event weight 174.6425906646785
#
# INFO:root:Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 13314 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 37 events
# INFO:root:tot event weight 1.027442041763618
#
# INFO:root:Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# INFO:root:Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 85676 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 1340 events
# INFO:root:tot event weight 18.690183284098126
#
# INFO:root:Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 5777 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 48 events
# INFO:root:tot event weight 23.625197252321236
#
# INFO:root:Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 1625 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 28 events
# INFO:root:tot event weight 6.991212299197531
#
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 3645 events
# INFO:root:Will fill the ggF dataframe with the remaining 1172 events
# INFO:root:tot event weight 7.955719358647583
#
# INFO:root:Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 1603 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 20 events
# INFO:root:tot event weight 4.967334175879083
#
# INFO:root:Finding QCD_Pt_3200toInf samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 64 events
# INFO:root:Will fill the QCD dataframe with the remaining 1 events
# INFO:root:tot event weight 2.6778853961117857e-06
#
# INFO:root:Finding SingleMuon_Run2016F_HIPM samples and should combine them under Data
# INFO:root:Applying THWW>0.80 selection on 6255 events
# INFO:root:Will fill the Data dataframe with the remaining 98 events
# INFO:root:tot event weight 98.0
#
# INFO:root:Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 6400 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 24 events
# INFO:root:tot event weight 0.10101613003155631
#
# INFO:root:Finding SingleElectron_Run2016F_HIPM samples and should combine them under Data
# INFO:root:Finding QCD_Pt_1800to2400 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 370 events
# INFO:root:Will fill the QCD dataframe with the remaining 3 events
# INFO:root:tot event weight 0.001045857854925606
#
# INFO:root:Finding WW samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 1252 events
# INFO:root:Will fill the Diboson dataframe with the remaining 107 events
# INFO:root:tot event weight 17.243947591427126
#
# INFO:root:Finding SingleMuon_Run2016D_HIPM samples and should combine them under Data
# INFO:root:Applying THWW>0.80 selection on 9752 events
# INFO:root:Will fill the Data dataframe with the remaining 139 events
# INFO:root:tot event weight 139.0
#
# INFO:root:Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 5538 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 15 events
# INFO:root:tot event weight 0.6232407436463879
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 48708 events
# INFO:root:Will fill the TTbar dataframe with the remaining 208 events
# INFO:root:tot event weight 6.740768542701025
#
# INFO:root:Finding QCD_Pt_2400to3200 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 216 events
# INFO:root:Will fill the QCD dataframe with the remaining 2 events
# INFO:root:tot event weight 5.496967141125122e-05
#
# INFO:root:Finding SingleElectron_Run2016E_HIPM samples and should combine them under Data
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 37 events
# INFO:root:Will fill the Diboson dataframe with the remaining 1 events
# INFO:root:tot event weight 0.26298850755808867
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 1921 events
# INFO:root:Will fill the TTbar dataframe with the remaining 14 events
# INFO:root:tot event weight 0.8404716685275341
#
# INFO:root:Finding QCD_Pt_1000to1400 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 1127 events
# INFO:root:Will fill the QCD dataframe with the remaining 4 events
# INFO:root:tot event weight 0.026831479647143438
#
# INFO:root:Finding SingleElectron_Run2016D_HIPM samples and should combine them under Data
# INFO:root:Finding QCD_Pt_600to800 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 2859 events
# INFO:root:Will fill the QCD dataframe with the remaining 20 events
# INFO:root:tot event weight 1.005848000853743
#
# INFO:root:Finding QCD_Pt_300to470 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 1405 events
# INFO:root:Will fill the QCD dataframe with the remaining 6 events
# INFO:root:tot event weight 12.63074885178358
#
# INFO:root:Finding SingleMuon_Run2016B_ver2_HIPM samples and should combine them under Data
# INFO:root:Applying THWW>0.80 selection on 13685 events
# INFO:root:Will fill the Data dataframe with the remaining 187 events
# INFO:root:tot event weight 187.0
#
# INFO:root:Finding SingleMuon_Run2016E_HIPM samples and should combine them under Data
# INFO:root:Applying THWW>0.80 selection on 9134 events
# INFO:root:Will fill the Data dataframe with the remaining 134 events
# INFO:root:tot event weight 134.0
#
# INFO:root:Finding QCD_Pt_170to300 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 62 events
# INFO:root:Will fill the QCD dataframe with the remaining 1 events
# INFO:root:tot event weight 94.59331569820648
#
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 45525 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 995 events
# INFO:root:tot event weight 127.7673349556409
#
# INFO:root:Finding SingleElectron_Run2016C_HIPM samples and should combine them under Data
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 40241 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 316 events
# INFO:root:tot event weight 0.07279400519844055
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 5431 events
# INFO:root:Will fill the ttH dataframe with the remaining 536 events
# INFO:root:tot event weight 1.0111456480864738
#
# INFO:root:Finding QCD_Pt_800to1000 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 2046 events
# INFO:root:Will fill the QCD dataframe with the remaining 9 events
# INFO:root:tot event weight 0.11450505635604938
#
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 16862 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 274 events
# INFO:root:tot event weight 137.91472968973076
#
# INFO:root:Finding QCD_Pt_470to600 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 2049 events
# INFO:root:Will fill the QCD dataframe with the remaining 13 events
# INFO:root:tot event weight 2.7612901845702287
#
# INFO:root:Finding SingleMuon_Run2016C_HIPM samples and should combine them under Data
# INFO:root:Applying THWW>0.80 selection on 5913 events
# INFO:root:Will fill the Data dataframe with the remaining 86 events
# INFO:root:tot event weight 86.0
#
# INFO:root:Finding WZ samples and should combine them under Diboson
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 414 events
# INFO:root:Will fill the Diboson dataframe with the remaining 26 events
# INFO:root:tot event weight 2.7632036278399528
#
# INFO:root:Finding QCD_Pt_1400to1800 samples and should combine them under QCD
# INFO:root:---> Using already stored event weight
# INFO:root:Applying THWW>0.80 selection on 773 events
# INFO:root:Will fill the QCD dataframe with the remaining 7 events
# INFO:root:tot event weight 0.006943062937574181
#
# INFO:root:Finding SingleElectron_Run2016B_ver2_HIPM samples and should combine them under Data

# %%
# presel = {
#         "THWW>0.80": "THWW>0.80",
# #             "msoftdrop": "fj_mass>40",
# #             "met": "met_pt>55",
# #             "lepmiso": "(lep_pt<120) | ( (lep_pt>120) & (lep_misolation<0.2))",
# }

# %%
# for cut, sel in list(presel.items()):    
#     for sample in samples:

#         for year in years:
#             for ch in channels:
      
#                 try:
#                     df = events_dict[year][ch][sample]
#                     df = df.query(sel)
#                     w = df["event_weight"]
#                 except:
#                     print(year, ch, sample, "is not present so will fill with 0")
#                     w = df["event_weight"]
                    
#                 cutflows[year][ch][sample][cut] = w.sum()

# %%
for ch in channels:
    for cut, sel in list(presel[ch].items()):
        for sample in samples:
            for year in years:
                try:
                    df = events_dict[year][ch][sample]
                    df = df.query(sel)
                    w = df["event_weight"]
                except:
                    print(year, ch, sample, "is not present so will fill with 0")
                    w = df["event_weight"]

                cutflows[year][ch][sample][cut] = w.sum()

# %%
cutflows["2016APV"]["mu"]["QCD"]     # take a quick look
# Out:
# {'sumgenweight': 2158841073.6961017,
#  'Trigger': 7733027.8571640495,
#  'METFilters': 7717476.40305799,
#  'OneLep': 2528471.2102144607,
#  'LepMiniIso': 223137.04624347284,
#  'NoTaus': 200312.06735418417,
#  'AtLeastOneFatJet': 136192.2108293256,
#  'CandidateJetpT': 52934.95056206322,
#  'LepInJet': 30920.008817828053,
#  'JetLepOverlap': 17344.944586178673,
#  'dPhiJetMET': 11616.677124383454,
#  'MET': 9717.0370157677,
#  'THWW>0.80': 111.14058583976653}

# %%
cutflows["2016APV"]["ele"]["QCD"]     # take a quick look
# Out:
# {'sumgenweight': 2165123387.235826,
#  'Trigger': 28180136.286444254,
#  'METFilters': 28140394.99885865,
#  'OneLep': 328760.50845948554,
#  'NoTaus': 328760.50845948554,
#  'AtLeastOneFatJet': 289704.74895183905,
#  'CandidateJetpT': 145730.687351548,
#  'LepInJet': 114936.89782142005,
#  'JetLepOverlap': 44327.886420873285,
#  'dPhiJetMET': 19018.86084559247,
#  'MET': 14124.286054968414,
#  'THWW>0.80': 93.77285944786469}

# %%
cutflows["2018"]["ele"]["ggF"]
# Out:
# {'sumgenweight': 6028.3346903316005,
#  'Trigger': 603.6899350730905,
#  'METFilters': 602.881734104983,
#  'OneLep': 388.9135434738342,
#  'NoTaus': 388.9135434738342,
#  'AtLeastOneFatJet': 318.12961390885613,
#  'CandidateJetpT': 170.6872193838514,
#  'LepInJet': 97.61137662573327,
#  'JetLepOverlap': 90.85626405647837,
#  'dPhiJetMET': 61.90578161681452,
#  'MET': 56.56200506649324,
#  'HEMCleaning': 54.4630950896176,
#  'THWW>0.80': 15.83365808263488}

# %%
cutflows["2018"]["ele"]["TTbar"]
# Out:
# {'sumgenweight': 49752687.64857001,
#  'Trigger': 4999747.120986915,
#  'METFilters': 4997120.90736503,
#  'OneLep': 3427834.7618229645,
#  'NoTaus': 3427834.7618229645,
#  'AtLeastOneFatJet': 621213.3788457776,
#  'CandidateJetpT': 302332.23598755227,
#  'LepInJet': 136434.24986663507,
#  'JetLepOverlap': 116772.86275007836,
#  'dPhiJetMET': 72395.2649972906,
#  'MET': 68160.81426400038,
#  'HEMCleaning': 65382.089800065885,
#  'THWW>0.80': 464.6288476418568}

# %% [markdown]
# # Combine different channels

# %%
common_cuts = cutflows["2018"]["mu"]["VBF"]
common_cuts
# Out:
# {'sumgenweight': 48316.581150264006,
#  'Trigger': 4634.032851408792,
#  'METFilters': 4630.388062311652,
#  'OneLep': 3302.3299191332926,
#  'LepMiniIso': 3267.9804752004325,
#  'NoTaus': 2470.6669092784737,
#  'AtLeastOneFatJet': 230.57294769595737,
#  'CandidateJetpT': 102.0553100822256,
#  'LepInJet': 61.2270060421994,
#  'JetLepOverlap': 57.679855037776875,
#  'dPhiJetMET': 42.988729949437804,
#  'MET': 39.53664274744095,
#  'HEMCleaning': 37.63394639219362,
#  'THWW>0.80': 10.27211516133846}

# %%
def combine_channels(cutflows):
    """
    Must add lepminiso cutflow to electron channel.
    Will add to extra keys to the channels,
        1. `ele_new`: which contains the mini-isolation label to match the mu channel (the yield doesn't change)
        2. `lep`: which is the sum of `ele_new` and `mu`
    """
    
    for year in cutflows.keys():
        cutflows[year]["ele_new"] = {}   

        for sample in cutflows[year]["ele"].keys():
            cutflows[year]["ele_new"][sample] = {}

            for cut in common_cuts:
                if (year != "2018") and (cut == "HEMCleaning"):
                    continue
                    
                if cut != "LepMiniIso":
                    cutflows[year]["ele_new"][sample][cut] = cutflows[year]["ele"][sample][cut]
                else:
                    cutflows[year]["ele_new"][sample][cut] = cutflows[year]["ele"][sample]["OneLep"]

    # combine both channels
    cutflows_new = {}
    for year in cutflows.keys():
        cutflows_new[year] = {}
        cutflows_new[year]["lep"] = {}
        
        for ch in ["mu", "ele_new"]:
            for sample in cutflows[year][ch]:
                                
                if sample not in cutflows_new[year]["lep"]:
                    cutflows_new[year]["lep"][sample] = {}
                
                for cut in cutflows[year][ch][sample]:
                    
                    if (year != "2018") and (cut == "HEMCleaning"):
                        continue
                    
                    if cut not in cutflows_new[year]["lep"][sample]:
                        cutflows_new[year]["lep"][sample][cut] = cutflows[year][ch][sample][cut]
                    else:
                        cutflows_new[year]["lep"][sample][cut] += cutflows[year][ch][sample][cut]
        cutflows[year] = {**cutflows[year], **cutflows_new[year]}
        
    return cutflows

# %%
cutflows = combine_channels(cutflows)

# %%
cutflows["2018"].keys()
# Out:
# dict_keys(['ele', 'mu', 'ele_new', 'lep'])

# %%
cutflows["2018"]["ele_new"]["WJetsLNu"]
# Out:
# {'sumgenweight': 98938496.94524625,
#  'Trigger': 13494656.17486616,
#  'METFilters': 13488618.890384968,
#  'OneLep': 10159409.905364677,
#  'LepMiniIso': 10159409.905364677,
#  'NoTaus': 10159409.905364677,
#  'AtLeastOneFatJet': 1156730.6194095358,
#  'CandidateJetpT': 495338.20674019103,
#  'LepInJet': 192104.8620934339,
#  'JetLepOverlap': 64323.362198248855,
#  'dPhiJetMET': 44303.27213056914,
#  'MET': 41197.55827468004,
#  'HEMCleaning': 39627.042510522035,
#  'THWW>0.80': 862.958461907012}

# %%
cutflows["2018"]["mu"]["WJetsLNu"]
# Out:
# {'sumgenweight': 98881812.96014196,
#  'Trigger': 18344533.58998877,
#  'METFilters': 18335526.912493113,
#  'OneLep': 15259681.07624155,
#  'LepMiniIso': 15201162.017077586,
#  'NoTaus': 12926093.249765638,
#  'AtLeastOneFatJet': 1364620.0240112403,
#  'CandidateJetpT': 583489.2706716096,
#  'LepInJet': 211377.56713725123,
#  'JetLepOverlap': 79562.04863680585,
#  'dPhiJetMET': 55806.28999208973,
#  'MET': 52121.20126645196,
#  'HEMCleaning': 50165.97622332939,
#  'THWW>0.80': 1232.8578706813782}

# %%
cutflows["2018"]["lep"]["WJetsLNu"]
# Out:
# {'sumgenweight': 197820309.9053882,
#  'Trigger': 31839189.76485493,
#  'METFilters': 31824145.80287808,
#  'OneLep': 25419090.981606226,
#  'LepMiniIso': 25360571.922442265,
#  'NoTaus': 23085503.155130316,
#  'AtLeastOneFatJet': 2521350.6434207764,
#  'CandidateJetpT': 1078827.4774118005,
#  'LepInJet': 403482.4292306851,
#  'JetLepOverlap': 143885.4108350547,
#  'dPhiJetMET': 100109.56212265887,
#  'MET': 93318.75954113199,
#  'HEMCleaning': 89793.01873385142,
#  'THWW>0.80': 2095.81633258839}

# %% [markdown]
# # Combine different years

# %%
def combine_years(cutflows):
    """Will remove the HEM cleaning cutflow from 2018 first."""
    
    whatever_year = list(cutflows.keys())[0]
    channels = cutflows[whatever_year].keys()
    
    # combine all years
    cutflows_new = {}
    cutflows_new["Run2"] = {}
    
    for ch in channels:
        cutflows_new["Run2"][ch] = {}
        
        for year in cutflows:
            for sample in cutflows[year][ch]:
                
                if sample not in cutflows_new["Run2"][ch]:
                    cutflows_new["Run2"][ch][sample] = {}

                for cut in cutflows[year][ch][sample]:
                    if "HEM" in cut:
                        continue
                    if cut not in cutflows_new["Run2"][ch][sample]:
                        cutflows_new["Run2"][ch][sample][cut] = cutflows[year][ch][sample][cut]
                    else:
                        cutflows_new["Run2"][ch][sample][cut] += cutflows[year][ch][sample][cut]

    cutflows = {**cutflows, **cutflows_new}

    return cutflows

# %%
cutflows = combine_years(cutflows)

# %%
cutflows["2016"]["ele"].keys()
# Out:
# dict_keys(['VBF', 'WJetsLNu', 'TTbar', 'Data', 'SingleTop', 'ggF', 'QCD', 'Diboson', 'ttH'])

# %%
cutflows.keys()
# Out:
# dict_keys(['2018', '2017', '2016', '2016APV', 'Run2'])

# %%
cutflows["Run2"].keys()
# Out:
# dict_keys(['ele', 'mu', 'ele_new', 'lep'])

# %% [markdown]
# # Combine non-dominant backgrounds

# %%
# combine non-dominant backgrounds under others
dominant_bkgs = ["WJetsLNu", "QCD", "TTbar"]
signals = ["ggF", "VH"]

for year in cutflows:
    for ch in cutflows[year]:
        cutflows[year][ch]["Others"] = dict.fromkeys(cutflows[year][ch]["WJetsLNu"], 0)
        for sample in cutflows[year][ch]:
            if sample == "Data":
                continue
            if sample not in signals+dominant_bkgs:
                for cut in cutflows[year][ch][sample]:
                    cutflows[year][ch]["Others"][cut] += cutflows[year][ch][sample][cut]

# %%
cutflows["2018"]["ele"].keys()
# Out:
# dict_keys(['VBF', 'WJetsLNu', 'TTbar', 'SingleTop', 'ggF', 'QCD', 'Data', 'Diboson', 'ttH', 'Others'])

# %%
cutflows["2018"]["lep"]["Others"]
# Out:
# {'sumgenweight': 103338427.99260004,
#  'Trigger': 8465163.68069785,
#  'METFilters': 8461578.098172793,
#  'OneLep': 6025103.119154213,
#  'LepMiniIso': 5994959.048241838,
#  'NoTaus': 5196687.329703328,
#  'AtLeastOneFatJet': 383662.5043456247,
#  'CandidateJetpT': 182760.08095323652,
#  'LepInJet': 73955.20521748498,
#  'JetLepOverlap': 35739.36283193218,
#  'dPhiJetMET': 23761.14152413553,
#  'MET': 22296.456684631317,
#  'HEMCleaning': 21362.67512062594,
#  'THWW>0.80': 392.48907897466495}

# %% [markdown]
# # LateX cutflow table

# %%
cuts = {
    "mu": [
        "sumgenweight",
        "Trigger",
        "METFilters",
        "OneLep",
        "LepMiniIso",        
        "NoTaus",
        "AtLeastOneFatJet",
        "CandidateJetpT",
        "LepInJet",
        "JetLepOverlap",
        "dPhiJetMET",
        "MET",
        "HEMCleaning",      
    ],
    "ele": [
        "sumgenweight",
        "Trigger",
        "METFilters",
        "OneLep",        
        "NoTaus",
        "AtLeastOneFatJet",
        "CandidateJetpT",
        "LepInJet",
        "JetLepOverlap",
        "dPhiJetMET",
        "MET",
        "HEMCleaning",   
    ],  
    "lep": [
        "sumgenweight",
        "Trigger",
        "METFilters",
        "OneLep",
        "LepMiniIso",        
        "NoTaus",
        "AtLeastOneFatJet",
        "CandidateJetpT",
        "LepInJet",
        "JetLepOverlap",
        "dPhiJetMET",
        "MET",
        "HEMCleaning",           
    ],
}

for ch in cuts:
    if ch == "lep":
        for cut in presel["mu"]:        
            cuts[ch] += [cut]
    else:
        for cut in presel[ch]:
            cuts[ch] += [cut]

# %%
cut_to_label = {
    "sumgenweight": "sumgenweight",        
    "HEMCleaning": "HEMCleaning",    
    "Trigger": "Trigger",
    "METFilters": "METFilters",
    "OneLep": "n Leptons = 1",
    "NoTaus": "n Taus = 0",
    "LepIso": r"$\ell$ relative isolation",
    "LepMiniIso": r"$\ell$ mini-isolation",    
    "AtLeastOneFatJet": r"n FatJets $>=$ 1",
    "CandidateJetpT": r"j $p_T > 250$GeV",
    "LepInJet": r"$\Delta R(j, \ell) < 0.8$",
    "JetLepOverlap": r"$\Delta R(j, \ell) > 0.03$",
    "dPhiJetMET": r"$\Delta \phi(\mathrm{MET}, j)<1.57$",
    "MET": r"$\mathrm{MET}>20$",
    
    "None": "None",

    "THWW>0.80": r"$\ensuremath{T_{\text{HWW}}^{\ell\nu qq}} > 0.80$",
}

# %%
parquet_to_latex = {
    "WJetsLNu": "$\PW(\Pell\PGn)$+",
    "QCD": "QCD",
#     "DYJets": "$\PZ(\Pell\Pell)$+jets",
    "TTbar": "\\ttbar",
    "Others": "Other MC",

    "ggF": "ggF",
    "VBF": "VBF",
#     "VH": "VH",
#     "ttH": "$t\\bar{t}H$",    
    
    "Data": "Data",
}

def make_latex_cutflow_table(cutflows_dict, year, ch, add_data=False, add_sumgenweight=False):
    """Will use the cutflows dictionary to make the LateX table we have in the AN."""
    
    samples_bkg = ["WJetsLNu","QCD","TTbar","Others"]
    samples_sig = ["ggF","VBF"]

    ### backgrounds
    headers = [parquet_to_latex[s] for s in samples_bkg]
    
    textabular = f"l{'r'*len(headers)}"
    textabular += "|r"
    
    texheader = "\\textbf{Inclusive Selection}" + " & " + " & ".join(headers) + " & Total MC "
    if add_data:
        textabular += "|r"
        texheader += "& Data "
    texheader += "\\\\"
    texdata = "\\hline\n"
    
    data = dict()
    
    for cut in cuts[ch]: 
        if (year != "2018") and (cut == "HEMCleaning"):
            continue
            
        if not add_sumgenweight and cut == "sumgenweight":
            continue
    
        data[cut] = []

        for sample in samples_bkg:            
            data[cut].append(round(cutflows_dict[year][ch][sample][cut]))
            
        totalmc = 0
        for sample in (samples_bkg + samples_sig):
            totalmc += round(cutflows_dict[year][ch][sample][cut])
            
        data[cut].append(totalmc)
        
        if add_data:
            data[cut].append(round(cutflows_dict[year][ch]["Data"][cut]))

    for label in data:
        if label == "z":
            texdata += "\\hline\n"
        texdata += f"{cut_to_label[label]} & {' & '.join(map(str,data[label]))} \\\\\n"
        
    texdata += "\\hline\n"    

    ### signal
    headers2 = [parquet_to_latex[s] for s in samples_sig]    
    texheader2 = " & " + " & ".join(headers2) + "\\\\"
    texdata2 = "\\hline\n"

    data = dict()
    for cut in cuts[ch]:
        if (year != "2018") and (cut == "HEMCleaning"):
            continue
            
        data[cut] = []

        for sample in samples_sig:
            data[cut].append(round(cutflows_dict[year][ch][sample][cut]))
        
    for label in data:
        if label == "z":
            texdata += "\\hline\n"
        texdata2 += f"{cut_to_label[label]} & {' & '.join(map(str,data[label]))} \\\\\n"    

    # make table
    print("\\begin{table}[!htp]")
    print("\\begin{center}")
    
    print("\\begin{tabular}{"+textabular+"}")
    print(texheader)
    print(texdata,end="")
    print(texheader2)
    print(texdata2,end="")
    print("\\end{tabular}")
    
    
    if ch == "lep":
        print("\\caption{Event yield of " + year + " Monte Carlo samples normalized to " + str(round(get_lumi([year], [ch]))) + "\\fbinv.}")        
    else:
        print("\\caption{Event yield of " + ch + " channel " + year + " Monte Carlo samples normalized to " + str(round(get_lumi([year], [ch]))) + "\\fbinv.}")

    print("\\label{sel-tab-cutflow" + year + "}")
    print("\\end{center}")
    print("\\end{table}")

# %%
make_latex_cutflow_table(cutflows, "2016", "lep", add_data=True, add_sumgenweight=True)
# Out:
# \begin{table}[!htp]
# \begin{center}
# \begin{tabular}{lrrrr|r|r}
# \textbf{Inclusive Selection} & $\PW(\Pell\PGn)$+ & QCD & \ttbar & Other MC & Total MC & Data \\
# \hline
# sumgenweight & 34495755 & 3734374445 & 27964378 & 29129527 & 3825994666 & 615115660 \\
# Trigger & 5263985 & 31071425 & 3527493 & 2445700 & 42311189 & 444762865 \\
# METFilters & 5260487 & 31026586 & 3524911 & 2444314 & 42258881 & 444581778 \\
# n Leptons = 1 & 3831194 & 2499006 & 2412703 & 1673192 & 10417793 & 173524490 \\
# $\ell$ mini-isolation & 3823434 & 486256 & 2383167 & 1663548 & 8358085 & 167806496 \\
# n Taus = 0 & 3666706 & 467539 & 1905815 & 1442753 & 7484236 & 161818889 \\
# n FatJets $>=$ 1 & 684900 & 372635 & 346909 & 108946 & 1513707 & 1808735 \\
# j $p_T > 250$GeV & 299584 & 174361 & 167639 & 51106 & 692848 & 719861 \\
# $\Delta R(j, \ell) < 0.8$ & 108796 & 127704 & 73800 & 20231 & 330625 & 358519 \\
# $\Delta R(j, \ell) > 0.03$ & 39183 & 53931 & 64386 & 9819 & 167406 & 160727 \\
# $\Delta \phi(\mathrm{MET}, j)<1.57$ & 27589 & 25914 & 40890 & 6507 & 100964 & 88487 \\
# $\mathrm{MET}>20$ & 25504 & 19304 & 38312 & 6049 & 89226 & 79302 \\
# $\ensuremath{T_{\text{HWW}}^{\ell\nu qq}} > 0.80$ & 531 & 117 & 272 & 108 & 1043 & 914 \\
# \hline
#  & ggF & VBF\\
# \hline
# sumgenweight & 3388 & 27173 \\
# Trigger & 420 & 2166 \\
# METFilters & 419 & 2164 \\
# n Leptons = 1 & 285 & 1413 \\
# $\ell$ mini-isolation & 277 & 1403 \\
# n Taus = 0 & 240 & 1183 \\
# n FatJets $>=$ 1 & 201 & 116 \\
# j $p_T > 250$GeV & 109 & 49 \\
# $\Delta R(j, \ell) < 0.8$ & 65 & 29 \\
# $\Delta R(j, \ell) > 0.03$ & 60 & 27 \\
# $\Delta \phi(\mathrm{MET}, j)<1.57$ & 44 & 20 \\
# $\mathrm{MET}>20$ & 39 & 18 \\
# $\ensuremath{T_{\text{HWW}}^{\ell\nu qq}} > 0.80$ & 11 & 4 \\
# \end{tabular}
# \caption{Event yield of 2016 Monte Carlo samples normalized to 17\fbinv.}
# \label{sel-tab-cutflow2016}
# \end{center}
# \end{table}
