# %% [markdown]
# # Compute the LateX cutflow tables
# - Will load the pkl files that contain the cutflows and the sumgenweight
# - Will scale the events by the cross section
# - Will save the yields in a dictionnary called ```cutflows -> Dict()```
# - Will make the LateX table using the function ```make_composition_table()```

# %%
import glob
import json
import os
import pickle as pkl
import sys

import hist as hist2
import matplotlib.pyplot as plt
import mplhep as hep
import numpy as np
import pandas as pd
import pyarrow
import pyarrow.parquet as pq
import yaml
from scipy.special import softmax
from sklearn.metrics import auc, roc_curve

sys.path
sys.path.append("../python/")

import utils

plt.style.use(hep.style.CMS)
plt.rcParams.update({"font.size": 20})

pd.options.mode.chained_assignment = None

import glob
import os
import json
import pickle
import yaml
import math

import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None
import pyarrow.parquet as pq
from sklearn.metrics import auc, roc_curve
from scipy.special import softmax

import hist as hist2
import matplotlib.pyplot as plt
import mplhep as hep

plt.style.use(hep.style.CMS)

import sys
sys.path
sys.path.append("../python/")

import utils

plt.rcParams.update({"font.size": 20})

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# get lumi
with open("../fileset/luminosity.json") as f:
    luminosity = json.load(f)
    
luminosity
# Out:
# {'ele': {'Run2': 137640.0,
#   '2016APV': 19492.72,
#   '2016': 16809.96,
#   '2017': 41476.02,
#   '2018': 59816.23},
#  'mu': {'Run2': 137640.0,
#   '2016APV': 19436.16,
#   '2016': 16810.81,
#   '2017': 41475.26,
#   '2018': 59781.96},
#  'lep': {'Run2': 137640.0,
#   '2016APV': 19436.16,
#   '2016': 16810.81,
#   '2017': 41475.26,
#   '2018': 59781.96},
#  'had': {'Run2': 137640.0,
#   '2016APV': 19436.16,
#   '2016': 16810.81,
#   '2017': 41475.26,
#   '2018': 59781.96}}

# %%
def get_lumi(years, channels):
    lum_ = 0
    for year in years:
        lum = 0
        for ch in channels:
            lum += luminosity[ch][year] / 1000.0

        lum_ += lum / len(channels)    
    return lum_

# %% [markdown]
# # Read cutflows from pkl

# %%
def get_sum_sumgenweight(pkl_files, year, sample):
    """Load and sum the sumgenweight of each pkl file."""
    
    sum_sumgenweight = 0
    for ifile in pkl_files:
        with open(ifile, "rb") as f:
            metadata = pkl.load(f)            
        sum_sumgenweight = sum_sumgenweight + metadata[sample][year]["sumgenweight"]

    return sum_sumgenweight


def get_xsecweight(pkl_files, year, ch, sample, is_data):
    
    if not is_data:
        # find xsection
        f = open("../fileset/xsec_pfnano.json")
        xsec = json.load(f)
        f.close()
        try:
            xsec = eval(str((xsec[sample])))
        except ValueError:
            print(f"sample {sample} doesn't have xsecs defined in xsec_pfnano.json so will skip it")
            return None

        # get overall weighting of events.. each event has a genweight...
        # sumgenweight sums over events in a chunk... sum_sumgenweight sums over chunks
        xsec_weight = (xsec * luminosity[ch][year]) / get_sum_sumgenweight(pkl_files, year, sample)
    else:
        xsec_weight = 1
    return xsec_weight

def get_cutflow(pkl_files, year, ch, sample, is_data):
    """
    Get cutflow from metadata but multiply by xsec-weight
    """
    xsec_weight = get_xsecweight(pkl_files, year, ch, sample, is_data)
        
    cuts = [
        "sumgenweight",
        "Trigger",
        "METFilters",
        "OneLep",
        "NoTaus",
        "AtLeastOneFatJet",
        "CandidateJetpT",
        "LepInJet",
        "JetLepOverlap",
        "dPhiJetMET",
        "MET",
    ]
        
    if year == "2018":
        cuts += ["HEMCleaning"]
        
    evyield = dict.fromkeys(cuts, 0)
    for ik, pkl_file in enumerate(pkl_files):
        with open(pkl_file, "rb") as f:
            metadata = pkl.load(f)
            
        cutflows = metadata[sample][year]["cutflows"][ch]

        for key in evyield.keys():

            if key == "sumgenweight":
                evyield[key] += metadata[sample][year][key] * xsec_weight
            else:
                evyield[key] += cutflows[key] * xsec_weight        
    return evyield

# %%
! ls ../eos/July18_hww_2016APV/WJetsToLNu_HT-100To200/outfiles/0-10.pkl
# Out:
# ../eos/July18_hww_2016APV/WJetsToLNu_HT-100To200/outfiles/0-10.pkl

# %%
with open("../eos/July18_hww_2016APV/WJetsToLNu_HT-100To200/outfiles/0-10.pkl", "rb") as f:
    metadata = pkl.load(f)
metadata
# Out:
# {'WJetsToLNu_HT-100To200': {'mc': 149,
#   '2016APV': {'sumgenweight': 1492951.0,
#    'sumlheweight': {0: 1551137.2,
#     1: 1551799.4,
#     2: 1541534.8,
#     3: 1491997.6,
#     4: 1492951.0,
#     5: 1483308.9,
#     6: 1443469.5,
#     7: 1444666.2,
#     8: 1435536.2},
#    'sumpdfweight': {0: 1492951.0,
#     1: 1494297.1,
#     2: 1492237.6,
#     3: 1494463.2,
#     4: 1493804.0,
#     5: 1494341.9,
#     6: 1493538.8,
#     7: 1494321.6,
#     8: 1493813.9,
#     9: 1493034.2,
#     10: 1492469.5,
#     11: 1491638.0,
#     12: 1493345.8,
#     13: 1493301.8,
#     14: 1492837.2,
#     15: 1493383.9,
#     16: 1492520.0,
#     17: 1492682.9,
#     18: 1492891.5,
#     19: 1492741.8,
#     20: 1493447.0,
#     21: 1493083.9,
#     22: 1493360.1,
#     23: 1492864.5,
#     24: 1493688.5,
#     25: 1493356.0,
#     26: 1493390.6,
#     27: 1493141.5,
#     28: 1493313.1,
#     29: 1494101.6,
#     30: 1493643.0,
#     31: 1494384.6,
#     32: 1493172.6,
#     33: 1494015.9,
#     34: 1493571.5,
#     35: 1492720.9,
#     36: 1492159.4,
#     37: 1493126.9,
#     38: 1493509.5,
#     39: 1491891.2,
#     40: 1492621.4,
#     41: 1493915.8,
#     42: 1491517.1,
#     43: 1492308.4,
#     44: 1492010.8,
#     45: 1492316.1,
#     46: 1491960.8,
#     47: 1492369.5,
#     48: 1493450.2,
#     49: 1492499.0,
#     50: 1492522.1,
#     51: 1493222.4,
#     52: 1492974.9,
#     53: 1493208.9,
#     54: 1493169.8,
#     55: 1493387.2,
#     56: 1493377.5,
#     57: 1492569.4,
#     58: 1492951.9,
#     59: 1493494.1,
#     60: 1493014.1,
#     61: 1493080.5,
#     62: 1493337.8,
#     63: 1492692.5,
#     64: 1493837.2,
#     65: 1493077.9,
#     66: 1493159.1,
#     67: 1493449.5,
#     68: 1493156.2,
#     69: 1493187.1,
#     70: 1492545.9,
#     71: 1493067.8,
#     72: 1493194.2,
#     73: 1493110.5,
#     74: 1492923.9,
#     75: 1492582.1,
#     76: 1492782.4,
#     77: 1493712.2,
#     78: 1492857.5,
#     79: 1492556.6,
#     80: 1492880.5,
#     81: 1492874.1,
#     82: 1493021.2,
#     83: 1492623.9,
#     84: 1493190.1,
#     85: 1492886.1,
#     86: 1492868.5,
#     87: 1493052.1,
#     88: 1493276.9,
#     89: 1493087.6,
#     90: 1493099.9,
#     91: 1493063.8,
#     92: 1492965.5,
#     93: 1492983.4,
#     94: 1492643.6,
#     95: 1492860.8,
#     96: 1492725.5,
#     97: 1492941.6,
#     98: 1492949.1,
#     99: 1492890.2,
#     100: 1492951.0,
#     101: 1421697.9,
#     102: 1562486.0},
#    'cutflows': {'ele': {'Trigger': 198848.0,
#      'METFilters': 198767.0,
#      'OneLep': 136324.0,
#      'NoTaus': 136324.0,
#      'AtLeastOneFatJet': 1854.0,
#      'CandidateJetpT': 53.0,
#      'LepInJet': 38.0,
#      'JetLepOverlap': 5.0,
#      'dPhiJetMET': 1.0,
#      'MET': 0.0},
#     'mu': {'Trigger': 228311.0,
#      'METFilters': 228203.0,
#      'OneLep': 227602.0,
#      'NoTaus': 192965.0,
#      'AtLeastOneFatJet': 2406.0,
#      'CandidateJetpT': 86.0,
#      'LepInJet': 67.0,
#      'JetLepOverlap': 9.0,
#      'dPhiJetMET': 3.0,
#      'MET': 3.0}}}}}

# %% [markdown]
# # Adding a cut from the parquets

# %%
### This is your configuration. specefy which channels, years, samples, and directory of pkl files to use.
channels = [
    "ele", 
    "mu",
]
years = [
#     "2018", 
#     "2017",
    "2016", 
    "2016APV",
]

samples = [
    "ggF", 
    "VBF",  
    "WH",
    "ZH",    
    "ttH",
    "WJetsLNu",
    "TTbar",
    "SingleTop",
    "Diboson",
    "EWKvjets",
    "DYJets",
    "WZQQ",
    "Data",
]

samples_dir = {
    "2016":    "../eos/July18_hww_2016",
    "2016APV": "../eos/July18_hww_2016APV",    
    "2017":    "../eos/July18_hww_2017",    
    "2018":    "../eos/July18_hww_2018",    
}

# %%
cutflows = {}
for year in years:
#     if year != "2016":
#         continue
    print(f"Processing year {year}")
    
    cutflows[year] = {}
    
    for ch in channels:
#         if ch != "mu": 
#             continue
        
        print(f"  {ch} channel")
        cutflows[year][ch] = {}

        condor_dir = os.listdir(samples_dir[year])

        for sample in condor_dir:

            # first: check if the sample is in one of combine_samples_by_name
            sample_to_use = None
            for key in utils.combine_samples_by_name:
                if key in sample:
                    sample_to_use = utils.combine_samples_by_name[key]
                    break

            # second: if not, combine under common label
            if sample_to_use is None:
                for key in utils.combine_samples:
                    if key in sample:
                        sample_to_use = utils.combine_samples[key]
                        break
                    else:
                        sample_to_use = sample

            if sample_to_use not in samples:
                continue

            is_data = False
            if sample_to_use == "Data":
                is_data = True

            out_files = f"{samples_dir[year]}/{sample}/outfiles/"
            pkl_files = glob.glob(f"{out_files}/*.pkl")

            if len(pkl_files) == 0:
                continue

            parquet_files = glob.glob(f"{out_files}/*_{ch}.parquet")
            
            try:
                data = pd.read_parquet(parquet_files)
            except pyarrow.lib.ArrowInvalid:
                # empty parquet because no event passed selection
#                 print(f"No parquet file for {sample}")
                continue

            if len(data) == 0:
#                 print(f"Hi, No parquet file for {sample}")
                continue
    
            if sample_to_use not in cutflows[year][ch].keys():
                cutflows[year][ch][sample_to_use] = get_cutflow(pkl_files, year, ch, sample, is_data)
            else:
                temp = get_cutflow(pkl_files, year, ch, sample, is_data)
                for key in cutflows[year][ch][sample_to_use]:
                    cutflows[year][ch][sample_to_use][key] += temp[key]
            
    print(f"------------------------------------------")
# Out:
# Processing year 2016
#   ele channel
#   mu channel
# ------------------------------------------
# Processing year 2016APV
#   ele channel
#   mu channel
# ------------------------------------------

# %%
samples = cutflows["2017"]["ele"].keys()  # samples
samples
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 samples = cutflows["2017"]["ele"].keys()  # samples
#       2 samples
#
# KeyError: '2017'

# %%
from make_stacked_hists import make_events_dict

presel = {
        "mu": {
            "fj_mass": "fj_mass>40",
            "THWW>0.50": "THWW>0.750",
        },
        "ele": {
            "fj_mass": "fj_mass>40",
            "THWW>0.50": "THWW>0.750",
        },
}

THWW_path = "../../weaver-core-dev/experiments_finetuning/v35_30/model.onnx"

events_dict = make_events_dict(years, channels, samples_dir, samples, presel, THWW_path)
# Out:
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:Applying fj_mass selection on 822 events
# INFO:root:Applying THWW>0.50 selection on 713 events
# INFO:root:Will fill the VBF dataframe with the remaining 263 events
# INFO:root:tot event weight 2.0417761938861987
#
# INFO:root:Finding fake_2016_ele_EWK_SF_Down.parquet samples and should combine them under EWKvjets
# INFO:root:No parquet file for fake_2016_ele_EWK_SF_Down.parquet
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 19 events
# INFO:root:Applying THWW>0.50 selection on 12 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding SingleMuon_Run2016H samples and should combine them under Data
# INFO:root:Finding SingleMuon_Run2016F samples and should combine them under Data
# INFO:root:Finding EWKWminus_WToLNu samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 1065 events
# INFO:root:Applying THWW>0.50 selection on 832 events
# INFO:root:Will fill the EWKvjets dataframe with the remaining 18 events
# INFO:root:tot event weight 4.94160054027001
#
# INFO:root:Finding EWKZ_ZToNuNu samples and should combine them under EWKvjets
# INFO:root:Finding SingleMuon_Run2016G samples and should combine them under Data
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Applying fj_mass selection on 1077 events
# INFO:root:Applying THWW>0.50 selection on 915 events
# INFO:root:Will fill the WH dataframe with the remaining 276 events
# INFO:root:tot event weight 0.27154146827776426
#
# INFO:root:Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 43264 events
# INFO:root:Applying THWW>0.50 selection on 40971 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 817 events
# INFO:root:tot event weight 48.31077117329768
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:Applying fj_mass selection on 357653 events
# INFO:root:Applying THWW>0.50 selection on 340435 events
# INFO:root:Will fill the TTbar dataframe with the remaining 3159 events
# INFO:root:tot event weight 138.63777720295678
#
# INFO:root:Finding SingleElectron_Run2016G samples and should combine them under Data
# INFO:root:Applying fj_mass selection on 18103 events
# INFO:root:Applying THWW>0.50 selection on 15735 events
# INFO:root:Will fill the Data dataframe with the remaining 271 events
# INFO:root:tot event weight 271.0
#
# INFO:root:Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 10913 events
# INFO:root:Applying THWW>0.50 selection on 10565 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 35 events
# INFO:root:tot event weight 0.8811877358089679
#
# INFO:root:Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 17 events
# INFO:root:Applying THWW>0.50 selection on 14 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 60993 events
# INFO:root:Applying THWW>0.50 selection on 56128 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 683 events
# INFO:root:tot event weight 8.34358563173262
#
# INFO:root:Finding EWKZ_ZToLL samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 394 events
# INFO:root:Applying THWW>0.50 selection on 356 events
# INFO:root:Will fill the EWKvjets dataframe with the remaining 10 events
# INFO:root:tot event weight 2.3380182891457117
#
# INFO:root:Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 4925 events
# INFO:root:Applying THWW>0.50 selection on 2999 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 40 events
# INFO:root:tot event weight 25.292246400210047
#
# INFO:root:Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 1726 events
# INFO:root:Applying THWW>0.50 selection on 1495 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 31 events
# INFO:root:tot event weight 6.682749354620232
#
# INFO:root:Finding SingleElectron_Run2016H samples and should combine them under Data
# INFO:root:Applying fj_mass selection on 19607 events
# INFO:root:Applying THWW>0.50 selection on 16909 events
# INFO:root:Will fill the Data dataframe with the remaining 261 events
# INFO:root:tot event weight 261.0
#
# INFO:root:Finding fake_2016_ele_EWK_SF_Up.parquet samples and should combine them under EWKvjets
# INFO:root:No parquet file for fake_2016_ele_EWK_SF_Up.parquet
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:Applying fj_mass selection on 2111 events
# INFO:root:Applying THWW>0.50 selection on 1796 events
# INFO:root:Will fill the ggF dataframe with the remaining 651 events
# INFO:root:tot event weight 4.731599235861588
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-650ToInf samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 120699 events
# INFO:root:Applying THWW>0.50 selection on 101389 events
# INFO:root:Will fill the DYJets dataframe with the remaining 326 events
# INFO:root:tot event weight 0.09810939138780249
#
# INFO:root:Finding SingleElectron_Run2016F samples and should combine them under Data
# INFO:root:Applying fj_mass selection on 936 events
# INFO:root:Applying THWW>0.50 selection on 809 events
# INFO:root:Will fill the Data dataframe with the remaining 12 events
# INFO:root:tot event weight 12.0
#
# INFO:root:Finding WJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 1654 events
# INFO:root:Applying THWW>0.50 selection on 1450 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 20 events
# INFO:root:tot event weight 4.551481266829658
#
# INFO:root:Finding ZJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Applying fj_mass selection on 1374 events
# INFO:root:Applying THWW>0.50 selection on 1165 events
# INFO:root:Will fill the WH dataframe with the remaining 369 events
# INFO:root:tot event weight 0.5211798853317536
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-100To250 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 28508 events
# INFO:root:Applying THWW>0.50 selection on 24900 events
# INFO:root:Will fill the DYJets dataframe with the remaining 241 events
# INFO:root:tot event weight 9.90327719827648
#
# INFO:root:Finding EWKWplus_WToQQ samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 51 events
# INFO:root:Applying THWW>0.50 selection on 40 events
# INFO:root:Will fill the EWKvjets dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 4871 events
# INFO:root:Applying THWW>0.50 selection on 4720 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 22 events
# INFO:root:tot event weight 0.11384238423647422
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-50To100 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 1632 events
# INFO:root:Applying THWW>0.50 selection on 1585 events
# INFO:root:Will fill the DYJets dataframe with the remaining 27 events
# INFO:root:tot event weight 2.4371094124675508
#
# INFO:root:Finding WW samples and should combine them under Diboson
# INFO:root:Applying fj_mass selection on 1367 events
# INFO:root:Applying THWW>0.50 selection on 1076 events
# INFO:root:Will fill the Diboson dataframe with the remaining 93 events
# INFO:root:tot event weight 12.411448791749784
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-250To400 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 369409 events
# INFO:root:Applying THWW>0.50 selection on 336498 events
# INFO:root:Will fill the DYJets dataframe with the remaining 743 events
# INFO:root:tot event weight 3.6241356562573
#
# INFO:root:Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 3809 events
# INFO:root:Applying THWW>0.50 selection on 3674 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 15 events
# INFO:root:tot event weight 0.5326805790932454
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:Applying fj_mass selection on 65972 events
# INFO:root:Applying THWW>0.50 selection on 62799 events
# INFO:root:Will fill the TTbar dataframe with the remaining 415 events
# INFO:root:tot event weight 10.772500595026177
#
# INFO:root:Finding EWKZ_ZToQQ samples and should combine them under EWKvjets
# INFO:root:Finding ZJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 39 events
# INFO:root:Applying THWW>0.50 selection on 24 events
# INFO:root:Will fill the WZQQ dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:Applying fj_mass selection on 85 events
# INFO:root:Applying THWW>0.50 selection on 75 events
# INFO:root:Will fill the Diboson dataframe with the remaining 1 events
# INFO:root:tot event weight 0.3285060815313095
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:Applying fj_mass selection on 725 events
# INFO:root:Applying THWW>0.50 selection on 668 events
# INFO:root:Will fill the TTbar dataframe with the remaining 14 events
# INFO:root:tot event weight 0.8630566177436101
#
# INFO:root:Finding WJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 405 events
# INFO:root:Applying THWW>0.50 selection on 361 events
# INFO:root:Will fill the WZQQ dataframe with the remaining 14 events
# INFO:root:tot event weight 1.4432644057630193
#
# INFO:root:Finding ZJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 212 events
# INFO:root:Applying THWW>0.50 selection on 167 events
# INFO:root:Will fill the WZQQ dataframe with the remaining 3 events
# INFO:root:tot event weight 0.23838283412593902
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-400To650 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 112129 events
# INFO:root:Applying THWW>0.50 selection on 95970 events
# INFO:root:Will fill the DYJets dataframe with the remaining 288 events
# INFO:root:tot event weight 0.9128013397427723
#
# INFO:root:Finding EWKWminus_WToQQ samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 38 events
# INFO:root:Applying THWW>0.50 selection on 27 events
# INFO:root:Will fill the EWKvjets dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 32347 events
# INFO:root:Applying THWW>0.50 selection on 30086 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 683 events
# INFO:root:tot event weight 80.19352151530202
#
# INFO:root:Finding WJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 226 events
# INFO:root:Applying THWW>0.50 selection on 193 events
# INFO:root:Will fill the WZQQ dataframe with the remaining 5 events
# INFO:root:tot event weight 0.5604036843586754
#
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 24856 events
# INFO:root:Applying THWW>0.50 selection on 20116 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 87 events
# INFO:root:tot event weight 0.020264305454563047
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Applying fj_mass selection on 6399 events
# INFO:root:Applying THWW>0.50 selection on 6058 events
# INFO:root:Will fill the ttH dataframe with the remaining 627 events
# INFO:root:tot event weight 0.7898057276653901
#
# INFO:root:Finding ZJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 315 events
# INFO:root:Applying THWW>0.50 selection on 269 events
# INFO:root:Will fill the WZQQ dataframe with the remaining 7 events
# INFO:root:tot event weight 0.47052169679895967
#
# INFO:root:Finding EWKWplus_WToLNu samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 937 events
# INFO:root:Applying THWW>0.50 selection on 735 events
# INFO:root:Will fill the EWKvjets dataframe with the remaining 17 events
# INFO:root:tot event weight 5.174168636207023
#
# INFO:root:Finding GluGluZH_HToWW_M-125_TuneCP5_13TeV-powheg-pythia8 samples and should combine them under ZH
# INFO:root:Applying fj_mass selection on 5015 events
# INFO:root:Applying THWW>0.50 selection on 4391 events
# INFO:root:Will fill the ZH dataframe with the remaining 1317 events
# INFO:root:tot event weight 0.07413529524464305
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-0To50 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 402 events
# INFO:root:Applying THWW>0.50 selection on 389 events
# INFO:root:Will fill the DYJets dataframe with the remaining 10 events
# INFO:root:tot event weight 4.240153867914887
#
# INFO:root:Finding WJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 35 events
# INFO:root:Applying THWW>0.50 selection on 28 events
# INFO:root:Will fill the WZQQ dataframe with the remaining 1 events
# INFO:root:tot event weight 1.508073155159401
#
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 12162 events
# INFO:root:Applying THWW>0.50 selection on 10676 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 260 events
# INFO:root:tot event weight 144.98155704800314
#
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:Applying fj_mass selection on 3939 events
# INFO:root:Applying THWW>0.50 selection on 3455 events
# INFO:root:Will fill the ZH dataframe with the remaining 971 events
# INFO:root:tot event weight 0.5204447560590343
#
# INFO:root:Finding WZ samples and should combine them under Diboson
# INFO:root:Applying fj_mass selection on 672 events
# INFO:root:Applying THWW>0.50 selection on 555 events
# INFO:root:Will fill the Diboson dataframe with the remaining 17 events
# INFO:root:tot event weight 1.8561696867772683
#
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:Applying fj_mass selection on 1132 events
# INFO:root:Applying THWW>0.50 selection on 921 events
# INFO:root:Will fill the VBF dataframe with the remaining 417 events
# INFO:root:tot event weight 2.958994831928974
#
# INFO:root:Finding fake_2016_ele_EWK_SF_Down.parquet samples and should combine them under EWKvjets
# INFO:root:No parquet file for fake_2016_ele_EWK_SF_Down.parquet
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:Finding SingleMuon_Run2016H samples and should combine them under Data
# INFO:root:Applying fj_mass selection on 25175 events
# INFO:root:Applying THWW>0.50 selection on 20984 events
# INFO:root:Will fill the Data dataframe with the remaining 379 events
# INFO:root:tot event weight 379.0
#
# INFO:root:Finding SingleMuon_Run2016F samples and should combine them under Data
# INFO:root:Applying fj_mass selection on 1201 events
# INFO:root:Applying THWW>0.50 selection on 997 events
# INFO:root:Will fill the Data dataframe with the remaining 12 events
# INFO:root:tot event weight 12.0
#
# INFO:root:Finding EWKWminus_WToLNu samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 1128 events
# INFO:root:Applying THWW>0.50 selection on 896 events
# INFO:root:Will fill the EWKvjets dataframe with the remaining 41 events
# INFO:root:tot event weight 9.673381342752961
#
# INFO:root:Finding EWKZ_ZToNuNu samples and should combine them under EWKvjets
# INFO:root:Finding SingleMuon_Run2016G samples and should combine them under Data
# INFO:root:Applying fj_mass selection on 22084 events
# INFO:root:Applying THWW>0.50 selection on 18390 events
# INFO:root:Will fill the Data dataframe with the remaining 347 events
# INFO:root:tot event weight 347.0
#
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Applying fj_mass selection on 1575 events
# INFO:root:Applying THWW>0.50 selection on 1310 events
# INFO:root:Will fill the WH dataframe with the remaining 461 events
# INFO:root:tot event weight 0.4202568740264877
#
# INFO:root:Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 62782 events
# INFO:root:Applying THWW>0.50 selection on 57823 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 1573 events
# INFO:root:tot event weight 88.9262598946238
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:Applying fj_mass selection on 426909 events
# INFO:root:Applying THWW>0.50 selection on 399955 events
# INFO:root:Will fill the TTbar dataframe with the remaining 4722 events
# INFO:root:tot event weight 196.0744409261019
#
# INFO:root:Finding SingleElectron_Run2016G samples and should combine them under Data
# INFO:root:Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 18024 events
# INFO:root:Applying THWW>0.50 selection on 17141 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 69 events
# INFO:root:tot event weight 1.8116031390080518
#
# INFO:root:Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 92 events
# INFO:root:Applying THWW>0.50 selection on 76 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 1 events
# INFO:root:tot event weight 0.022461527357381817
#
# INFO:root:Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 91268 events
# INFO:root:Applying THWW>0.50 selection on 81337 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 1827 events
# INFO:root:tot event weight 22.244911936091643
#
# INFO:root:Finding EWKZ_ZToLL samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 168 events
# INFO:root:Applying THWW>0.50 selection on 140 events
# INFO:root:Will fill the EWKvjets dataframe with the remaining 1 events
# INFO:root:tot event weight 0.407153624586531
#
# INFO:root:Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 5582 events
# INFO:root:Applying THWW>0.50 selection on 3335 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 64 events
# INFO:root:tot event weight 35.376176111795225
#
# INFO:root:Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 1861 events
# INFO:root:Applying THWW>0.50 selection on 1638 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 40 events
# INFO:root:tot event weight 8.03705922970592
#
# INFO:root:Finding SingleElectron_Run2016H samples and should combine them under Data
# INFO:root:Finding fake_2016_ele_EWK_SF_Up.parquet samples and should combine them under EWKvjets
# INFO:root:No parquet file for fake_2016_ele_EWK_SF_Up.parquet
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:Applying fj_mass selection on 3454 events
# INFO:root:Applying THWW>0.50 selection on 2832 events
# INFO:root:Will fill the ggF dataframe with the remaining 1193 events
# INFO:root:tot event weight 8.373583196977176
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-650ToInf samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 59712 events
# INFO:root:Applying THWW>0.50 selection on 45916 events
# INFO:root:Will fill the DYJets dataframe with the remaining 448 events
# INFO:root:tot event weight 0.1695850935068937
#
# INFO:root:Finding SingleElectron_Run2016F samples and should combine them under Data
# INFO:root:Finding WJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 2019 events
# INFO:root:Applying THWW>0.50 selection on 1758 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 40 events
# INFO:root:tot event weight 7.680909366150036
#
# INFO:root:Finding ZJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Applying fj_mass selection on 2016 events
# INFO:root:Applying THWW>0.50 selection on 1702 events
# INFO:root:Will fill the WH dataframe with the remaining 663 events
# INFO:root:tot event weight 0.9672366181668914
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-100To250 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 18496 events
# INFO:root:Applying THWW>0.50 selection on 14696 events
# INFO:root:Will fill the DYJets dataframe with the remaining 227 events
# INFO:root:tot event weight 9.655084009673258
#
# INFO:root:Finding EWKWplus_WToQQ samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 109 events
# INFO:root:Applying THWW>0.50 selection on 81 events
# INFO:root:Will fill the EWKvjets dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 7550 events
# INFO:root:Applying THWW>0.50 selection on 7245 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 21 events
# INFO:root:tot event weight 0.05590863221654965
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-50To100 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 2061 events
# INFO:root:Applying THWW>0.50 selection on 1925 events
# INFO:root:Will fill the DYJets dataframe with the remaining 29 events
# INFO:root:tot event weight 1.4018995118208295
#
# INFO:root:Finding WW samples and should combine them under Diboson
# INFO:root:Applying fj_mass selection on 1489 events
# INFO:root:Applying THWW>0.50 selection on 1206 events
# INFO:root:Will fill the Diboson dataframe with the remaining 132 events
# INFO:root:tot event weight 15.712605759324855
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-250To400 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 79888 events
# INFO:root:Applying THWW>0.50 selection on 59911 events
# INFO:root:Will fill the DYJets dataframe with the remaining 471 events
# INFO:root:tot event weight 2.5193998912693267
#
# INFO:root:Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 6329 events
# INFO:root:Applying THWW>0.50 selection on 5988 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 24 events
# INFO:root:tot event weight 0.589469179533094
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:Applying fj_mass selection on 58417 events
# INFO:root:Applying THWW>0.50 selection on 54565 events
# INFO:root:Will fill the TTbar dataframe with the remaining 346 events
# INFO:root:tot event weight 8.937657885102798
#
# INFO:root:Finding EWKZ_ZToQQ samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 66 events
# INFO:root:Applying THWW>0.50 selection on 57 events
# INFO:root:Will fill the EWKvjets dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding ZJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 64 events
# INFO:root:Applying THWW>0.50 selection on 53 events
# INFO:root:Will fill the WZQQ dataframe with the remaining 2 events
# INFO:root:tot event weight 0.532091348544727
#
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:Applying fj_mass selection on 38 events
# INFO:root:Applying THWW>0.50 selection on 31 events
# INFO:root:Will fill the Diboson dataframe with the remaining 2 events
# INFO:root:tot event weight 0.3946202693489349
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:Applying fj_mass selection on 3281 events
# INFO:root:Applying THWW>0.50 selection on 3119 events
# INFO:root:Will fill the TTbar dataframe with the remaining 16 events
# INFO:root:tot event weight 0.8413151772370631
#
# INFO:root:Finding WJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 575 events
# INFO:root:Applying THWW>0.50 selection on 487 events
# INFO:root:Will fill the WZQQ dataframe with the remaining 8 events
# INFO:root:tot event weight 0.745691382742618
#
# INFO:root:Finding ZJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 555 events
# INFO:root:Applying THWW>0.50 selection on 490 events
# INFO:root:Will fill the WZQQ dataframe with the remaining 6 events
# INFO:root:tot event weight 0.5851967208720052
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-400To650 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 24655 events
# INFO:root:Applying THWW>0.50 selection on 18044 events
# INFO:root:Will fill the DYJets dataframe with the remaining 195 events
# INFO:root:tot event weight 0.6525910574363125
#
# INFO:root:Finding EWKWminus_WToQQ samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 72 events
# INFO:root:Applying THWW>0.50 selection on 57 events
# INFO:root:Will fill the EWKvjets dataframe with the remaining 2 events
# INFO:root:tot event weight 0.12931442878831206
#
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 47077 events
# INFO:root:Applying THWW>0.50 selection on 42859 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 1258 events
# INFO:root:tot event weight 148.76193021731626
#
# INFO:root:Finding WJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 255 events
# INFO:root:Applying THWW>0.50 selection on 214 events
# INFO:root:Will fill the WZQQ dataframe with the remaining 7 events
# INFO:root:tot event weight 1.823079240691406
#
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 38503 events
# INFO:root:Applying THWW>0.50 selection on 29628 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 408 events
# INFO:root:tot event weight 0.09431398137519853
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Applying fj_mass selection on 6739 events
# INFO:root:Applying THWW>0.50 selection on 6234 events
# INFO:root:Will fill the ttH dataframe with the remaining 724 events
# INFO:root:tot event weight 0.832734610070738
#
# INFO:root:Finding ZJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 1060 events
# INFO:root:Applying THWW>0.50 selection on 921 events
# INFO:root:Will fill the WZQQ dataframe with the remaining 15 events
# INFO:root:tot event weight 0.7230303967356327
#
# INFO:root:Finding EWKWplus_WToLNu samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 971 events
# INFO:root:Applying THWW>0.50 selection on 763 events
# INFO:root:Will fill the EWKvjets dataframe with the remaining 23 events
# INFO:root:tot event weight 6.089538002941888
#
# INFO:root:Finding GluGluZH_HToWW_M-125_TuneCP5_13TeV-powheg-pythia8 samples and should combine them under ZH
# INFO:root:Applying fj_mass selection on 5870 events
# INFO:root:Applying THWW>0.50 selection on 4931 events
# INFO:root:Will fill the ZH dataframe with the remaining 1858 events
# INFO:root:tot event weight 0.10112636092507735
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-0To50 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 340 events
# INFO:root:Applying THWW>0.50 selection on 325 events
# INFO:root:Will fill the DYJets dataframe with the remaining 3 events
# INFO:root:tot event weight 0.4946557209320245
#
# INFO:root:Finding WJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 17 events
# INFO:root:Applying THWW>0.50 selection on 15 events
# INFO:root:Will fill the WZQQ dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 16262 events
# INFO:root:Applying THWW>0.50 selection on 13960 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 359 events
# INFO:root:tot event weight 181.52296882763665
#
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:Applying fj_mass selection on 5228 events
# INFO:root:Applying THWW>0.50 selection on 4369 events
# INFO:root:Will fill the ZH dataframe with the remaining 1671 events
# INFO:root:tot event weight 0.8550725327147359
#
# INFO:root:Finding WZ samples and should combine them under Diboson
# INFO:root:Applying fj_mass selection on 450 events
# INFO:root:Applying THWW>0.50 selection on 348 events
# INFO:root:Will fill the Diboson dataframe with the remaining 23 events
# INFO:root:tot event weight 1.897962997806431
#
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:Applying fj_mass selection on 488 events
# INFO:root:Applying THWW>0.50 selection on 423 events
# INFO:root:Will fill the VBF dataframe with the remaining 154 events
# INFO:root:tot event weight 1.8241967249406037
#
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 8 events
# INFO:root:Applying THWW>0.50 selection on 5 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding EWKWminus_WToLNu samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 1002 events
# INFO:root:Applying THWW>0.50 selection on 785 events
# INFO:root:Will fill the EWKvjets dataframe with the remaining 28 events
# INFO:root:tot event weight 7.386083915582296
#
# INFO:root:Finding EWKZ_ZToNuNu samples and should combine them under EWKvjets
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Applying fj_mass selection on 1463 events
# INFO:root:Applying THWW>0.50 selection on 1258 events
# INFO:root:Will fill the WH dataframe with the remaining 384 events
# INFO:root:tot event weight 0.301641080622401
#
# INFO:root:Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 51342 events
# INFO:root:Applying THWW>0.50 selection on 48725 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 1010 events
# INFO:root:tot event weight 52.3433123638456
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:Applying fj_mass selection on 330497 events
# INFO:root:Applying THWW>0.50 selection on 315009 events
# INFO:root:Will fill the TTbar dataframe with the remaining 3306 events
# INFO:root:tot event weight 165.6268822417615
#
# INFO:root:Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 9217 events
# INFO:root:Applying THWW>0.50 selection on 8920 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 34 events
# INFO:root:tot event weight 1.0210902329832108
#
# INFO:root:Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# INFO:root:Finding fake_2016APV_ele_EWK_SF_Down.parquet samples and should combine them under EWKvjets
# INFO:root:No parquet file for fake_2016APV_ele_EWK_SF_Down.parquet
# INFO:root:Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 57860 events
# INFO:root:Applying THWW>0.50 selection on 53194 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 696 events
# INFO:root:tot event weight 9.61100917388433
#
# INFO:root:Finding EWKZ_ZToLL samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 497 events
# INFO:root:Applying THWW>0.50 selection on 457 events
# INFO:root:Will fill the EWKvjets dataframe with the remaining 4 events
# INFO:root:tot event weight 0.9098272827922604
#
# INFO:root:Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 5558 events
# INFO:root:Applying THWW>0.50 selection on 3400 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 58 events
# INFO:root:tot event weight 28.43859513520682
#
# INFO:root:Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 1520 events
# INFO:root:Applying THWW>0.50 selection on 1348 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 29 events
# INFO:root:tot event weight 7.182683689263468
#
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:Applying fj_mass selection on 2389 events
# INFO:root:Applying THWW>0.50 selection on 2050 events
# INFO:root:Will fill the ggF dataframe with the remaining 746 events
# INFO:root:tot event weight 5.13111447427462
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-650ToInf samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 122895 events
# INFO:root:Applying THWW>0.50 selection on 103825 events
# INFO:root:Will fill the DYJets dataframe with the remaining 351 events
# INFO:root:tot event weight 0.13963388191675666
#
# INFO:root:Finding WJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 1474 events
# INFO:root:Applying THWW>0.50 selection on 1267 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 23 events
# INFO:root:tot event weight 6.010615746353507
#
# INFO:root:Finding ZJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding SingleMuon_Run2016F_HIPM samples and should combine them under Data
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Applying fj_mass selection on 1871 events
# INFO:root:Applying THWW>0.50 selection on 1578 events
# INFO:root:Will fill the WH dataframe with the remaining 474 events
# INFO:root:tot event weight 0.5844071938323456
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-100To250 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 29709 events
# INFO:root:Applying THWW>0.50 selection on 26206 events
# INFO:root:Will fill the DYJets dataframe with the remaining 234 events
# INFO:root:tot event weight 12.192291744663823
#
# INFO:root:Finding fake_2016APV_ele_EWK_SF_Up.parquet samples and should combine them under EWKvjets
# INFO:root:No parquet file for fake_2016APV_ele_EWK_SF_Up.parquet
# INFO:root:Finding EWKWplus_WToQQ samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 45 events
# INFO:root:Applying THWW>0.50 selection on 37 events
# INFO:root:Will fill the EWKvjets dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 4584 events
# INFO:root:Applying THWW>0.50 selection on 4442 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 19 events
# INFO:root:tot event weight 0.08647811968946367
#
# INFO:root:Finding SingleElectron_Run2016F_HIPM samples and should combine them under Data
# INFO:root:Applying fj_mass selection on 5658 events
# INFO:root:Applying THWW>0.50 selection on 4884 events
# INFO:root:Will fill the Data dataframe with the remaining 79 events
# INFO:root:tot event weight 79.0
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-50To100 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 1663 events
# INFO:root:Applying THWW>0.50 selection on 1616 events
# INFO:root:Will fill the DYJets dataframe with the remaining 22 events
# INFO:root:tot event weight 4.905775822110595
#
# INFO:root:Finding WW samples and should combine them under Diboson
# INFO:root:Applying fj_mass selection on 1157 events
# INFO:root:Applying THWW>0.50 selection on 889 events
# INFO:root:Will fill the Diboson dataframe with the remaining 73 events
# INFO:root:tot event weight 11.482474745283968
#
# INFO:root:Finding SingleMuon_Run2016D_HIPM samples and should combine them under Data
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-250To400 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 384630 events
# INFO:root:Applying THWW>0.50 selection on 352607 events
# INFO:root:Will fill the DYJets dataframe with the remaining 770 events
# INFO:root:tot event weight 4.141938751708842
#
# INFO:root:Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 3763 events
# INFO:root:Applying THWW>0.50 selection on 3628 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 16 events
# INFO:root:tot event weight 0.5049117480940931
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:Applying fj_mass selection on 58556 events
# INFO:root:Applying THWW>0.50 selection on 55850 events
# INFO:root:Will fill the TTbar dataframe with the remaining 352 events
# INFO:root:tot event weight 11.186192877002824
#
# INFO:root:Finding SingleElectron_Run2016E_HIPM samples and should combine them under Data
# INFO:root:Applying fj_mass selection on 8915 events
# INFO:root:Applying THWW>0.50 selection on 7747 events
# INFO:root:Will fill the Data dataframe with the remaining 159 events
# INFO:root:tot event weight 159.0
#
# INFO:root:Finding EWKZ_ZToQQ samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 49 events
# INFO:root:Applying THWW>0.50 selection on 41 events
# INFO:root:Will fill the EWKvjets dataframe with the remaining 1 events
# INFO:root:tot event weight 0.03166225543463802
#
# INFO:root:Finding ZJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 48 events
# INFO:root:Applying THWW>0.50 selection on 29 events
# INFO:root:Will fill the WZQQ dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:Applying fj_mass selection on 119 events
# INFO:root:Applying THWW>0.50 selection on 104 events
# INFO:root:Will fill the Diboson dataframe with the remaining 2 events
# INFO:root:tot event weight 0.5599891295457438
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:Applying fj_mass selection on 818 events
# INFO:root:Applying THWW>0.50 selection on 785 events
# INFO:root:Will fill the TTbar dataframe with the remaining 14 events
# INFO:root:tot event weight 0.5734203025040916
#
# INFO:root:Finding SingleElectron_Run2016D_HIPM samples and should combine them under Data
# INFO:root:Applying fj_mass selection on 9499 events
# INFO:root:Applying THWW>0.50 selection on 8211 events
# INFO:root:Will fill the Data dataframe with the remaining 170 events
# INFO:root:tot event weight 170.0
#
# INFO:root:Finding WJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 543 events
# INFO:root:Applying THWW>0.50 selection on 480 events
# INFO:root:Will fill the WZQQ dataframe with the remaining 10 events
# INFO:root:tot event weight 0.6743763615487409
#
# INFO:root:Finding ZJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 180 events
# INFO:root:Applying THWW>0.50 selection on 145 events
# INFO:root:Will fill the WZQQ dataframe with the remaining 2 events
# INFO:root:tot event weight 0.2237114451281526
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-400To650 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 119545 events
# INFO:root:Applying THWW>0.50 selection on 103064 events
# INFO:root:Will fill the DYJets dataframe with the remaining 267 events
# INFO:root:tot event weight 1.0040734532129947
# INFO:root:Finding SingleMuon_Run2016B_ver2_HIPM samples and should combine them under Data
# INFO:root:Finding SingleMuon_Run2016E_HIPM samples and should combine them under Data
# INFO:root:Finding EWKWminus_WToQQ samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 32 events
# INFO:root:Applying THWW>0.50 selection on 22 events
# INFO:root:Will fill the EWKvjets dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 32368 events
# INFO:root:Applying THWW>0.50 selection on 30132 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 750 events
# INFO:root:tot event weight 96.95922959380687
#
# INFO:root:Finding SingleElectron_Run2016C_HIPM samples and should combine them under Data
# INFO:root:Applying fj_mass selection on 5696 events
# INFO:root:Applying THWW>0.50 selection on 4953 events
# INFO:root:Will fill the Data dataframe with the remaining 86 events
# INFO:root:tot event weight 86.0
#
# INFO:root:Finding WJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 364 events
# INFO:root:Applying THWW>0.50 selection on 298 events
# INFO:root:Will fill the WZQQ dataframe with the remaining 9 events
# INFO:root:tot event weight 0.9929402359506835
#
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 27093 events
# INFO:root:Applying THWW>0.50 selection on 22026 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 79 events
# INFO:root:tot event weight 0.018242044540892025
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Applying fj_mass selection on 5370 events
# INFO:root:Applying THWW>0.50 selection on 5069 events
# INFO:root:Will fill the ttH dataframe with the remaining 481 events
# INFO:root:tot event weight 0.7807334718711627
#
# INFO:root:Finding ZJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 172 events
# INFO:root:Applying THWW>0.50 selection on 146 events
# INFO:root:Will fill the WZQQ dataframe with the remaining 1 events
# INFO:root:tot event weight 0.08440556412428873
#
# INFO:root:Finding EWKWplus_WToLNu samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 875 events
# INFO:root:Applying THWW>0.50 selection on 695 events
# INFO:root:Will fill the EWKvjets dataframe with the remaining 19 events
# INFO:root:tot event weight 6.047155322044824
#
# INFO:root:Finding GluGluZH_HToWW_M-125_TuneCP5_13TeV-powheg-pythia8 samples and should combine them under ZH
# INFO:root:Applying fj_mass selection on 5480 events
# INFO:root:Applying THWW>0.50 selection on 4783 events
# INFO:root:Will fill the ZH dataframe with the remaining 1394 events
# INFO:root:tot event weight 0.07588556883715203
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-0To50 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 386 events
# INFO:root:Applying THWW>0.50 selection on 372 events
# INFO:root:Will fill the DYJets dataframe with the remaining 6 events
# INFO:root:tot event weight -0.0883882882952498
#
# INFO:root:Finding WJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 48 events
# INFO:root:Applying THWW>0.50 selection on 37 events
# INFO:root:Will fill the WZQQ dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 13089 events
# INFO:root:Applying THWW>0.50 selection on 11450 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 260 events
# INFO:root:tot event weight 135.8887326048964
#
# INFO:root:Finding SingleMuon_Run2016C_HIPM samples and should combine them under Data
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:Applying fj_mass selection on 4220 events
# INFO:root:Applying THWW>0.50 selection on 3653 events
# INFO:root:Will fill the ZH dataframe with the remaining 1060 events
# INFO:root:tot event weight 0.5859773574614734
#
# INFO:root:Finding WZ samples and should combine them under Diboson
# INFO:root:Applying fj_mass selection on 687 events
# INFO:root:Applying THWW>0.50 selection on 568 events
# INFO:root:Will fill the Diboson dataframe with the remaining 11 events
# INFO:root:tot event weight 1.2074451843653211
#
# INFO:root:Finding SingleElectron_Run2016B_ver2_HIPM samples and should combine them under Data
# INFO:root:Applying fj_mass selection on 13459 events
# INFO:root:Applying THWW>0.50 selection on 11828 events
# INFO:root:Will fill the Data dataframe with the remaining 240 events
# INFO:root:tot event weight 240.0
#
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:Applying fj_mass selection on 860 events
# INFO:root:Applying THWW>0.50 selection on 694 events
# INFO:root:Will fill the VBF dataframe with the remaining 311 events
# INFO:root:tot event weight 3.519118478814809
#
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 19 events
# INFO:root:Applying THWW>0.50 selection on 8 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding EWKWminus_WToLNu samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 1184 events
# INFO:root:Applying THWW>0.50 selection on 942 events
# INFO:root:Will fill the EWKvjets dataframe with the remaining 36 events
# INFO:root:tot event weight 9.59589809070825
#
# INFO:root:Finding EWKZ_ZToNuNu samples and should combine them under EWKvjets
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Applying fj_mass selection on 2079 events
# INFO:root:Applying THWW>0.50 selection on 1750 events
# INFO:root:Will fill the WH dataframe with the remaining 668 events
# INFO:root:tot event weight 0.4930084608317903
#
# INFO:root:Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 77194 events
# INFO:root:Applying THWW>0.50 selection on 71091 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 2037 events
# INFO:root:tot event weight 105.19908391035658
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:Applying fj_mass selection on 400063 events
# INFO:root:Applying THWW>0.50 selection on 375179 events
# INFO:root:Will fill the TTbar dataframe with the remaining 4597 events
# INFO:root:tot event weight 225.55315350699505
#
# INFO:root:Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 14713 events
# INFO:root:Applying THWW>0.50 selection on 13989 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 53 events
# INFO:root:tot event weight 1.6086423539642059
#
# INFO:root:Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 93 events
# INFO:root:Applying THWW>0.50 selection on 77 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 2 events
# INFO:root:tot event weight -0.0004162298638367666
#
# INFO:root:Finding fake_2016APV_ele_EWK_SF_Down.parquet samples and should combine them under EWKvjets
# INFO:root:No parquet file for fake_2016APV_ele_EWK_SF_Down.parquet
# INFO:root:Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 89879 events
# INFO:root:Applying THWW>0.50 selection on 80140 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 1898 events
# INFO:root:tot event weight 26.49738872666979
#
# INFO:root:Finding EWKZ_ZToLL samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 200 events
# INFO:root:Applying THWW>0.50 selection on 167 events
# INFO:root:Will fill the EWKvjets dataframe with the remaining 4 events
# INFO:root:tot event weight 0.948344773371681
# INFO:root:Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 6299 events
# INFO:root:Applying THWW>0.50 selection on 3804 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 80 events
# INFO:root:tot event weight 40.150735199354344
#
# INFO:root:Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 1735 events
# INFO:root:Applying THWW>0.50 selection on 1540 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 43 events
# INFO:root:tot event weight 10.89618176734101
#
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:Applying fj_mass selection on 3790 events
# INFO:root:Applying THWW>0.50 selection on 3105 events
# INFO:root:Will fill the ggF dataframe with the remaining 1292 events
# INFO:root:tot event weight 8.745904766334407
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-650ToInf samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 59042 events
# INFO:root:Applying THWW>0.50 selection on 45813 events
# INFO:root:Will fill the DYJets dataframe with the remaining 463 events
# INFO:root:tot event weight 0.17536882356807337
#
# INFO:root:Finding WJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 1745 events
# INFO:root:Applying THWW>0.50 selection on 1538 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 29 events
# INFO:root:tot event weight 7.258946247656713
#
# INFO:root:Finding ZJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding SingleMuon_Run2016F_HIPM samples and should combine them under Data
# INFO:root:Applying fj_mass selection on 7245 events
# INFO:root:Applying THWW>0.50 selection on 6062 events
# INFO:root:Will fill the Data dataframe with the remaining 131 events
# INFO:root:tot event weight 131.0
#
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Applying fj_mass selection on 2638 events
# INFO:root:Applying THWW>0.50 selection on 2215 events
# INFO:root:Will fill the WH dataframe with the remaining 819 events
# INFO:root:tot event weight 0.9833379542879774
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-100To250 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 19041 events
# INFO:root:Applying THWW>0.50 selection on 15329 events
# INFO:root:Will fill the DYJets dataframe with the remaining 222 events
# INFO:root:tot event weight 8.40077413825218
#
# INFO:root:Finding fake_2016APV_ele_EWK_SF_Up.parquet samples and should combine them under EWKvjets
# INFO:root:No parquet file for fake_2016APV_ele_EWK_SF_Up.parquet
# INFO:root:Finding EWKWplus_WToQQ samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 100 events
# INFO:root:Applying THWW>0.50 selection on 71 events
# INFO:root:Will fill the EWKvjets dataframe with the remaining 1 events
# INFO:root:tot event weight 0.11100947707970997
#
# INFO:root:Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 7282 events
# INFO:root:Applying THWW>0.50 selection on 6969 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 33 events
# INFO:root:tot event weight 0.15305438532246532
#
# INFO:root:Finding SingleElectron_Run2016F_HIPM samples and should combine them under Data
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-50To100 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 2058 events
# INFO:root:Applying THWW>0.50 selection on 1951 events
# INFO:root:Will fill the DYJets dataframe with the remaining 40 events
# INFO:root:tot event weight 3.4696905157141096
#
# INFO:root:Finding WW samples and should combine them under Diboson
# INFO:root:Applying fj_mass selection on 1332 events
# INFO:root:Applying THWW>0.50 selection on 1049 events
# INFO:root:Will fill the Diboson dataframe with the remaining 138 events
# INFO:root:tot event weight 22.20422248358182
#
# INFO:root:Finding SingleMuon_Run2016D_HIPM samples and should combine them under Data
# INFO:root:Applying fj_mass selection on 11331 events
# INFO:root:Applying THWW>0.50 selection on 9561 events
# INFO:root:Will fill the Data dataframe with the remaining 195 events
# INFO:root:tot event weight 195.0
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-250To400 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 86587 events
# INFO:root:Applying THWW>0.50 selection on 66747 events
# INFO:root:Will fill the DYJets dataframe with the remaining 513 events
# INFO:root:tot event weight 2.850936711810935
#
# INFO:root:Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 6161 events
# INFO:root:Applying THWW>0.50 selection on 5801 events
# INFO:root:Will fill the SingleTop dataframe with the remaining 33 events
# INFO:root:tot event weight 1.3253133821433727
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:Applying fj_mass selection on 53014 events
# INFO:root:Applying THWW>0.50 selection on 49541 events
# INFO:root:Will fill the TTbar dataframe with the remaining 324 events
# INFO:root:tot event weight 9.910179959590735
#
# INFO:root:Finding SingleElectron_Run2016E_HIPM samples and should combine them under Data
# INFO:root:Finding EWKZ_ZToQQ samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 82 events
# INFO:root:Applying THWW>0.50 selection on 74 events
# INFO:root:Will fill the EWKvjets dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding ZJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 66 events
# INFO:root:Applying THWW>0.50 selection on 59 events
# INFO:root:Will fill the WZQQ dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:Applying fj_mass selection on 50 events
# INFO:root:Applying THWW>0.50 selection on 37 events
# INFO:root:Will fill the Diboson dataframe with the remaining 1 events
# INFO:root:tot event weight 0.26298850755808867
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:Applying fj_mass selection on 3706 events
# INFO:root:Applying THWW>0.50 selection on 3547 events
# INFO:root:Will fill the TTbar dataframe with the remaining 26 events
# INFO:root:tot event weight 1.4108144743464779
#
# INFO:root:Finding SingleElectron_Run2016D_HIPM samples and should combine them under Data
# INFO:root:Finding WJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 912 events
# INFO:root:Applying THWW>0.50 selection on 760 events
# INFO:root:Will fill the WZQQ dataframe with the remaining 21 events
# INFO:root:tot event weight 1.3836963529051922
#
# INFO:root:Finding ZJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 567 events
# INFO:root:Applying THWW>0.50 selection on 511 events
# INFO:root:Will fill the WZQQ dataframe with the remaining 5 events
# INFO:root:tot event weight 0.4286485113649684
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-400To650 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 27428 events
# INFO:root:Applying THWW>0.50 selection on 20512 events
# INFO:root:Will fill the DYJets dataframe with the remaining 200 events
# INFO:root:tot event weight 0.8916996089636289
#
# INFO:root:Finding SingleMuon_Run2016B_ver2_HIPM samples and should combine them under Data
# INFO:root:Applying fj_mass selection on 15726 events
# INFO:root:Applying THWW>0.50 selection on 13284 events
# INFO:root:Will fill the Data dataframe with the remaining 254 events
# INFO:root:tot event weight 254.0
#
# INFO:root:Finding SingleMuon_Run2016E_HIPM samples and should combine them under Data
# INFO:root:Applying fj_mass selection on 10634 events
# INFO:root:Applying THWW>0.50 selection on 8817 events
# INFO:root:Will fill the Data dataframe with the remaining 176 events
# INFO:root:tot event weight 176.0
#
# INFO:root:Finding EWKWminus_WToQQ samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 61 events
# INFO:root:Applying THWW>0.50 selection on 47 events
# INFO:root:Will fill the EWKvjets dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 47533 events
# INFO:root:Applying THWW>0.50 selection on 43214 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 1390 events
# INFO:root:tot event weight 178.4888230535879
#
# INFO:root:Finding SingleElectron_Run2016C_HIPM samples and should combine them under Data
# INFO:root:Finding WJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 386 events
# INFO:root:Applying THWW>0.50 selection on 321 events
# INFO:root:Will fill the WZQQ dataframe with the remaining 12 events
# INFO:root:tot event weight 1.7439199827957241
#
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 42508 events
# INFO:root:Applying THWW>0.50 selection on 32712 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 446 events
# INFO:root:tot event weight 0.10230551011525377
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Applying fj_mass selection on 5830 events
# INFO:root:Applying THWW>0.50 selection on 5411 events
# INFO:root:Will fill the ttH dataframe with the remaining 658 events
# INFO:root:tot event weight 1.0354965842056243
#
# INFO:root:Finding ZJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 814 events
# INFO:root:Applying THWW>0.50 selection on 733 events
# INFO:root:Will fill the WZQQ dataframe with the remaining 7 events
# INFO:root:tot event weight 0.5901929786799543
#
# INFO:root:Finding EWKWplus_WToLNu samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 1029 events
# INFO:root:Applying THWW>0.50 selection on 819 events
# INFO:root:Will fill the EWKvjets dataframe with the remaining 45 events
# INFO:root:tot event weight 14.641050352258066
#
# INFO:root:Finding GluGluZH_HToWW_M-125_TuneCP5_13TeV-powheg-pythia8 samples and should combine them under ZH
# INFO:root:Applying fj_mass selection on 6612 events
# INFO:root:Applying THWW>0.50 selection on 5470 events
# INFO:root:Will fill the ZH dataframe with the remaining 2171 events
# INFO:root:tot event weight 0.11577301481688437
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-0To50 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 360 events
# INFO:root:Applying THWW>0.50 selection on 338 events
# INFO:root:Will fill the DYJets dataframe with the remaining 5 events
# INFO:root:tot event weight 1.6696634225774112
#
# INFO:root:Finding WJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 28 events
# INFO:root:Applying THWW>0.50 selection on 24 events
# INFO:root:Will fill the WZQQ dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 17843 events
# INFO:root:Applying THWW>0.50 selection on 15259 events
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 414 events
# INFO:root:tot event weight 209.94304525007996
#
# INFO:root:Finding SingleMuon_Run2016C_HIPM samples and should combine them under Data
# INFO:root:Applying fj_mass selection on 6972 events
# INFO:root:Applying THWW>0.50 selection on 5811 events
# INFO:root:Will fill the Data dataframe with the remaining 113 events
# INFO:root:tot event weight 113.0
#
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:Applying fj_mass selection on 5636 events
# INFO:root:Applying THWW>0.50 selection on 4737 events
# INFO:root:Will fill the ZH dataframe with the remaining 1870 events
# INFO:root:tot event weight 1.000646556504467
#
# INFO:root:Finding WZ samples and should combine them under Diboson
# INFO:root:Applying fj_mass selection on 476 events
# INFO:root:Applying THWW>0.50 selection on 374 events
# INFO:root:Will fill the Diboson dataframe with the remaining 30 events
# INFO:root:tot event weight 3.2886423291349547
#
# INFO:root:Finding SingleElectron_Run2016B_ver2_HIPM samples and should combine them under Data

# %% [markdown]
# # Add the cut to the cutflow dict

# %%
presel = {
        "mu": {
            "fj_mass": "fj_mass>40",
            "THWW>0.75": "fj_mass>40 & THWW>0.75",
        },
        "ele": {
            "fj_mass": "fj_mass>40",            
            "THWW>0.75": "fj_mass>40 & THWW>0.75",
        },
}

# %%
for ch in channels:
    for cut, sel in list(presel[ch].items()):
        for sample in samples:
            for year in years:

                df = events_dict[year][ch][sample]
                df = df.query(sel)
                
                w = df["nominal"]

                cutflows[year][ch][sample][cut] = w.sum()

# %%
cutflows["2016APV"]["mu"]["WJetsLNu"]     # take a quick look
# Out:
# {'sumgenweight': 32148205.541996155,
#  'Trigger': 5052102.989037976,
#  'METFilters': 5049012.531204127,
#  'OneLep': 5031057.850622146,
#  'NoTaus': 4271447.470579825,
#  'AtLeastOneFatJet': 461978.1002925532,
#  'CandidateJetpT': 196124.03115179407,
#  'LepInJet': 68289.06508691012,
#  'JetLepOverlap': 26003.119346261694,
#  'dPhiJetMET': 18333.833322064966,
#  'MET': 16980.930607238028,
#  'fj_mass': 560.3813816501639,
#  'THWW>0.75': 560.3813816501639}

# %%
cutflows["2016APV"]["ele"]["WJetsLNu"]     # take a quick look
# Out:
# {'sumgenweight': 32241758.10101272,
#  'Trigger': 4454643.38131529,
#  'METFilters': 4451955.991847101,
#  'OneLep': 3062734.5054372367,
#  'NoTaus': 3062734.5054372367,
#  'AtLeastOneFatJet': 364780.748501086,
#  'CandidateJetpT': 153895.86376889877,
#  'LepInJet': 58938.59730123174,
#  'JetLepOverlap': 19206.882023214886,
#  'dPhiJetMET': 13362.535289163337,
#  'MET': 12293.663142455729,
#  'fj_mass': 323.25912091618096,
#  'THWW>0.75': 323.25912091618096}

# %% [markdown]
# # Combine different channels

# %%
common_cuts = cutflows["2018"]["mu"]["WJetsLNu"]
common_cuts
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 common_cuts = cutflows["2018"]["mu"]["WJetsLNu"]
#       2 common_cuts
#
# KeyError: '2018'

# %%
def combine_channels(cutflows):

    # combine both channels
    cutflows_new = {}
    for year in cutflows.keys():
        cutflows_new[year] = {}
        cutflows_new[year]["lep"] = {}
        
        for ch in ["mu", "ele"]:
            for sample in cutflows[year][ch]:
                                
                if sample not in cutflows_new[year]["lep"]:
                    cutflows_new[year]["lep"][sample] = {}
                
                for cut in cutflows[year][ch][sample]:
                    
                    if (year != "2018") and (cut == "HEMCleaning"):
                        continue
                    
                    if cut not in cutflows_new[year]["lep"][sample]:
                        cutflows_new[year]["lep"][sample][cut] = cutflows[year][ch][sample][cut]
                    else:
                        cutflows_new[year]["lep"][sample][cut] += cutflows[year][ch][sample][cut]
        cutflows[year] = {**cutflows[year], **cutflows_new[year]}
        
    return cutflows

# %%
cutflows = combine_channels(cutflows)

# %%
cutflows["2018"].keys()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 cutflows["2018"].keys()
#
# KeyError: '2018'

# %%
cutflows["2018"]["ele"]["WJetsLNu"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 cutflows["2018"]["ele"]["WJetsLNu"]
#
# KeyError: '2018'

# %%
cutflows["2018"]["mu"]["WJetsLNu"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 cutflows["2018"]["mu"]["WJetsLNu"]
#
# KeyError: '2018'

# %%
cutflows["2018"]["lep"]["WJetsLNu"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 cutflows["2018"]["lep"]["WJetsLNu"]
#
# KeyError: '2018'

# %% [markdown]
# # Combine different years

# %%
def combine_years(cutflows):
    """Will remove the HEM cleaning cutflow from 2018 first."""
    
    whatever_year = list(cutflows.keys())[0]
    channels = cutflows[whatever_year].keys()
    
    # combine all years
    cutflows_new = {}
    cutflows_new["Run2"] = {}
    
    for ch in channels:
        cutflows_new["Run2"][ch] = {}
        
        for year in cutflows:
            for sample in cutflows[year][ch]:
                
                if sample not in cutflows_new["Run2"][ch]:
                    cutflows_new["Run2"][ch][sample] = {}

                for cut in cutflows[year][ch][sample]:
                    if "HEM" in cut:
                        continue
                    if cut not in cutflows_new["Run2"][ch][sample]:
                        cutflows_new["Run2"][ch][sample][cut] = cutflows[year][ch][sample][cut]
                    else:
                        cutflows_new["Run2"][ch][sample][cut] += cutflows[year][ch][sample][cut]

    cutflows = {**cutflows, **cutflows_new}

    return cutflows

# %%
cutflows = combine_years(cutflows)

# %%
cutflows["2016"]["ele"].keys()
# Out:
# dict_keys(['VBF', 'WJetsLNu', 'EWKvjets', 'WH', 'TTbar', 'Data', 'SingleTop', 'ggF', 'DYJets', 'Diboson', 'WZQQ', 'ttH', 'ZH'])

# %%
cutflows.keys()
# Out:
# dict_keys(['2016', '2016APV', 'Run2'])

# %%
cutflows["Run2"].keys()
# Out:
# dict_keys(['ele', 'mu', 'lep'])

# %% [markdown]
# # Combine non-dominant backgrounds

# %%
# combine non-dominant backgrounds under others
dominant_bkgs = ["WJetsLNu", "TTbar"]
signals = ["ggF", "VH", "WH", "ZH", "ttH"]

for year in cutflows:
    for ch in cutflows[year]:
        cutflows[year][ch]["Others"] = dict.fromkeys(cutflows[year][ch]["WJetsLNu"], 0)
        for sample in cutflows[year][ch]:
            if sample == "Data":
                continue
            if sample not in signals+dominant_bkgs:
                for cut in cutflows[year][ch][sample]:
                    cutflows[year][ch]["Others"][cut] += cutflows[year][ch][sample][cut]

# %%
cutflows["2018"]["ele"].keys()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 cutflows["2018"]["ele"].keys()
#
# KeyError: '2018'

# %%
cutflows["2018"]["lep"]["Others"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 cutflows["2018"]["lep"]["Others"]
#
# KeyError: '2018'

# %% [markdown]
# # LateX cutflow table

# %%
cuts = [
    "sumgenweight",
    "Trigger",
    "METFilters",
    "OneLep",        
    "NoTaus",
    "AtLeastOneFatJet",
    "CandidateJetpT",
    "LepInJet",
    "JetLepOverlap",
    "dPhiJetMET",
    "MET",
    "HEMCleaning",
]

for cut in presel["mu"]:
    cuts += [cut]

# %%
cut_to_label = {
    "sumgenweight": "sumgenweight",        
    "HEMCleaning": "HEMCleaning",    
    "Trigger": "Trigger",
    "METFilters": "METFilters",
    "OneLep": "n Leptons = 1",
    "NoTaus": "n Taus = 0",
    "AtLeastOneFatJet": r"n FatJets $>=$ 1",
    "CandidateJetpT": r"j $p_T > 250$GeV",
    "LepInJet": r"$\Delta R(j, \ell) < 0.8$",
    "JetLepOverlap": r"$\Delta R(j, \ell) > 0.03$",
    "dPhiJetMET": r"$\Delta \phi(\mathrm{MET}, j)<1.57$",
    "MET": r"$\mathrm{MET}>20$",
    
    "None": "None",

    "fj_mass": r"j $\mathrm{softdrop} > 40$GeV",
    
    "THWW>0.75": r"$\ensuremath{T_{\text{HWW}}^{\ell\nu qq}} > 0.75$",
}

# %%
parquet_to_latex = {
    "WJetsLNu": "$\PW(\Pell\PGn)$+",
    "TTbar": "\\ttbar",
    "Others": "Other MC",

    "ggF": "ggF",
    "VBF": "VBF",
    "WH": "WH",
    "ZH": "ZH",    
    "ttH": "$t\\bar{t}H$",    
    
    "Data": "Data",
}

def make_latex_cutflow_table(cutflows_dict, year, ch, add_data=False, add_sumgenweight=False):
    """Will use the cutflows dictionary to make the LateX table we have in the AN."""
    
    samples_bkg = ["WJetsLNu", "TTbar", "Others"]
    samples_sig = ["ggF","VBF", "WH", "ZH", "ttH"]

    ### backgrounds
    headers = [parquet_to_latex[s] for s in samples_bkg]
    
    textabular = f"l{'r'*len(headers)}"
    textabular += "|r"
    
    texheader = "\\textbf{Inclusive Selection}" + " & " + " & ".join(headers) + " & Total MC "
    if add_data:
        textabular += "|r"
        texheader += "& Data "
    texheader += "\\\\"
    texdata = "\\hline\n"
    
    data = dict()
    
    for cut in cuts: 
        if (year != "2018") and (cut == "HEMCleaning"):
            continue
            
        if not add_sumgenweight and cut == "sumgenweight":
            continue
    
        data[cut] = []

        for sample in samples_bkg:            
            data[cut].append(round(cutflows_dict[year][ch][sample][cut]))
            
        totalmc = 0
        for sample in (samples_bkg + samples_sig):
            totalmc += round(cutflows_dict[year][ch][sample][cut])
            
        data[cut].append(totalmc)
        
        if add_data:
            data[cut].append(round(cutflows_dict[year][ch]["Data"][cut]))

    for label in data:
        if label == "z":
            texdata += "\\hline\n"
        texdata += f"{cut_to_label[label]} & {' & '.join(map(str,data[label]))} \\\\\n"
        
    texdata += "\\hline\n"    

    ### signal
    headers2 = [parquet_to_latex[s] for s in samples_sig]
    texheader2 = " & " + " & ".join(headers2) + "\\\\"
    texdata2 = "\\hline\n"

    textabular2 = f"l{'r'*len(headers2)}"
    
    data = dict()
    for cut in cuts:
        if (year != "2018") and (cut == "HEMCleaning"):
            continue
            
        data[cut] = []

        for sample in samples_sig:
            data[cut].append(round(cutflows_dict[year][ch][sample][cut]))
        
    for label in data:
        if label == "z":
            texdata += "\\hline\n"
        texdata2 += f"{cut_to_label[label]} & {' & '.join(map(str,data[label]))} \\\\\n"    

    # make table
    print("\\begin{table}[!htp]")
    print("\\begin{center}")
    
    print("\\begin{tabular}{"+textabular+"}")
    print(texheader)
    print(texdata,end="")
    print("\\end{tabular}")

    print("\\begin{tabular}{"+textabular2+"}")
    print(texheader2)
    print(texdata2,end="")
    print("\\end{tabular}")
    
    
    if ch == "lep":
        print("\\caption{Event yield of " + year + " Monte Carlo samples normalized to " + str(round(get_lumi([year], [ch]))) + "\\fbinv.}")        
    else:
        print("\\caption{Event yield of " + ch + " channel " + year + " Monte Carlo samples normalized to " + str(round(get_lumi([year], [ch]))) + "\\fbinv.}")
        
    print("\\label{sel-tab-cutflow" + year + "}")
    print("\\end{center}")
    print("\\end{table}")

# %%
make_latex_cutflow_table(cutflows, "2016", "lep", add_data=True, add_sumgenweight=True)
# Out:
# \begin{table}[!htp]
# \begin{center}
# \begin{tabular}{lrrr|r|r}
# \textbf{Inclusive Selection} & $\PW(\Pell\PGn)$+ & \ttbar & Other MC & Total MC & Data \\
# \hline
# sumgenweight & 34495755 & 27964378 & 206072910 & 268588181 & 615115660 \\
# Trigger & 5073520 & 3014113 & 30758671 & 38851228 & 340441292 \\
# METFilters & 5070260 & 3011980 & 30743881 & 38831040 & 340346213 \\
# n Leptons = 1 & 3898866 & 2429647 & 19258350 & 25590602 & 174430987 \\
# n Taus = 0 & 3737633 & 1940154 & 17943360 & 23624147 & 168036783 \\
# n FatJets $>=$ 1 & 700000 & 355885 & 497342 & 1553908 & 1928098 \\
# j $p_T > 250$GeV & 317487 & 177748 & 223761 & 719364 & 765173 \\
# $\Delta R(j, \ell) < 0.8$ & 113857 & 77714 & 107066 & 298829 & 382488 \\
# $\Delta R(j, \ell) > 0.03$ & 41009 & 67736 & 42216 & 151134 & 175116 \\
# $\Delta \phi(\mathrm{MET}, j)<1.57$ & 28841 & 43044 & 25441 & 97444 & 97479 \\
# $\mathrm{MET}>20$ & 26663 & 40342 & 21242 & 88355 & 87106 \\
# j $\mathrm{softdrop} > 40$GeV & 784 & 356 & 284 & 1448 & 1282 \\
# $\ensuremath{T_{\text{HWW}}^{\ell\nu qq}} > 0.75$ & 784 & 356 & 284 & 1448 & 1282 \\
# \hline
# \end{tabular}
# \begin{tabular}{lrrrrr}
#  & ggF & VBF & WH & ZH & $t\bar{t}H$\\
# \hline
# sumgenweight & 3388 & 27173 & 10177 & 7336 & 7064 \\
# Trigger & 359 & 1810 & 1081 & 621 & 1053 \\
# METFilters & 359 & 1808 & 1080 & 620 & 1052 \\
# n Leptons = 1 & 282 & 1423 & 829 & 434 & 771 \\
# n Taus = 0 & 245 & 1199 & 667 & 356 & 533 \\
# n FatJets $>=$ 1 & 204 & 118 & 76 & 43 & 240 \\
# j $p_T > 250$GeV & 114 & 53 & 39 & 22 & 140 \\
# $\Delta R(j, \ell) < 0.8$ & 67 & 30 & 18 & 13 & 64 \\
# $\Delta R(j, \ell) > 0.03$ & 63 & 28 & 12 & 11 & 59 \\
# $\Delta \phi(\mathrm{MET}, j)<1.57$ & 46 & 21 & 8 & 6 & 37 \\
# $\mathrm{MET}>20$ & 41 & 18 & 8 & 6 & 35 \\
# j $\mathrm{softdrop} > 40$GeV & 13 & 5 & 2 & 2 & 2 \\
# $\ensuremath{T_{\text{HWW}}^{\ell\nu qq}} > 0.75$ & 13 & 5 & 2 & 2 & 2 \\
# \end{tabular}
# \caption{Event yield of 2016 Monte Carlo samples normalized to 17\fbinv.}
# \label{sel-tab-cutflow2016}
# \end{center}
# \end{table}
