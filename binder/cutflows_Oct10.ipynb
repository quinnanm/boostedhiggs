# %% [markdown]
# # Compute the LateX cutflow tables
# - Will load the pkl files that contain the cutflows and the sumgenweight
# - Will scale the events by the cross section
# - Will save the yields in a dictionnary called ```cutflows -> Dict()```
# - Will make the LateX table using the function ```make_composition_table()```

# %%
import glob
import json
import os
import pickle as pkl
import sys

import hist as hist2
import matplotlib.pyplot as plt
import mplhep as hep
import numpy as np
import pandas as pd
import pyarrow
import pyarrow.parquet as pq
import yaml
from scipy.special import softmax
from sklearn.metrics import auc, roc_curve

sys.path
sys.path.append("../python/")

import utils

plt.style.use(hep.style.CMS)
plt.rcParams.update({"font.size": 20})

pd.options.mode.chained_assignment = None

import glob
import os
import json
import pickle
import yaml
import math

import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None
import pyarrow.parquet as pq
from sklearn.metrics import auc, roc_curve
from scipy.special import softmax

import hist as hist2
import matplotlib.pyplot as plt
import mplhep as hep

plt.style.use(hep.style.CMS)

import sys
sys.path
sys.path.append("../python/")

import utils

plt.rcParams.update({"font.size": 20})

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# get lumi
with open("../fileset/luminosity.json") as f:
    luminosity = json.load(f)
    
luminosity
# Out:
# {'ele': {'Run2': 137640.0,
#   '2016APV': 19492.72,
#   '2016': 16809.96,
#   '2017': 41476.02,
#   '2018': 59816.23},
#  'mu': {'Run2': 137640.0,
#   '2016APV': 19436.16,
#   '2016': 16810.81,
#   '2017': 41475.26,
#   '2018': 59781.96},
#  'lep': {'Run2': 137640.0,
#   '2016APV': 19436.16,
#   '2016': 16810.81,
#   '2017': 41475.26,
#   '2018': 59781.96},
#  'had': {'Run2': 137640.0,
#   '2016APV': 19436.16,
#   '2016': 16810.81,
#   '2017': 41475.26,
#   '2018': 59781.96}}

# %%
def get_lumi(years, channels):
    lum_ = 0
    for year in years:
        lum = 0
        for ch in channels:
            lum += luminosity[ch][year] / 1000.0

        lum_ += lum / len(channels)    
    return lum_

# %% [markdown]
# # Read cutflows from pkl

# %%
def get_sum_sumgenweight(pkl_files, year, sample):
    """Load and sum the sumgenweight of each pkl file."""
    
    sum_sumgenweight = 0
    for ifile in pkl_files:
        with open(ifile, "rb") as f:
            metadata = pkl.load(f)            
        sum_sumgenweight = sum_sumgenweight + metadata[sample][year]["sumgenweight"]

    return sum_sumgenweight


def get_xsecweight(pkl_files, year, ch, sample, is_data):
    
    if not is_data:
        # find xsection
        f = open("../fileset/xsec_pfnano.json")
        xsec = json.load(f)
        f.close()
        try:
            xsec = eval(str((xsec[sample])))
        except ValueError:
            print(f"sample {sample} doesn't have xsecs defined in xsec_pfnano.json so will skip it")
            return None

        # get overall weighting of events.. each event has a genweight...
        # sumgenweight sums over events in a chunk... sum_sumgenweight sums over chunks
        xsec_weight = (xsec * luminosity[ch][year]) / get_sum_sumgenweight(pkl_files, year, sample)
    else:
        xsec_weight = 1
    return xsec_weight

def get_cutflow(pkl_files, year, ch, sample, is_data):
    """
    Get cutflow from metadata but multiply by xsec-weight
    """
    xsec_weight = get_xsecweight(pkl_files, year, ch, sample, is_data)
        
    cuts = [
        "sumgenweight",
        "Trigger",
        "METFilters",
        "OneLep",
        "NoTaus",
        "AtLeastOneFatJet",
        "CandidateJetpT",
        "LepInJet",
        "JetLepOverlap",
        "dPhiJetMET",
        "MET",
    ]
        
    if year == "2018":
        cuts += ["HEMCleaning"]
        
    evyield = dict.fromkeys(cuts, 0)
    for ik, pkl_file in enumerate(pkl_files):
        with open(pkl_file, "rb") as f:
            metadata = pkl.load(f)
            
        cutflows = metadata[sample][year]["cutflows"][ch]

        for key in evyield.keys():

            if key == "sumgenweight":
                evyield[key] += metadata[sample][year][key] * xsec_weight
            else:
                evyield[key] += cutflows[key] * xsec_weight        
    return evyield

# %%
! ls ../eos/July18_hww_2016APV/WJetsToLNu_HT-100To200/outfiles/0-10.pkl
# Out:
# ../eos/July18_hww_2016APV/WJetsToLNu_HT-100To200/outfiles/0-10.pkl

# %%
with open("../eos/Oct10_hww_2016APV/WJetsToLNu_HT-100To200/outfiles/0-10.pkl", "rb") as f:
    metadata = pkl.load(f)
metadata
# Out:
# {'WJetsToLNu_HT-100To200': {'mc': 149,
#   '2016APV': {'sumgenweight': 1492951.0,
#    'sumlheweight': {0: 1551137.2,
#     1: 1551799.4,
#     2: 1541534.8,
#     3: 1491997.6,
#     4: 1492951.0,
#     5: 1483308.9,
#     6: 1443469.5,
#     7: 1444666.2,
#     8: 1435536.2},
#    'sumpdfweight': {0: 1492951.0,
#     1: 1494297.1,
#     2: 1492237.6,
#     3: 1494463.2,
#     4: 1493804.0,
#     5: 1494341.9,
#     6: 1493538.8,
#     7: 1494321.6,
#     8: 1493813.9,
#     9: 1493034.2,
#     10: 1492469.5,
#     11: 1491638.0,
#     12: 1493345.8,
#     13: 1493301.8,
#     14: 1492837.2,
#     15: 1493383.9,
#     16: 1492520.0,
#     17: 1492682.9,
#     18: 1492891.5,
#     19: 1492741.8,
#     20: 1493447.0,
#     21: 1493083.9,
#     22: 1493360.1,
#     23: 1492864.5,
#     24: 1493688.5,
#     25: 1493356.0,
#     26: 1493390.6,
#     27: 1493141.5,
#     28: 1493313.1,
#     29: 1494101.6,
#     30: 1493643.0,
#     31: 1494384.6,
#     32: 1493172.6,
#     33: 1494015.9,
#     34: 1493571.5,
#     35: 1492720.9,
#     36: 1492159.4,
#     37: 1493126.9,
#     38: 1493509.5,
#     39: 1491891.2,
#     40: 1492621.4,
#     41: 1493915.8,
#     42: 1491517.1,
#     43: 1492308.4,
#     44: 1492010.8,
#     45: 1492316.1,
#     46: 1491960.8,
#     47: 1492369.5,
#     48: 1493450.2,
#     49: 1492499.0,
#     50: 1492522.1,
#     51: 1493222.4,
#     52: 1492974.9,
#     53: 1493208.9,
#     54: 1493169.8,
#     55: 1493387.2,
#     56: 1493377.5,
#     57: 1492569.4,
#     58: 1492951.9,
#     59: 1493494.1,
#     60: 1493014.1,
#     61: 1493080.5,
#     62: 1493337.8,
#     63: 1492692.5,
#     64: 1493837.2,
#     65: 1493077.9,
#     66: 1493159.1,
#     67: 1493449.5,
#     68: 1493156.2,
#     69: 1493187.1,
#     70: 1492545.9,
#     71: 1493067.8,
#     72: 1493194.2,
#     73: 1493110.5,
#     74: 1492923.9,
#     75: 1492582.1,
#     76: 1492782.4,
#     77: 1493712.2,
#     78: 1492857.5,
#     79: 1492556.6,
#     80: 1492880.5,
#     81: 1492874.1,
#     82: 1493021.2,
#     83: 1492623.9,
#     84: 1493190.1,
#     85: 1492886.1,
#     86: 1492868.5,
#     87: 1493052.1,
#     88: 1493276.9,
#     89: 1493087.6,
#     90: 1493099.9,
#     91: 1493063.8,
#     92: 1492965.5,
#     93: 1492983.4,
#     94: 1492643.6,
#     95: 1492860.8,
#     96: 1492725.5,
#     97: 1492941.6,
#     98: 1492949.1,
#     99: 1492890.2,
#     100: 1492951.0,
#     101: 1421697.9,
#     102: 1562486.0},
#    'cutflows': {'ele': {'PU_cutoff': 1492951.0,
#      'Trigger': 198848.0,
#      'METFilters': 198767.0,
#      'OneLep': 136324.0,
#      'NoTaus': 136324.0,
#      'AtLeastOneFatJet': 1854.0,
#      'CandidateJetpT': 53.0,
#      'LepInJet': 38.0,
#      'JetLepOverlap': 5.0,
#      'dPhiJetMET': 1.0,
#      'MET': 0.0},
#     'mu': {'PU_cutoff': 1492951.0,
#      'Trigger': 228311.0,
#      'METFilters': 228203.0,
#      'OneLep': 227602.0,
#      'NoTaus': 192965.0,
#      'AtLeastOneFatJet': 2406.0,
#      'CandidateJetpT': 86.0,
#      'LepInJet': 67.0,
#      'JetLepOverlap': 9.0,
#      'dPhiJetMET': 3.0,
#      'MET': 3.0}}}}}

# %% [markdown]
# # Adding a cut from the parquets

# %%
### This is your configuration. specefy which channels, years, samples, and directory of pkl files to use.
channels = [
    "ele", 
    "mu",
]
years = [
    "2018", 
    "2017",
    "2016", 
    "2016APV",
]

samples = [
    "ggF", 
    "VBF",  
    "WH",
    "ZH",    
    "ttH",
    "WJetsLNu",
    "TTbar",
    "SingleTop",
    "Diboson",
    "EWKvjets",
    "DYJets",
    "WZQQ",
    "Data",
]

samples_dir = {
    "2016":    "../eos/Oct10_hww_2016",
    "2016APV": "../eos/Oct10_hww_2016APV",    
    "2017":    "../eos/Oct10_hww_2017",    
    "2018":    "../eos/Oct10_hww_2018",    
}

# %%
df["xsecweight"]
# Out:
# 1       0.000583
# 2       0.000583
# 10      0.000583
# 12      0.000583
# 19      0.000583
#           ...
# 5623    0.000583
# 5624    0.000583
# 5625    0.000583
# 5633    0.000583
# 5635    0.000583
# Name: xsecweight, Length: 1870, dtype: float64

# %%
df["nominal"]
# Out:
# 1       0.000618
# 2       0.000394
# 10      0.000625
# 12      0.000560
# 19      0.000607
#           ...
# 5623    0.000608
# 5624    0.000327
# 5625    0.000582
# 5633    0.000600
# 5635    0.000625
# Name: nominal, Length: 1870, dtype: float64

# %%
cutflows = {}
for year in years:
#     if year != "2016":
#         continue
    print(f"Processing year {year}")
    
    cutflows[year] = {}
    
    for ch in channels:
#         if ch != "mu": 
#             continue
        
        print(f"  {ch} channel")
        cutflows[year][ch] = {}

        condor_dir = os.listdir(samples_dir[year])

        for sample in condor_dir:

            # first: check if the sample is in one of combine_samples_by_name
            sample_to_use = None
            for key in utils.combine_samples_by_name:
                if key in sample:
                    sample_to_use = utils.combine_samples_by_name[key]
                    break

            # second: if not, combine under common label
            if sample_to_use is None:
                for key in utils.combine_samples:
                    if key in sample:
                        sample_to_use = utils.combine_samples[key]
                        break
                    else:
                        sample_to_use = sample

            if sample_to_use not in samples:
                continue

            is_data = False
            if sample_to_use == "Data":
                is_data = True

            out_files = f"{samples_dir[year]}/{sample}/outfiles/"
            pkl_files = glob.glob(f"{out_files}/*.pkl")

            if len(pkl_files) == 0:
                continue

            parquet_files = glob.glob(f"{out_files}/*_{ch}.parquet")
            
            try:
                data = pd.read_parquet(parquet_files)
            except pyarrow.lib.ArrowInvalid:
                # empty parquet because no event passed selection
#                 print(f"No parquet file for {sample}")
                continue

            if len(data) == 0:
#                 print(f"Hi, No parquet file for {sample}")
                continue
    
            if sample_to_use not in cutflows[year][ch].keys():
                cutflows[year][ch][sample_to_use] = get_cutflow(pkl_files, year, ch, sample, is_data)
            else:
                temp = get_cutflow(pkl_files, year, ch, sample, is_data)
                for key in cutflows[year][ch][sample_to_use]:
                    cutflows[year][ch][sample_to_use][key] += temp[key]
            
    print(f"------------------------------------------")
# Out:
# Processing year 2018
#   ele channel
#   mu channel
# ------------------------------------------
# Processing year 2017
#   ele channel
#   mu channel
# ------------------------------------------
# Processing year 2016
#   ele channel
#   mu channel
# ------------------------------------------
# Processing year 2016APV
#   ele channel
#   mu channel
# ------------------------------------------

# %%
samples = cutflows["2017"]["ele"].keys()  # samples
samples
# Out:
# dict_keys(['VBF', 'WJetsLNu', 'EWKvjets', 'WH', 'TTbar', 'SingleTop', 'ggF', 'DYJets', 'Data', 'Diboson', 'WZQQ', 'ttH', 'ZH'])

# %%
from make_stacked_hists import make_events_dict

presel = {
        "mu": {
#             "fj_mass": "fj_mass>40",
#             "THWW>0.75": "THWW>0.750",
        },
        "ele": {
#             "fj_mass": "fj_mass>40",
#             "THWW>0.75": "THWW>0.750",
        },
}

THWW_path = "../../weaver-core-dev/experiments_finetuning/v35_30/model.onnx"

events_dict = make_events_dict(years, channels, samples_dir, samples, presel, THWW_path)
# Out:
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:Will fill the VBF dataframe with the remaining 1601 events
# INFO:root:tot event weight 25.613311877416795
#
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 57 events
# INFO:root:tot event weight 126.30860134877776
#
# INFO:root:Finding EWKWminus_WToLNu samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 2069 events
# INFO:root:tot event weight 881.62056583208
#
# INFO:root:Finding EWKZ_ZToNuNu samples and should combine them under EWKvjets
# INFO:root:Finding fake_2018_mu_EWK_SF_Up.parquet samples and should combine them under EWKvjets
# INFO:root:No parquet file for fake_2018_mu_EWK_SF_Up.parquet
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Will fill the WH dataframe with the remaining 5590 events
# INFO:root:tot event weight 3.9852056605721935
#
# INFO:root:Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 161245 events
# INFO:root:tot event weight 9172.828639396193
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 356603 events
# INFO:root:tot event weight 53752.55199620239
#
# INFO:root:Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 31662 events
# INFO:root:tot event weight 994.3147927384935
#
# INFO:root:Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# INFO:root:Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 191894 events
# INFO:root:tot event weight 2810.8541213427197
#
# INFO:root:Finding EWKZ_ZToLL samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 907 events
# INFO:root:tot event weight 335.82800060537204
#
# INFO:root:Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 20283 events
# INFO:root:tot event weight 10139.438258638136
#
# INFO:root:Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 5477 events
# INFO:root:tot event weight 1322.0962934270106
#
# INFO:root:Finding GluGluHToWWToLNuQQ_M-125_TuneCP5_13TeV_powheg_jhugen751_pythia8 samples and should combine them under ggF
# INFO:root:Will fill the ggF dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:Will fill the ggF dataframe with the remaining 4679 events
# INFO:root:tot event weight 55.781310755475886
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-650ToInf samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 220597 events
# INFO:root:tot event weight 132.52293167742766
#
# INFO:root:Finding WJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 5306 events
# INFO:root:tot event weight 1322.2516077295913
#
# INFO:root:Finding ZJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding fake_2018_ele_EWK_SF_Up.parquet samples and should combine them under EWKvjets
# INFO:root:No parquet file for fake_2018_ele_EWK_SF_Up.parquet
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Will fill the WH dataframe with the remaining 6219 events
# INFO:root:tot event weight 7.642533180999573
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-100To250 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 64445 events
# INFO:root:tot event weight 4518.314075830994
#
# INFO:root:Finding EGamma_Run2018A samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 32586 events
# INFO:root:tot event weight 32586.0
#
# INFO:root:Finding fake_2018_mu_EWK_SF_Down.parquet samples and should combine them under EWKvjets
# INFO:root:No parquet file for fake_2018_mu_EWK_SF_Down.parquet
# INFO:root:Finding EWKWplus_WToQQ samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 94 events
# INFO:root:tot event weight 13.305509908756312
#
# INFO:root:Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 17488 events
# INFO:root:tot event weight 58.07600996383873
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-50To100 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 3969 events
# INFO:root:tot event weight 867.2937068242144
#
# INFO:root:Finding SingleMuon_Run2018A samples and should combine them under Data
# INFO:root:Finding WW samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 595 events
# INFO:root:tot event weight 638.6256753082617
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-250To400 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 710464 events
# INFO:root:tot event weight 5838.349454646785
#
# INFO:root:Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 12290 events
# INFO:root:tot event weight 433.33487848478285
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 128501 events
# INFO:root:tot event weight 6055.5206676625
#
# INFO:root:Finding EWKZ_ZToQQ samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 1 events
# INFO:root:tot event weight 3.91923286649798
#
# INFO:root:Finding ZJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 58 events
# INFO:root:tot event weight 44.12203672981981
#
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 312 events
# INFO:root:tot event weight 82.67058125269736
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 652 events
# INFO:root:tot event weight 134.07446749917008
#
# INFO:root:Finding WJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 767 events
# INFO:root:tot event weight 138.01170103569956
#
# INFO:root:Finding fake_2018_ele_EWK_SF_Down.parquet samples and should combine them under EWKvjets
# INFO:root:No parquet file for fake_2018_ele_EWK_SF_Down.parquet
# INFO:root:Finding ZJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 333 events
# INFO:root:tot event weight 64.51741328308194
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-400To650 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 198722 events
# INFO:root:tot event weight 1444.5003501020515
#
# INFO:root:Finding EWKWminus_WToQQ samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 68 events
# INFO:root:tot event weight 7.64821618598643
#
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 107379 events
# INFO:root:tot event weight 14277.029136636776
#
# INFO:root:Finding WJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 456 events
# INFO:root:tot event weight 175.1663824111345
#
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 62435 events
# INFO:root:tot event weight 22.96116749615988
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Will fill the ttH dataframe with the remaining 5879 events
# INFO:root:tot event weight 35.14049157748235
#
# INFO:root:Finding ZJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 512 events
# INFO:root:tot event weight 61.299457382969194
#
# INFO:root:Finding EGamma_Run2018C samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 15261 events
# INFO:root:tot event weight 15261.0
#
# INFO:root:Finding EGamma_Run2018D samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 69925 events
# INFO:root:tot event weight 69925.0
#
# INFO:root:Finding EWKWplus_WToLNu samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 1792 events
# INFO:root:tot event weight 924.9605700855368
#
# INFO:root:Finding EGamma_Run2018B samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 16456 events
# INFO:root:tot event weight 16456.0
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-0To50 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 992 events
# INFO:root:tot event weight 444.44090969731815
#
# INFO:root:Finding SingleMuon_Run2018C samples and should combine them under Data
# INFO:root:Finding WJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 64 events
# INFO:root:tot event weight 194.9445517188456
#
# INFO:root:Finding SingleMuon_Run2018D samples and should combine them under Data
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 46190 events
# INFO:root:tot event weight 23404.961644559364
#
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:Will fill the ZH dataframe with the remaining 9317 events
# INFO:root:tot event weight 7.857694752244376
#
# INFO:root:Finding WZ samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 704 events
# INFO:root:tot event weight 246.76810375696294
#
# INFO:root:Finding SingleMuon_Run2018B samples and should combine them under Data
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:Will fill the VBF dataframe with the remaining 2473 events
# INFO:root:tot event weight 39.093589361903085
#
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 74 events
# INFO:root:tot event weight 161.41535567575173
#
# INFO:root:Finding EWKWminus_WToLNu samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 2296 events
# INFO:root:tot event weight 965.1569302190219
#
# INFO:root:Finding EWKZ_ZToNuNu samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 3 events
# INFO:root:tot event weight 0.6259324406698612
#
# INFO:root:Finding fake_2018_mu_EWK_SF_Up.parquet samples and should combine them under EWKvjets
# INFO:root:No parquet file for fake_2018_mu_EWK_SF_Up.parquet
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Will fill the WH dataframe with the remaining 7423 events
# INFO:root:tot event weight 5.260047330127025
#
# INFO:root:Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 222468 events
# INFO:root:tot event weight 12595.822651018278
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 402515 events
# INFO:root:tot event weight 59744.15470073567
#
# INFO:root:Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 49730 events
# INFO:root:tot event weight 1543.467733597804
#
# INFO:root:Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 311 events
# INFO:root:tot event weight 2.49318427082235
#
# INFO:root:Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 272785 events
# INFO:root:tot event weight 3982.766939000062
#
# INFO:root:Finding EWKZ_ZToLL samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 396 events
# INFO:root:tot event weight 144.4894976106733
#
# INFO:root:Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 23295 events
# INFO:root:tot event weight 11585.371206736985
#
# INFO:root:Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 6077 events
# INFO:root:tot event weight 1448.8180693851723
#
# INFO:root:Finding GluGluHToWWToLNuQQ_M-125_TuneCP5_13TeV_powheg_jhugen751_pythia8 samples and should combine them under ggF
# INFO:root:Will fill the ggF dataframe with the remaining 2 events
# INFO:root:tot event weight 1.331892000395285
#
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:Will fill the ggF dataframe with the remaining 7238 events
# INFO:root:tot event weight 85.37949444243593
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-650ToInf samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 116456 events
# INFO:root:tot event weight 69.27984700233736
#
# INFO:root:Finding WJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 5845 events
# INFO:root:tot event weight 1434.303800313341
#
# INFO:root:Finding ZJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding fake_2018_ele_EWK_SF_Up.parquet samples and should combine them under EWKvjets
# INFO:root:No parquet file for fake_2018_ele_EWK_SF_Up.parquet
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Will fill the WH dataframe with the remaining 8427 events
# INFO:root:tot event weight 10.207260159860956
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-100To250 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 43512 events
# INFO:root:tot event weight 3095.0458133307134
#
# INFO:root:Finding EGamma_Run2018A samples and should combine them under Data
# INFO:root:Finding fake_2018_mu_EWK_SF_Down.parquet samples and should combine them under EWKvjets
# INFO:root:No parquet file for fake_2018_mu_EWK_SF_Down.parquet
# INFO:root:Finding EWKWplus_WToQQ samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 213 events
# INFO:root:tot event weight 29.921073439704777
#
# INFO:root:Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 25487 events
# INFO:root:tot event weight 83.1386749404649
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-50To100 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 4479 events
# INFO:root:tot event weight 945.5806119089019
#
# INFO:root:Finding SingleMuon_Run2018A samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 40106 events
# INFO:root:tot event weight 40106.0
# INFO:root:Finding WW samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 624 events
# INFO:root:tot event weight 661.3145558679895
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-250To400 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 165755 events
# INFO:root:tot event weight 1317.4916547823514
#
# INFO:root:Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 19318 events
# INFO:root:tot event weight 667.5982563083757
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 109127 events
# INFO:root:tot event weight 5088.6265446193775
#
# INFO:root:Finding EWKZ_ZToQQ samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 5 events
# INFO:root:tot event weight 15.827615865241098
#
# INFO:root:Finding ZJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 99 events
# INFO:root:tot event weight 72.28292072629712
#
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 160 events
# INFO:root:tot event weight 41.525588043989636
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 3327 events
# INFO:root:tot event weight 657.0268545135393
#
# INFO:root:Finding WJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 1172 events
# INFO:root:tot event weight 200.53838197072787
#
# INFO:root:Finding fake_2018_ele_EWK_SF_Down.parquet samples and should combine them under EWKvjets
# INFO:root:No parquet file for fake_2018_ele_EWK_SF_Down.parquet
# INFO:root:Finding ZJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 1004 events
# INFO:root:tot event weight 187.05518559084484
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-400To650 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 47341 events
# INFO:root:tot event weight 342.19279896419505
#
# INFO:root:Finding EWKWminus_WToQQ samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 110 events
# INFO:root:tot event weight 12.150436071812452
#
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 145423 events
# INFO:root:tot event weight 19220.120141443516
#
# INFO:root:Finding WJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 437 events
# INFO:root:tot event weight 161.79267414875244
#
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 89377 events
# INFO:root:tot event weight 32.73341807004747
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Will fill the ttH dataframe with the remaining 5720 events
# INFO:root:tot event weight 33.082708376763804
#
# INFO:root:Finding ZJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 1871 events
# INFO:root:tot event weight 209.2191903284076
#
# INFO:root:Finding EGamma_Run2018C samples and should combine them under Data
# INFO:root:Finding EGamma_Run2018D samples and should combine them under Data
# INFO:root:Finding EWKWplus_WToLNu samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 2257 events
# INFO:root:tot event weight 1151.8723827240135
#
# INFO:root:Finding EGamma_Run2018B samples and should combine them under Data
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-0To50 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 833 events
# INFO:root:tot event weight 324.8404458077512
#
# INFO:root:Finding SingleMuon_Run2018C samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 18506 events
# INFO:root:tot event weight 18506.0
#
# INFO:root:Finding WJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Finding SingleMuon_Run2018D samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 85292 events
# INFO:root:tot event weight 85292.0
#
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 59085 events
# INFO:root:tot event weight 29739.95212508256
#
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:Will fill the ZH dataframe with the remaining 11735 events
# INFO:root:tot event weight 9.752818133599014
#
# INFO:root:Finding WZ samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 468 events
# INFO:root:tot event weight 161.75386009440746
#
# INFO:root:Finding SingleMuon_Run2018B samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 20087 events
# INFO:root:tot event weight 20087.0
#
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:Will fill the VBF dataframe with the remaining 1717 events
# INFO:root:tot event weight 17.005345264367623
#
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 83 events
# INFO:root:tot event weight 125.86210797339875
#
# INFO:root:Finding fake_2017_mu_EWK_SF_Down.parquet samples and should combine them under EWKvjets
# INFO:root:No parquet file for fake_2017_mu_EWK_SF_Down.parquet
# INFO:root:Finding fake_2017_mu_EWK_SF_Up.parquet samples and should combine them under EWKvjets
# INFO:root:No parquet file for fake_2017_mu_EWK_SF_Up.parquet
# INFO:root:Finding EWKWminus_WToLNu samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 1926 events
# INFO:root:tot event weight 588.6257331430671
#
# INFO:root:Finding EWKZ_ZToNuNu samples and should combine them under EWKvjets
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Will fill the WH dataframe with the remaining 4025 events
# INFO:root:tot event weight 2.72200673325456
#
# INFO:root:Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 111347 events
# INFO:root:tot event weight 5994.65368724613
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 354475 events
# INFO:root:tot event weight 36910.73170885753
#
# INFO:root:Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 23439 events
# INFO:root:tot event weight 638.1955079669372
#
# INFO:root:Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 34 events
# INFO:root:tot event weight 0.2510139320125857
#
# INFO:root:Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 120664 events
# INFO:root:tot event weight 1872.3623865020595
#
# INFO:root:Finding EWKZ_ZToLL samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 557 events
# INFO:root:tot event weight 219.07732125197197
#
# INFO:root:Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 18401 events
# INFO:root:tot event weight 7594.737120120749
#
# INFO:root:Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 4036 events
# INFO:root:tot event weight 914.3763829556749
#
# INFO:root:Finding GluGluHToWWToLNuQQ_M-125_TuneCP5_13TeV_powheg_jhugen751_pythia8 samples and should combine them under ggF
# INFO:root:Will fill the ggF dataframe with the remaining 1 events
# INFO:root:tot event weight 0.6687053205537946
#
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:Will fill the ggF dataframe with the remaining 4809 events
# INFO:root:tot event weight 37.83235012135305
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-650ToInf samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 233145 events
# INFO:root:tot event weight 92.58058359541592
#
# INFO:root:Finding WJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 4027 events
# INFO:root:tot event weight 910.5421166566867
#
# INFO:root:Finding ZJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding SingleElectron_Run2017E samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 22746 events
# INFO:root:tot event weight 22746.0
#
# INFO:root:Finding SingleElectron_Run2017B samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 9060 events
# INFO:root:tot event weight 9060.0
#
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Will fill the WH dataframe with the remaining 4782 events
# INFO:root:tot event weight 5.194334980069201
#
# INFO:root:Finding SingleElectron_Run2017C samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 24152 events
# INFO:root:tot event weight 24152.0
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-100To250 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 61827 events
# INFO:root:tot event weight 3141.419683574312
#
# INFO:root:Finding SingleElectron_Run2017D samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 10914 events
# INFO:root:tot event weight 10914.0
#
# INFO:root:Finding EWKWplus_WToQQ samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 96 events
# INFO:root:tot event weight 7.748512054602874
#
# INFO:root:Finding SingleMuon_Run2017C samples and should combine them under Data
# INFO:root:Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 12672 events
# INFO:root:tot event weight 40.05940902044164
#
# INFO:root:Finding SingleMuon_Run2017D samples and should combine them under Data
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-50To100 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 3265 events
# INFO:root:tot event weight 568.5682371672135
#
# INFO:root:Finding SingleMuon_Run2017E samples and should combine them under Data
# INFO:root:Finding SingleMuon_Run2017B samples and should combine them under Data
# INFO:root:Finding WW samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 895 events
# INFO:root:tot event weight 419.462190808406
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-250To400 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 750350 events
# INFO:root:tot event weight 3836.6553900222293
#
# INFO:root:Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 9525 events
# INFO:root:tot event weight 302.3935870291113
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 135201 events
# INFO:root:tot event weight 4174.430400267646
#
# INFO:root:Finding EWKZ_ZToQQ samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 85 events
# INFO:root:tot event weight 3.287064136558973
#
# INFO:root:Finding ZJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 72 events
# INFO:root:tot event weight 33.33078461596703
#
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 269 events
# INFO:root:tot event weight 63.64859363214285
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 646 events
# INFO:root:tot event weight 84.94907350720295
#
# INFO:root:Finding fake_2017_ele_EWK_SF_Up.parquet samples and should combine them under EWKvjets
# INFO:root:No parquet file for fake_2017_ele_EWK_SF_Up.parquet
# INFO:root:Finding WJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 859 events
# INFO:root:tot event weight 88.19333481788661
#
# INFO:root:Finding fake_2017_ele_EWK_SF_Down.parquet samples and should combine them under EWKvjets
# INFO:root:No parquet file for fake_2017_ele_EWK_SF_Down.parquet
# INFO:root:Finding ZJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 321 events
# INFO:root:tot event weight 40.38124209151705
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-400To650 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 189073 events
# INFO:root:tot event weight 978.908380537887
#
# INFO:root:Finding EWKWminus_WToQQ samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 60 events
# INFO:root:tot event weight 4.580799013678229
#
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 82235 events
# INFO:root:tot event weight 9340.927866475826
#
# INFO:root:Finding WJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 525 events
# INFO:root:tot event weight 116.75200315913897
#
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 40568 events
# INFO:root:tot event weight 15.102554798831221
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Will fill the ttH dataframe with the remaining 14915 events
# INFO:root:tot event weight 23.77446069253398
#
# INFO:root:Finding ZJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 469 events
# INFO:root:tot event weight 35.51227838985062
#
# INFO:root:Finding SingleElectron_Run2017F samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 31932 events
# INFO:root:tot event weight 31932.0
#
# INFO:root:Finding EWKWplus_WToLNu samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 1510 events
# INFO:root:tot event weight 628.6986156509545
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-0To50 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 677 events
# INFO:root:tot event weight 227.1521233634912
#
# INFO:root:Finding WJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 41 events
# INFO:root:tot event weight 93.9247740438603
#
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 33508 events
# INFO:root:tot event weight 15839.149950300696
#
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:Will fill the ZH dataframe with the remaining 9371 events
# INFO:root:tot event weight 5.4639525667359825
#
# INFO:root:Finding WZ samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 596 events
# INFO:root:tot event weight 160.23113492875405
#
# INFO:root:Finding SingleMuon_Run2017F samples and should combine them under Data
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:Will fill the VBF dataframe with the remaining 2576 events
# INFO:root:tot event weight 24.855114197840102
#
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 105 events
# INFO:root:tot event weight 166.74539815030852
#
# INFO:root:Finding fake_2017_mu_EWK_SF_Down.parquet samples and should combine them under EWKvjets
# INFO:root:No parquet file for fake_2017_mu_EWK_SF_Down.parquet
# INFO:root:Finding fake_2017_mu_EWK_SF_Up.parquet samples and should combine them under EWKvjets
# INFO:root:No parquet file for fake_2017_mu_EWK_SF_Up.parquet
# INFO:root:Finding EWKWminus_WToLNu samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 2202 events
# INFO:root:tot event weight 665.9977139326375
#
# INFO:root:Finding EWKZ_ZToNuNu samples and should combine them under EWKvjets
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Will fill the WH dataframe with the remaining 5491 events
# INFO:root:tot event weight 3.657736722717444
#
# INFO:root:Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 156750 events
# INFO:root:tot event weight 8387.492131650246
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 407264 events
# INFO:root:tot event weight 41321.923304364835
#
# INFO:root:Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 38294 events
# INFO:root:tot event weight 1028.654458205438
#
# INFO:root:Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 263 events
# INFO:root:tot event weight 1.836814340980808
#
# INFO:root:Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 174083 events
# INFO:root:tot event weight 2667.921662023751
#
# INFO:root:Finding EWKZ_ZToLL samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 242 events
# INFO:root:tot event weight 98.74612307121625
#
# INFO:root:Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 21248 events
# INFO:root:tot event weight 8814.524165953686
#
# INFO:root:Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 4494 events
# INFO:root:tot event weight 991.4127231834264
#
# INFO:root:Finding GluGluHToWWToLNuQQ_M-125_TuneCP5_13TeV_powheg_jhugen751_pythia8 samples and should combine them under ggF
# INFO:root:Will fill the ggF dataframe with the remaining 1 events
# INFO:root:tot event weight 0.7430357969657414
#
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:Will fill the ggF dataframe with the remaining 7536 events
# INFO:root:tot event weight 58.030164601228726
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-650ToInf samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 120433 events
# INFO:root:tot event weight 46.373963839191504
#
# INFO:root:Finding WJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 4313 events
# INFO:root:tot event weight 949.4992261339069
#
# INFO:root:Finding ZJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding SingleElectron_Run2017E samples and should combine them under Data
# INFO:root:Finding SingleElectron_Run2017B samples and should combine them under Data
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Will fill the WH dataframe with the remaining 6664 events
# INFO:root:tot event weight 7.093665153681461
#
# INFO:root:Finding SingleElectron_Run2017C samples and should combine them under Data
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-100To250 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 41997 events
# INFO:root:tot event weight 2235.5408568153257
#
# INFO:root:Finding SingleElectron_Run2017D samples and should combine them under Data
# INFO:root:Finding EWKWplus_WToQQ samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 251 events
# INFO:root:tot event weight 20.323480438298514
#
# INFO:root:Finding SingleMuon_Run2017C samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 29696 events
# INFO:root:tot event weight 29696.0
#
# INFO:root:Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 18797 events
# INFO:root:tot event weight 56.59215768186777
#
# INFO:root:Finding SingleMuon_Run2017D samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 13398 events
# INFO:root:tot event weight 13398.0
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-50To100 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 3875 events
# INFO:root:tot event weight 687.4256466049878
#
# INFO:root:Finding SingleMuon_Run2017E samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 29299 events
# INFO:root:tot event weight 29299.0
#
# INFO:root:Finding SingleMuon_Run2017B samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 14712 events
# INFO:root:tot event weight 14712.0
#
# INFO:root:Finding WW samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 982 events
# INFO:root:tot event weight 457.1921948349528
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-250To400 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 171399 events
# INFO:root:tot event weight 889.2222205523036
#
# INFO:root:Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 14593 events
# INFO:root:tot event weight 440.1213007655431
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 114380 events
# INFO:root:tot event weight 3445.397477088014
#
# INFO:root:Finding EWKZ_ZToQQ samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 145 events
# INFO:root:tot event weight 5.2589497777548395
#
# INFO:root:Finding ZJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 125 events
# INFO:root:tot event weight 56.822895251403445
#
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 120 events
# INFO:root:tot event weight 29.3253043360535
#
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 3412 events
# INFO:root:tot event weight 437.2100886426317
#
# INFO:root:Finding fake_2017_ele_EWK_SF_Up.parquet samples and should combine them under EWKvjets
# INFO:root:No parquet file for fake_2017_ele_EWK_SF_Up.parquet
# INFO:root:Finding WJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 1367 events
# INFO:root:tot event weight 136.3794313711509
#
# INFO:root:Finding fake_2017_ele_EWK_SF_Down.parquet samples and should combine them under EWKvjets
# INFO:root:No parquet file for fake_2017_ele_EWK_SF_Down.parquet
# INFO:root:Finding ZJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 1041 events
# INFO:root:tot event weight 132.78213443900563
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-400To650 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 43875 events
# INFO:root:tot event weight 226.85021133916075
#
# INFO:root:Finding EWKWminus_WToQQ samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 112 events
# INFO:root:tot event weight 8.71855588160276
#
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 113052 events
# INFO:root:tot event weight 12820.773604403246
#
# INFO:root:Finding WJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 538 events
# INFO:root:tot event weight 119.66019202192493
#
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 59970 events
# INFO:root:tot event weight 21.786435302251288
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Will fill the ttH dataframe with the remaining 14665 events
# INFO:root:tot event weight 22.58480154341172
#
# INFO:root:Finding ZJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 1999 events
# INFO:root:tot event weight 148.22150728660625
#
# INFO:root:Finding SingleElectron_Run2017F samples and should combine them under Data
# INFO:root:Finding EWKWplus_WToLNu samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 1824 events
# INFO:root:tot event weight 748.8985622388
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-0To50 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 592 events
# INFO:root:tot event weight 263.20888530166104
#
# INFO:root:Finding WJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 27 events
# INFO:root:tot event weight 60.91180067597108
#
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 43548 events
# INFO:root:tot event weight 20598.352167092635
#
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:Will fill the ZH dataframe with the remaining 11622 events
# INFO:root:tot event weight 6.651541345670931
#
# INFO:root:Finding WZ samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 462 events
# INFO:root:tot event weight 125.70875209839483
#
# INFO:root:Finding SingleMuon_Run2017F samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 43194 events
# INFO:root:tot event weight 43194.0
#
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:Will fill the VBF dataframe with the remaining 798 events
# INFO:root:tot event weight 7.049427463764538
#
# INFO:root:Finding fake_2016_ele_EWK_SF_Down.parquet samples and should combine them under EWKvjets
# INFO:root:No parquet file for fake_2016_ele_EWK_SF_Down.parquet
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 19 events
# INFO:root:tot event weight 30.97540156670793
#
# INFO:root:Finding SingleMuon_Run2016H samples and should combine them under Data
# INFO:root:Finding SingleMuon_Run2016F samples and should combine them under Data
# INFO:root:Finding EWKWminus_WToLNu samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 1032 events
# INFO:root:tot event weight 245.90293187150928
#
# INFO:root:Finding EWKZ_ZToNuNu samples and should combine them under EWKvjets
# INFO:root:Finding SingleMuon_Run2016G samples and should combine them under Data
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Will fill the WH dataframe with the remaining 1056 events
# INFO:root:tot event weight 1.0346961671812898
#
# INFO:root:Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 42372 events
# INFO:root:tot event weight 2391.7959353211745
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 349842 events
# INFO:root:tot event weight 14247.879243099764
#
# INFO:root:Finding SingleElectron_Run2016G samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 18103 events
# INFO:root:tot event weight 18103.0
#
# INFO:root:Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 10699 events
# INFO:root:tot event weight 251.92824400890117
#
# INFO:root:Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 17 events
# INFO:root:tot event weight 0.18436138845528333
#
# INFO:root:Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 59705 events
# INFO:root:tot event weight 743.2842533922296
#
# INFO:root:Finding EWKZ_ZToLL samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 384 events
# INFO:root:tot event weight 80.76750255677808
#
# INFO:root:Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 4792 events
# INFO:root:tot event weight 2637.035311418343
#
# INFO:root:Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 1682 events
# INFO:root:tot event weight 357.273172903566
#
# INFO:root:Finding GluGluHToWWToLNuQQ_M-125_TuneCP5_13TeV_powheg_jhugen751_pythia8 samples and should combine them under ggF
# INFO:root:Will fill the ggF dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# ...
#
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 119 events
# INFO:root:tot event weight 28.046770575856716
#
# INFO:root:Finding fake_2016APV_mu_EWK_SF_Down.parquet samples and should combine them under EWKvjets
# INFO:root:No parquet file for fake_2016APV_mu_EWK_SF_Down.parquet
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 818 events
# INFO:root:tot event weight 41.6310408415809
#
# INFO:root:Finding SingleElectron_Run2016D_HIPM samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 9499 events
# INFO:root:tot event weight 9499.0
#
# INFO:root:Finding WJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 543 events
# INFO:root:tot event weight 39.66628892998817
#
# INFO:root:Finding ZJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 180 events
# INFO:root:tot event weight 17.58614039593092
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-400To650 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 119545 events
# INFO:root:tot event weight 487.7201939638807
#
# INFO:root:Finding SingleMuon_Run2016B_ver2_HIPM samples and should combine them under Data
# INFO:root:Finding SingleMuon_Run2016E_HIPM samples and should combine them under Data
# INFO:root:Finding EWKWminus_WToQQ samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 32 events
# INFO:root:tot event weight 2.314554269009178
#
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 32368 events
# INFO:root:tot event weight 4167.464159502781
#
# INFO:root:Finding SingleElectron_Run2016C_HIPM samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 5696 events
# INFO:root:tot event weight 5696.0
#
# INFO:root:Finding WJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 364 events
# INFO:root:tot event weight 51.24802932637182
#
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 27093 events
# INFO:root:tot event weight 6.605592804843872
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Will fill the ttH dataframe with the remaining 5370 events
# INFO:root:tot event weight 10.17996711080357
#
# INFO:root:Finding ZJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 172 events
# INFO:root:tot event weight 14.662439348693116
#
# INFO:root:Finding EWKWplus_WToLNu samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 875 events
# INFO:root:tot event weight 289.79313670423795
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-0To50 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 386 events
# INFO:root:tot event weight 96.14646789521903
#
# INFO:root:Finding WJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 48 events
# INFO:root:tot event weight 41.48889097691069
#
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 13089 events
# INFO:root:tot event weight 6597.546151187164
#
# INFO:root:Finding SingleMuon_Run2016C_HIPM samples and should combine them under Data
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:Will fill the ZH dataframe with the remaining 4220 events
# INFO:root:tot event weight 2.2890368768238423
#
# INFO:root:Finding WZ samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 687 events
# INFO:root:tot event weight 74.07226614054493
#
# INFO:root:Finding fake_2016APV_mu_EWK_SF_Up.parquet samples and should combine them under EWKvjets
# INFO:root:No parquet file for fake_2016APV_mu_EWK_SF_Up.parquet
# INFO:root:Finding SingleElectron_Run2016B_ver2_HIPM samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 13459 events
# INFO:root:tot event weight 13459.0
#
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:Will fill the VBF dataframe with the remaining 860 events
# INFO:root:tot event weight 11.714897904162498
#
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 19 events
# INFO:root:tot event weight 28.984910426687517
#
# INFO:root:Finding EWKWminus_WToLNu samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 1184 events
# INFO:root:tot event weight 309.04683126100355
#
# INFO:root:Finding EWKZ_ZToNuNu samples and should combine them under EWKvjets
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Will fill the WH dataframe with the remaining 2079 events
# INFO:root:tot event weight 1.5526026120519634
#
# INFO:root:Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 77194 events
# INFO:root:tot event weight 3964.0858364323212
#
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 400063 events
# INFO:root:tot event weight 18598.581466613607
#
# INFO:root:Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 14713 events
# INFO:root:tot event weight 439.86298890139165
#
# INFO:root:Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 93 events
# INFO:root:tot event weight 0.8951737960481461
#
# INFO:root:Finding fake_2016APV_ele_EWK_SF_Down.parquet samples and should combine them under EWKvjets
# INFO:root:No parquet file for fake_2016APV_ele_EWK_SF_Down.parquet
# INFO:root:Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 89879 events
# INFO:root:tot event weight 1262.6414786194462
#
# INFO:root:Finding EWKZ_ZToLL samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 200 events
# INFO:root:tot event weight 43.8766487560803
#
# INFO:root:Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 6299 events
# INFO:root:tot event weight 3029.1005725777877
#
# INFO:root:Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 1735 events
# INFO:root:tot event weight 445.87800042579187
#
# INFO:root:Finding GluGluHToWWToLNuQQ_M-125_TuneCP5_13TeV_powheg_jhugen751_pythia8 samples and should combine them under ggF
# INFO:root:Will fill the ggF dataframe with the remaining 0 events
# INFO:root:tot event weight 0.0
#
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:Will fill the ggF dataframe with the remaining 3742 events
# INFO:root:tot event weight 25.120066158609966
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-650ToInf samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 59042 events
# INFO:root:tot event weight 22.294498321158063
#
# INFO:root:Finding WJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 1745 events
# INFO:root:tot event weight 443.9726336497779
#
# INFO:root:Finding ZJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding SingleMuon_Run2016F_HIPM samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 7245 events
# INFO:root:tot event weight 7245.0
#
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Will fill the WH dataframe with the remaining 2638 events
# INFO:root:tot event weight 3.1440988544145365
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-100To250 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 19041 events
# INFO:root:tot event weight 859.5615211328432
#
# INFO:root:Finding fake_2016APV_ele_EWK_SF_Up.parquet samples and should combine them under EWKvjets
# INFO:root:No parquet file for fake_2016APV_ele_EWK_SF_Up.parquet
# INFO:root:Finding EWKWplus_WToQQ samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 100 events
# INFO:root:tot event weight 9.651920172122018
#
# INFO:root:Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 7282 events
# INFO:root:tot event weight 25.693792894058475
#
# INFO:root:Finding SingleElectron_Run2016F_HIPM samples and should combine them under Data
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-50To100 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 2058 events
# INFO:root:tot event weight 254.93569869711422
#
# INFO:root:Finding WW samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 1332 events
# INFO:root:tot event weight 205.77201547716868
#
# INFO:root:Finding SingleMuon_Run2016D_HIPM samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 11331 events
# INFO:root:tot event weight 11331.0
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-250To400 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 86587 events
# INFO:root:tot event weight 415.5494831059824
#
# INFO:root:Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Will fill the SingleTop dataframe with the remaining 6161 events
# INFO:root:tot event weight 194.08207416077585
#
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 53014 events
# INFO:root:tot event weight 1579.7934060830457
#
# INFO:root:Finding SingleElectron_Run2016E_HIPM samples and should combine them under Data
# INFO:root:Finding EWKZ_ZToQQ samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 82 events
# INFO:root:tot event weight 2.3494975886052707
#
# INFO:root:Finding ZJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 66 events
# INFO:root:tot event weight 20.065086768585076
#
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 50 events
# INFO:root:tot event weight 12.313360544775668
#
# INFO:root:Finding fake_2016APV_mu_EWK_SF_Down.parquet samples and should combine them under EWKvjets
# INFO:root:No parquet file for fake_2016APV_mu_EWK_SF_Down.parquet
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:Will fill the TTbar dataframe with the remaining 3706 events
# INFO:root:tot event weight 183.06281737340643
#
# INFO:root:Finding SingleElectron_Run2016D_HIPM samples and should combine them under Data
# INFO:root:Finding WJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 912 events
# INFO:root:tot event weight 62.1046058947007
#
# INFO:root:Finding ZJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 567 events
# INFO:root:tot event weight 53.15208878469889
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-400To650 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 27428 events
# INFO:root:tot event weight 108.78877605408292
#
# INFO:root:Finding SingleMuon_Run2016B_ver2_HIPM samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 15726 events
# INFO:root:tot event weight 15726.0
#
# INFO:root:Finding SingleMuon_Run2016E_HIPM samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 10634 events
# INFO:root:tot event weight 10634.0
#
# INFO:root:Finding EWKWminus_WToQQ samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 61 events
# INFO:root:tot event weight 4.348807297913558
#
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 47533 events
# INFO:root:tot event weight 6029.248026554666
#
# INFO:root:Finding SingleElectron_Run2016C_HIPM samples and should combine them under Data
# INFO:root:Finding WJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 386 events
# INFO:root:tot event weight 52.32616413786943
#
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 42508 events
# INFO:root:tot event weight 10.255733670526496
#
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Will fill the ttH dataframe with the remaining 5830 events
# INFO:root:tot event weight 10.774963349601375
#
# INFO:root:Finding ZJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 814 events
# INFO:root:tot event weight 65.32606370078773
#
# INFO:root:Finding EWKWplus_WToLNu samples and should combine them under EWKvjets
# INFO:root:Will fill the EWKvjets dataframe with the remaining 1029 events
# INFO:root:tot event weight 330.62588751681506
#
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-0To50 samples and should combine them under DYJets
# INFO:root:Will fill the DYJets dataframe with the remaining 360 events
# INFO:root:tot event weight 87.40611256213732
#
# INFO:root:Finding WJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Will fill the WZQQ dataframe with the remaining 28 events
# INFO:root:tot event weight 23.978702858002315
#
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:Will fill the WJetsLNu dataframe with the remaining 17843 events
# INFO:root:tot event weight 8880.671166984437
#
# INFO:root:Finding SingleMuon_Run2016C_HIPM samples and should combine them under Data
# INFO:root:Will fill the Data dataframe with the remaining 6972 events
# INFO:root:tot event weight 6972.0
#
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:Will fill the ZH dataframe with the remaining 5636 events
# INFO:root:tot event weight 2.982594637874188
#
# INFO:root:Finding WZ samples and should combine them under Diboson
# INFO:root:Will fill the Diboson dataframe with the remaining 476 events
# INFO:root:tot event weight 50.99746380984884
#
# INFO:root:Finding fake_2016APV_mu_EWK_SF_Up.parquet samples and should combine them under EWKvjets
# INFO:root:No parquet file for fake_2016APV_mu_EWK_SF_Up.parquet
# INFO:root:Finding SingleElectron_Run2016B_ver2_HIPM samples and should combine them under Data

# %% [markdown]
# # Add the cut to the cutflow dict

# %%
presel = {
        "mu": {
            "fj_mass": "fj_mass>40",
            "THWW>0.75": "fj_mass>40 & THWW>0.75",
        },
        "ele": {
            "fj_mass": "fj_mass>40",            
            "THWW>0.75": "fj_mass>40 & THWW>0.75",
        },
}

# %%
for ch in channels:
    for cut, sel in list(presel[ch].items()):
        for sample in samples:
            for year in years:

                df = events_dict[year][ch][sample]
                df = df.query(sel)
                
                w = df["nominal"]

                cutflows[year][ch][sample][cut] = w.sum()

# %%
cutflows["2016APV"]["mu"]["WJetsLNu"]     # take a quick look
# Out:
# {'sumgenweight': 32148205.541996155,
#  'Trigger': 5052102.989037976,
#  'METFilters': 5049012.531204127,
#  'OneLep': 5031057.850622146,
#  'NoTaus': 4271447.470579825,
#  'AtLeastOneFatJet': 461978.1002925532,
#  'CandidateJetpT': 196124.03115179407,
#  'LepInJet': 68289.06508691012,
#  'JetLepOverlap': 26003.119346261694,
#  'dPhiJetMET': 18333.833322064966,
#  'MET': 16980.930607238028,
#  'fj_mass': 19896.861487391365,
#  'THWW>0.75': 560.3813816501639}

# %%
cutflows["2016APV"]["ele"]["WJetsLNu"]     # take a quick look
# Out:
# {'sumgenweight': 32241758.10101272,
#  'Trigger': 4454643.38131529,
#  'METFilters': 4451955.991847101,
#  'OneLep': 3062734.5054372367,
#  'NoTaus': 3062734.5054372367,
#  'AtLeastOneFatJet': 364780.748501086,
#  'CandidateJetpT': 153895.86376889877,
#  'LepInJet': 58938.59730123174,
#  'JetLepOverlap': 19206.882023214886,
#  'dPhiJetMET': 13362.535289163337,
#  'MET': 12293.663142455729,
#  'fj_mass': 14729.953784965503,
#  'THWW>0.75': 323.25912091618096}

# %% [markdown]
# # Combine different channels

# %%
common_cuts = cutflows["2018"]["mu"]["WJetsLNu"]
common_cuts
# Out:
# {'sumgenweight': 98881812.96014196,
#  'Trigger': 15774368.475905173,
#  'METFilters': 15767447.50578202,
#  'OneLep': 15713782.312337536,
#  'NoTaus': 13365615.02871292,
#  'AtLeastOneFatJet': 1419078.1158154933,
#  'CandidateJetpT': 638926.6511643255,
#  'LepInJet': 226595.34688035544,
#  'JetLepOverlap': 85525.34383794866,
#  'dPhiJetMET': 59904.21890436672,
#  'MET': 55956.918262700114,
#  'HEMCleaning': 53829.03321016653,
#  'fj_mass': 65069.24460716746,
#  'THWW>0.75': 1822.2158269649399}

# %%
def combine_channels(cutflows):

    # combine both channels
    cutflows_new = {}
    for year in cutflows.keys():
        cutflows_new[year] = {}
        cutflows_new[year]["lep"] = {}
        
        for ch in ["mu", "ele"]:
            for sample in cutflows[year][ch]:
                                
                if sample not in cutflows_new[year]["lep"]:
                    cutflows_new[year]["lep"][sample] = {}
                
                for cut in cutflows[year][ch][sample]:
                    
                    if (year != "2018") and (cut == "HEMCleaning"):
                        continue
                    
                    if cut not in cutflows_new[year]["lep"][sample]:
                        cutflows_new[year]["lep"][sample][cut] = cutflows[year][ch][sample][cut]
                    else:
                        cutflows_new[year]["lep"][sample][cut] += cutflows[year][ch][sample][cut]
        cutflows[year] = {**cutflows[year], **cutflows_new[year]}
        
    return cutflows

# %%
cutflows = combine_channels(cutflows)

# %%
cutflows["2018"].keys()
# Out:
# dict_keys(['ele', 'mu', 'lep'])

# %%
cutflows["2018"]["ele"]["WJetsLNu"]
# Out:
# {'sumgenweight': 98938496.94524625,
#  'Trigger': 13451747.990687694,
#  'METFilters': 13445769.865167841,
#  'OneLep': 10365734.270532267,
#  'NoTaus': 10365734.270532267,
#  'AtLeastOneFatJet': 1175706.8480802262,
#  'CandidateJetpT': 527598.3350759504,
#  'LepInJet': 203266.60352170584,
#  'JetLepOverlap': 67482.88251702799,
#  'dPhiJetMET': 46441.958592916984,
#  'MET': 43162.660704319554,
#  'HEMCleaning': 41485.858620482926,
#  'fj_mass': 51498.8021733948,
#  'THWW>0.75': 1300.756305407815}

# %%
cutflows["2018"]["mu"]["WJetsLNu"]
# Out:
# {'sumgenweight': 98881812.96014196,
#  'Trigger': 15774368.475905173,
#  'METFilters': 15767447.50578202,
#  'OneLep': 15713782.312337536,
#  'NoTaus': 13365615.02871292,
#  'AtLeastOneFatJet': 1419078.1158154933,
#  'CandidateJetpT': 638926.6511643255,
#  'LepInJet': 226595.34688035544,
#  'JetLepOverlap': 85525.34383794866,
#  'dPhiJetMET': 59904.21890436672,
#  'MET': 55956.918262700114,
#  'HEMCleaning': 53829.03321016653,
#  'fj_mass': 65069.24460716746,
#  'THWW>0.75': 1822.2158269649399}

# %%
cutflows["2018"]["lep"]["WJetsLNu"]
# Out:
# {'sumgenweight': 197820309.9053882,
#  'Trigger': 29226116.466592867,
#  'METFilters': 29213217.37094986,
#  'OneLep': 26079516.582869805,
#  'NoTaus': 23731349.299245186,
#  'AtLeastOneFatJet': 2594784.9638957195,
#  'CandidateJetpT': 1166524.986240276,
#  'LepInJet': 429861.9504020613,
#  'JetLepOverlap': 153008.22635497665,
#  'dPhiJetMET': 106346.1774972837,
#  'MET': 99119.57896701967,
#  'HEMCleaning': 95314.89183064946,
#  'fj_mass': 116568.04678056226,
#  'THWW>0.75': 3122.972132372755}

# %% [markdown]
# # Combine different years

# %%
def combine_years(cutflows):
    """Will remove the HEM cleaning cutflow from 2018 first."""
    
    whatever_year = list(cutflows.keys())[0]
    channels = cutflows[whatever_year].keys()
    
    # combine all years
    cutflows_new = {}
    cutflows_new["Run2"] = {}
    
    for ch in channels:
        cutflows_new["Run2"][ch] = {}
        
        for year in cutflows:
            for sample in cutflows[year][ch]:
                
                if sample not in cutflows_new["Run2"][ch]:
                    cutflows_new["Run2"][ch][sample] = {}

                for cut in cutflows[year][ch][sample]:
                    if "HEM" in cut:
                        continue
                    if cut not in cutflows_new["Run2"][ch][sample]:
                        cutflows_new["Run2"][ch][sample][cut] = cutflows[year][ch][sample][cut]
                    else:
                        cutflows_new["Run2"][ch][sample][cut] += cutflows[year][ch][sample][cut]

    cutflows = {**cutflows, **cutflows_new}

    return cutflows

# %%
cutflows = combine_years(cutflows)

# %%
cutflows["2016"]["ele"].keys()
# Out:
# dict_keys(['VBF', 'WJetsLNu', 'EWKvjets', 'WH', 'TTbar', 'Data', 'SingleTop', 'ggF', 'DYJets', 'Diboson', 'WZQQ', 'ttH', 'ZH'])

# %%
cutflows.keys()
# Out:
# dict_keys(['2018', '2017', '2016', '2016APV', 'Run2'])

# %%
cutflows["Run2"].keys()
# Out:
# dict_keys(['ele', 'mu', 'lep'])

# %% [markdown]
# # Combine non-dominant backgrounds

# %%
# combine non-dominant backgrounds under others
dominant_bkgs = ["WJetsLNu", "TTbar"]
signals = ["ggF", "VBF", "WH", "ZH", "ttH"]

for year in cutflows:
    for ch in cutflows[year]:
        cutflows[year][ch]["Others"] = dict.fromkeys(cutflows[year][ch]["WJetsLNu"], 0)
        for sample in cutflows[year][ch]:
            if sample == "Data":
                continue
            if sample not in signals+dominant_bkgs:
                for cut in cutflows[year][ch][sample]:
                    cutflows[year][ch]["Others"][cut] += cutflows[year][ch][sample][cut]

# %%
cutflows["2018"]["ele"].keys()
# Out:
# dict_keys(['VBF', 'WJetsLNu', 'EWKvjets', 'WH', 'TTbar', 'SingleTop', 'ggF', 'DYJets', 'Data', 'Diboson', 'WZQQ', 'ttH', 'ZH', 'Others'])

# %%
cutflows["2018"]["lep"]["Others"]
# Out:
# {'sumgenweight': 701905777.1893944,
#  'Trigger': 106776300.4785971,
#  'METFilters': 106744779.68028218,
#  'OneLep': 69889276.65752879,
#  'NoTaus': 65050915.302088186,
#  'AtLeastOneFatJet': 1747597.8010711675,
#  'CandidateJetpT': 813340.0718076346,
#  'LepInJet': 395296.1751882167,
#  'JetLepOverlap': 151354.71308578423,
#  'dPhiJetMET': 90838.14744899893,
#  'MET': 78830.04211136982,
#  'HEMCleaning': 75405.24645365497,
#  'fj_mass': 62865.87271783278,
#  'THWW>0.75': 1103.411013839698}

# %% [markdown]
# # LateX cutflow table

# %%
cuts = [
    "sumgenweight",
    "Trigger",
    "METFilters",
    "OneLep",        
    "NoTaus",
    "AtLeastOneFatJet",
    "CandidateJetpT",
    "LepInJet",
    "JetLepOverlap",
    "dPhiJetMET",
    "MET",
    "HEMCleaning",
]

for cut in presel["mu"]:
    cuts += [cut]

# %%
cut_to_label = {
    "sumgenweight": "sumgenweight",        
    "HEMCleaning": "HEMCleaning",    
    "Trigger": "Trigger",
    "METFilters": "METFilters",
    "OneLep": "n Leptons = 1",
    "NoTaus": "n Taus = 0",
    "AtLeastOneFatJet": r"n FatJets $>=$ 1",
    "CandidateJetpT": r"j $p_T > 250$GeV",
    "LepInJet": r"$\Delta R(j, \ell) < 0.8$",
    "JetLepOverlap": r"$\Delta R(j, \ell) > 0.03$",
    "dPhiJetMET": r"$\Delta \phi(\mathrm{MET}, j)<1.57$",
    "MET": r"$\mathrm{MET}>20$",
    
    "None": "None",

    "fj_mass": r"j $\mathrm{softdrop} > 40$GeV",
    
    "THWW>0.75": r"$\ensuremath{T_{\text{HWW}}^{\ell\nu qq}} > 0.75$",
}

# %%
parquet_to_latex = {
    "WJetsLNu": "$\PW(\Pell\PGn)$+",
    "TTbar": "\\ttbar",
    "Others": "Other MC",

    "ggF": "ggF",
    "VBF": "VBF",
    "WH": "WH",
    "ZH": "ZH",    
    "ttH": "$t\\bar{t}H$",    
    
    "Data": "Data",
}

def make_latex_cutflow_table(cutflows_dict, year, ch, add_data=False, add_sumgenweight=False):
    """Will use the cutflows dictionary to make the LateX table we have in the AN."""
    
    samples_bkg = ["WJetsLNu", "TTbar", "Others"]
    samples_sig = ["ggF","VBF", "WH", "ZH", "ttH"]

    ### backgrounds
    headers = [parquet_to_latex[s] for s in samples_bkg]
    
    textabular = f"l{'r'*len(headers)}"
    textabular += "|r"
    
    texheader = "\\textbf{Inclusive Selection}" + " & " + " & ".join(headers) + " & Total MC "
    if add_data:
        textabular += "|r"
        texheader += "& Data "
    texheader += "\\\\"
    texdata = "\\hline\n"
    
    data = dict()
    
    for cut in cuts: 
        if (year != "2018") and (cut == "HEMCleaning"):
            continue
            
        if not add_sumgenweight and cut == "sumgenweight":
            continue
    
        data[cut] = []

        for sample in samples_bkg:            
            data[cut].append(round(cutflows_dict[year][ch][sample][cut]))
            
        totalmc = 0
        for sample in (samples_bkg + samples_sig):
            totalmc += round(cutflows_dict[year][ch][sample][cut])
            
        data[cut].append(totalmc)
        
        if add_data:
            data[cut].append(round(cutflows_dict[year][ch]["Data"][cut]))

    for label in data:
        if label == "z":
            texdata += "\\hline\n"
        texdata += f"{cut_to_label[label]} & {' & '.join(map(str,data[label]))} \\\\\n"
        
    texdata += "\\hline\n"    

    ### signal
    headers2 = [parquet_to_latex[s] for s in samples_sig]
    texheader2 = " & " + " & ".join(headers2) + "\\\\"
    texdata2 = "\\hline\n"

    textabular2 = f"l{'r'*len(headers2)}"
    
    data = dict()
    for cut in cuts:
        if (year != "2018") and (cut == "HEMCleaning"):
            continue
            
        data[cut] = []

        for sample in samples_sig:
            data[cut].append(round(cutflows_dict[year][ch][sample][cut]))
        
    for label in data:
        if label == "z":
            texdata += "\\hline\n"
        texdata2 += f"{cut_to_label[label]} & {' & '.join(map(str,data[label]))} \\\\\n"    

    # make table
    print("\\begin{table}[!htp]")
    print("\\begin{center}")
    
    print("\\begin{tabular}{"+textabular+"}")
    print(texheader)
    print(texdata,end="")
    print("\\end{tabular}")

    print("\\begin{tabular}{"+textabular2+"}")
    print(texheader2)
    print(texdata2,end="")
    print("\\end{tabular}")
    
    
    if ch == "lep":
        print("\\caption{Event yield of " + year + " Monte Carlo samples normalized to " + str(round(get_lumi([year], [ch]))) + "\\fbinv.}")        
    else:
        print("\\caption{Event yield of " + ch + " channel " + year + " Monte Carlo samples normalized to " + str(round(get_lumi([year], [ch]))) + "\\fbinv.}")
        
    print("\\label{sel-tab-cutflow" + year + "}")
    print("\\end{center}")
    print("\\end{table}")

# %%
make_latex_cutflow_table(cutflows, "2018", "lep", add_data=True, add_sumgenweight=True)
# Out:
# \begin{table}[!htp]
# \begin{center}
# \begin{tabular}{lrrr|r|r}
# \textbf{Inclusive Selection} & $\PW(\Pell\PGn)$+ & \ttbar & Other MC & Total MC & Data \\
# \hline
# sumgenweight & 197820310 & 99476871 & 701905777 & 999935499 & 2276244440 \\
# Trigger & 29226116 & 10530590 & 106776300 & 146591899 & 1174738710 \\
# METFilters & 29213217 & 10524986 & 106744780 & 146541854 & 1173476723 \\
# n Leptons = 1 & 26079517 & 8801799 & 69889277 & 104819686 & 656865738 \\
# n Taus = 0 & 23731349 & 7031178 & 65050915 & 95857257 & 632124064 \\
# n FatJets $>=$ 1 & 2594785 & 1264275 & 1747598 & 5610184 & 6978889 \\
# j $p_T > 250$GeV & 1166525 & 642813 & 813340 & 2624530 & 2825338 \\
# $\Delta R(j, \ell) < 0.8$ & 429862 & 283922 & 395296 & 1110154 & 1392226 \\
# $\Delta R(j, \ell) > 0.03$ & 153008 & 245912 & 151355 & 551261 & 640994 \\
# $\Delta \phi(\mathrm{MET}, j)<1.57$ & 106346 & 155609 & 90838 & 353469 & 359014 \\
# $\mathrm{MET}>20$ & 99120 & 146617 & 78830 & 325195 & 326733 \\
# HEMCleaning & 95315 & 140575 & 75405 & 311842 & 298219 \\
# j $\mathrm{softdrop} > 40$GeV & 116568 & 118219 & 62866 & 297927 & 252775 \\
# $\ensuremath{T_{\text{HWW}}^{\ell\nu qq}} > 0.75$ & 3123 & 1314 & 1103 & 5630 & 4677 \\
# \hline
# \end{tabular}
# \begin{tabular}{lrrrrr}
#  & ggF & VBF & WH & ZH & $t\bar{t}H$\\
# \hline
# sumgenweight & 550027 & 96661 & 36203 & 24523 & 25127 \\
# Trigger & 43245 & 6192 & 3766 & 1994 & 3696 \\
# METFilters & 43235 & 6187 & 3764 & 1993 & 3692 \\
# n Leptons = 1 & 36618 & 5191 & 3026 & 1465 & 2793 \\
# n Taus = 0 & 33868 & 4374 & 2435 & 1206 & 1932 \\
# n FatJets $>=$ 1 & 1843 & 424 & 273 & 128 & 858 \\
# j $p_T > 250$GeV & 939 & 194 & 142 & 69 & 508 \\
# $\Delta R(j, \ell) < 0.8$ & 621 & 112 & 67 & 40 & 234 \\
# $\Delta R(j, \ell) > 0.03$ & 588 & 104 & 45 & 36 & 213 \\
# $\Delta \phi(\mathrm{MET}, j)<1.57$ & 416 & 75 & 31 & 20 & 134 \\
# $\mathrm{MET}>20$ & 383 & 69 & 29 & 19 & 128 \\
# HEMCleaning & 367 & 66 & 27 & 18 & 69 \\
# j $\mathrm{softdrop} > 40$GeV & 118 & 54 & 23 & 15 & 64 \\
# $\ensuremath{T_{\text{HWW}}^{\ell\nu qq}} > 0.75$ & 48 & 22 & 8 & 5 & 7 \\
# \end{tabular}
# \caption{Event yield of 2018 Monte Carlo samples normalized to 60\fbinv.}
# \label{sel-tab-cutflow2018}
# \end{center}
# \end{table}
