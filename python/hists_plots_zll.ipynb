# %%
import glob
import os
import json
import pickle
import yaml

import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None
import pyarrow.parquet as pq
from sklearn.metrics import auc, roc_curve
from scipy.special import softmax

import hist as hist2
import matplotlib.pyplot as plt
import mplhep as hep

plt.style.use(hep.style.CMS)

import utils_farouk as utils
plt.rcParams.update({"font.size": 20})
# Out:
# /opt/anaconda3/envs/coffea-env/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
# %load_ext autoreload
# %autoreload 2

# %%
! ls ../zll_Pt_2017
# Out:
# DYJetsToLL_M-10to50                     SingleElectron_Run2017E
# DYJetsToLL_Pt-100To250                  SingleElectron_Run2017F
# DYJetsToLL_Pt-250To400                  SingleMuon_Run2017B
# DYJetsToLL_Pt-400To650                  SingleMuon_Run2017C
# DYJetsToLL_Pt-50To100                   SingleMuon_Run2017D
# DYJetsToLL_Pt-650ToInf                  SingleMuon_Run2017E
# GluGluHToTauTau                         SingleMuon_Run2017F
# GluGluHToWW_Pt-200ToInf_M-125           TTTo2L2Nu
# GluGluZH_HToWW_ZTo2L_M-125              TTToHadronic
# HWminusJ_HToWW_M-125                    TTToSemiLeptonic
# HWplusJ_HToWW_M-125                     VBFHToWWToLNuQQ_M-125_withDipoleRecoil
# HZJ_HToWW_M-125                         WJetsToLNu_HT-100To200
# QCD_Pt_1000to1400                       WJetsToLNu_HT-1200To2500
# QCD_Pt_1400to1800                       WJetsToLNu_HT-200To400
# QCD_Pt_170to300                         WJetsToLNu_HT-2500ToInf
# QCD_Pt_1800to2400                       WJetsToLNu_HT-400To600
# QCD_Pt_2400to3200                       WJetsToLNu_HT-600To800
# QCD_Pt_300to470                         WJetsToLNu_HT-70To100
# QCD_Pt_3200toInf                        WJetsToLNu_HT-800To1200
# QCD_Pt_470to600                         WJetsToQQ_HT-200to400
# QCD_Pt_600to800                         WJetsToQQ_HT-400to600
# QCD_Pt_800to1000                        WJetsToQQ_HT-600to800
# ST_s-channel_4f_hadronicDecays          WJetsToQQ_HT-800toInf
# ST_s-channel_4f_leptonDecays            WW
# ST_t-channel_antitop_4f_InclusiveDecays WZ
# ST_t-channel_top_4f_InclusiveDecays     ZJetsToQQ_HT-200to400
# ST_tW_antitop_5f_inclusiveDecays        ZJetsToQQ_HT-400to600
# ST_tW_top_5f_inclusiveDecays            ZJetsToQQ_HT-600to800
# SingleElectron_Run2017B                 ZJetsToQQ_HT-800toInf
# SingleElectron_Run2017C                 ZZ
# SingleElectron_Run2017D                 ttHToNonbb_M125

# %% [markdown]
# # Read parquets
# - loads parquet dataframes and combine different pT-bins per sample
# - applies the preselection specefied in the next cell
# - saves the combined dataframe under `events[ch][sample]`

# %%
presel = {
    "mu": {
        "lep_fj_dr": "( ( lep_fj_dr>0.03) )",
        "n_bjets_M": "( (n_bjets_M<2) )",        
    },
    "ele": {
        "lep_fj_dr": "( ( lep_fj_dr>0.03) )",
        "n_bjets_M": "( (n_bjets_M<2) )",
    }    
}

# %%
year = "2017"
channels = ["mu", "ele"]
# samples_dir = f"../zll_Pt_{year}"
samples_dir = f"../zll_M_{year}"   # new samples

samples = [
    "HWW", 
    "VH",
    "VBF",
    "ttH",
    "QCD",
    "DYJets",
    "WJetsLNu",
    "WZQQ",
    "TTbar",
    "SingleTop",
    "Diboson",
    "Data"
]

# %%
events_dict = utils.event_skimmer(year, channels, samples_dir, samples, presel, "all")
# Out:
# Finding DYJetsToLL_M-50_HT-600to800 samples and should combine them under DYJets
# ---> Applying preselection.
# applying lep_fj_dr selection on 737289 events
# applying n_bjets_M selection on 688279 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the DYJets dataframe with the remaining 676519 events
# tot event weight 12697.510140663222
#
# Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# ---> Applying preselection.
# applying lep_fj_dr selection on 118 events
# applying n_bjets_M selection on 47 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the WJetsLNu dataframe with the remaining 47 events
# tot event weight 73.63512371073823
#
# Finding DYJetsToLL_M-10to50 samples and should combine them under DYJets
# ---> Applying preselection.
# applying lep_fj_dr selection on 675 events
# applying n_bjets_M selection on 624 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the DYJets dataframe with the remaining 618 events
# tot event weight 11104.501123915506
#
# Finding VBFHToWWToLNuQQ_M-125_withDipoleRecoil samples and should combine them under VBF
# ---> Applying preselection.
# applying lep_fj_dr selection on 6 events
# applying n_bjets_M selection on 6 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the VBF dataframe with the remaining 6 events
# tot event weight 0.29681249683129424
#
# Finding HWminusJ_HToWW_M-125 samples and should combine them under VH
# ---> Applying preselection.
# applying lep_fj_dr selection on 5121 events
# applying n_bjets_M selection on 4122 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the VH dataframe with the remaining 4107 events
# tot event weight 2.80307304492643
#
# Finding DYJetsToLL_M-50_HT-70to100 samples and should combine them under DYJets
# ---> Applying preselection.
# applying lep_fj_dr selection on 17 events
# applying n_bjets_M selection on 4 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the DYJets dataframe with the remaining 4 events
# tot event weight 294.40839160560427
#
# Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# ---> Applying preselection.
# applying lep_fj_dr selection on 3752 events
# applying n_bjets_M selection on 2689 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the WJetsLNu dataframe with the remaining 2612 events
# tot event weight 146.8057428165106
#
# Finding TTToSemiLeptonic samples and should combine them under TTbar
# ---> Applying preselection.
# applying lep_fj_dr selection on 43529 events
# applying n_bjets_M selection on 40379 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the TTbar dataframe with the remaining 34112 events
# tot event weight 3239.5955561464953
#
# Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# ---> Applying preselection.
# applying lep_fj_dr selection on 4719 events
# applying n_bjets_M selection on 4138 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the SingleTop dataframe with the remaining 3771 events
# tot event weight 107.95052340780634
#
# Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# ---> Applying preselection.
# applying lep_fj_dr selection on 121 events
# applying n_bjets_M selection on 76 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the SingleTop dataframe with the remaining 67 events
# tot event weight 0.45086719378977996
#
# Finding DYJetsToLL_M-50_HT-400to600 samples and should combine them under DYJets
# ---> Applying preselection.
# applying lep_fj_dr selection on 527993 events
# applying n_bjets_M selection on 486682 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the DYJets dataframe with the remaining 480889 events
# tot event weight 42544.69961022269
#
# Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# ---> Applying preselection.
# applying lep_fj_dr selection on 4573 events
# applying n_bjets_M selection on 3221 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the WJetsLNu dataframe with the remaining 3094 events
# tot event weight 41.695391079244175
#
# Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# ---> Applying preselection.
# applying lep_fj_dr selection on 3017 events
# applying n_bjets_M selection on 1716 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the WJetsLNu dataframe with the remaining 1711 events
# tot event weight 805.3952271439723
#
# Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# ---> Applying preselection.
# applying lep_fj_dr selection on 5160 events
# applying n_bjets_M selection on 3099 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the SingleTop dataframe with the remaining 2819 events
# tot event weight 645.8139044221124
#
# Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under HWW
# ---> Applying preselection.
# applying lep_fj_dr selection on 2576 events
# applying n_bjets_M selection on 2466 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the HWW dataframe with the remaining 2445 events
# tot event weight 19.450328547789432
#
# Finding WJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# ---> Applying preselection.
# applying lep_fj_dr selection on 5220 events
# applying n_bjets_M selection on 3173 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the SingleTop dataframe with the remaining 2894 events
# tot event weight 661.3266539221293
#
# Finding ZJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# ---> Applying preselection.
# applying lep_fj_dr selection on 4 events
# applying n_bjets_M selection on 3 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the WZQQ dataframe with the remaining 3 events
# tot event weight 12.716446128426835
#
# Finding SingleElectron_Run2017E samples and should combine them under Data
# Finding SingleElectron_Run2017B samples and should combine them under Data
# Finding DYJetsToLL_M-50_HT-800to1200 samples and should combine them under DYJets
# ---> Applying preselection.
# applying lep_fj_dr selection on 58245 events
# applying n_bjets_M selection on 54175 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the DYJets dataframe with the remaining 53047 events
# tot event weight 6168.834139806013
# Finding QCD_Pt_3200toInf samples and should combine them under QCD
# ---> Applying preselection.
# applying lep_fj_dr selection on 121 events
# applying n_bjets_M selection on 90 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the QCD dataframe with the remaining 88 events
# tot event weight 0.0004669845278739181
#
# Finding HWplusJ_HToWW_M-125 samples and should combine them under VH
# ---> Applying preselection.
# applying lep_fj_dr selection on 5746 events
# applying n_bjets_M selection on 4566 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the VH dataframe with the remaining 4544 events
# tot event weight 4.960661293713194
#
# Finding SingleElectron_Run2017C samples and should combine them under Data
# Finding SingleElectron_Run2017D samples and should combine them under Data
# Finding WJetsToLNu_HT-70To100 samples and should combine them under WJetsLNu
# Finding SingleMuon_Run2017C samples and should combine them under Data
# ---> Applying preselection.
# applying lep_fj_dr selection on 68425 events
# applying n_bjets_M selection on 49545 events
# ---> Done with preselection.
# Will fill the Data dataframe with the remaining 47933 events
# tot event weight 47933.0
#
# Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# ---> Applying preselection.
# applying lep_fj_dr selection on 1927 events
# applying n_bjets_M selection on 1618 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the SingleTop dataframe with the remaining 1522 events
# tot event weight 4.990482313879398
#
# Finding SingleMuon_Run2017D samples and should combine them under Data
# ---> Applying preselection.
# applying lep_fj_dr selection on 30044 events
# applying n_bjets_M selection on 21808 events
# ---> Done with preselection.
# Will fill the Data dataframe with the remaining 21114 events
# tot event weight 21114.0
#
# Finding QCD_Pt_1800to2400 samples and should combine them under QCD
# ---> Applying preselection.
# applying lep_fj_dr selection on 703 events
# applying n_bjets_M selection on 484 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the QCD dataframe with the remaining 476 events
# tot event weight 0.30164553208176415
#
# Finding SingleMuon_Run2017E samples and should combine them under Data
# ---> Applying preselection.
# applying lep_fj_dr selection on 61707 events
# applying n_bjets_M selection on 44627 events
# ---> Done with preselection.
# Will fill the Data dataframe with the remaining 43154 events
# tot event weight 43154.0
#
# Finding SingleMuon_Run2017B samples and should combine them under Data
# ---> Applying preselection.
# applying lep_fj_dr selection on 33275 events
# applying n_bjets_M selection on 24149 events
# ---> Done with preselection.
# Will fill the Data dataframe with the remaining 23410 events
# tot event weight 23410.0
#
# Finding WW samples and should combine them under Diboson
# ---> Applying preselection.
# applying lep_fj_dr selection on 2769 events
# applying n_bjets_M selection on 1177 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the Diboson dataframe with the remaining 1174 events
# tot event weight 244.50534375101267
#
# Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# ---> Applying preselection.
# applying lep_fj_dr selection on 2394 events
# applying n_bjets_M selection on 2082 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the SingleTop dataframe with the remaining 1895 events
# tot event weight 63.16131759033962
#
# Finding TTTo2L2Nu samples and should combine them under TTbar
# ---> Applying preselection.
# applying lep_fj_dr selection on 899399 events
# applying n_bjets_M selection on 761871 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the TTbar dataframe with the remaining 655670 events
# tot event weight 19482.649662302076
#
# Finding QCD_Pt_2400to3200 samples and should combine them under QCD
# ---> Applying preselection.
# applying lep_fj_dr selection on 435 events
# applying n_bjets_M selection on 313 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the QCD dataframe with the remaining 310 events
# tot event weight 0.021464522482109664
#
# ATTENTION: GluGluHToTauTau will be skipped
# Finding ZJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# ---> Applying preselection.
# applying lep_fj_dr selection on 115 events
# applying n_bjets_M selection on 65 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the WZQQ dataframe with the remaining 59 events
# tot event weight 28.11680770089175
#
# Finding ZZ samples and should combine them under Diboson
# ---> Applying preselection.
# applying lep_fj_dr selection on 3657 events
# applying n_bjets_M selection on 2764 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the Diboson dataframe with the remaining 2656 events
# tot event weight 471.0546089245485
#
# Finding TTToHadronic samples and should combine them under TTbar
# ---> Applying preselection.
# applying lep_fj_dr selection on 1211 events
# applying n_bjets_M selection on 1087 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the TTbar dataframe with the remaining 921 events
# tot event weight 108.74292648168617
#
# Finding GluGluZH_HToWW_ZTo2L_M-125 samples and should combine them under Diboson
# ---> Applying preselection.
# applying lep_fj_dr selection on 617975 events
# applying n_bjets_M selection on 537855 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the Diboson dataframe with the remaining 532502 events
# tot event weight 5.533782919503224
#
# Finding DYJetsToLL_M-50_HT-2500toInf samples and should combine them under DYJets
# ---> Applying preselection.
# applying lep_fj_dr selection on 240928 events
# applying n_bjets_M selection on 221573 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the DYJets dataframe with the remaining 213500 events
# tot event weight 30.288709357506082
#
# Finding QCD_Pt_1000to1400 samples and should combine them under QCD
# ---> Applying preselection.
# applying lep_fj_dr selection on 2193 events
# applying n_bjets_M selection on 1360 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the QCD dataframe with the remaining 1318 events
# tot event weight 19.742579125918375
#
# Finding QCD_Pt_600to800 samples and should combine them under QCD
# ---> Applying preselection.
# applying lep_fj_dr selection on 1448 events
# applying n_bjets_M selection on 870 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the QCD dataframe with the remaining 856 events
# tot event weight 265.18103514528394
#
# Finding QCD_Pt_300to470 samples and should combine them under QCD
# ---> Applying preselection.
# applying lep_fj_dr selection on 599 events
# applying n_bjets_M selection on 335 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the QCD dataframe with the remaining 328 events
# tot event weight 4298.406163599647
#
# Finding WJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# ---> Applying preselection.
# applying lep_fj_dr selection on 675 events
# applying n_bjets_M selection on 463 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the WZQQ dataframe with the remaining 453 events
# tot event weight 46.837525061978326
#
# Finding DYJetsToLL_M-50_HT-1200to2500 samples and should combine them under DYJets
# ---> Applying preselection.
# applying lep_fj_dr selection on 699837 events
# applying n_bjets_M selection on 645883 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the DYJets dataframe with the remaining 629054 events
# tot event weight 1576.0803480666432
#
# Finding ZJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# ---> Applying preselection.
# applying lep_fj_dr selection on 287 events
# applying n_bjets_M selection on 197 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the WZQQ dataframe with the remaining 182 events
# tot event weight 23.59649634664736
#
# Finding QCD_Pt_170to300 samples and should combine them under QCD
# ---> Applying preselection.
# applying lep_fj_dr selection on 258 events
# applying n_bjets_M selection on 150 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the QCD dataframe with the remaining 145 events
# tot event weight 19412.231714073358
#
# Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# ---> Applying preselection.
# applying lep_fj_dr selection on 3281 events
# applying n_bjets_M selection on 2346 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the WJetsLNu dataframe with the remaining 2287 events
# tot event weight 264.35559539050735
#
# Finding WJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# ---> Applying preselection.
# applying lep_fj_dr selection on 303 events
# applying n_bjets_M selection on 207 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the WZQQ dataframe with the remaining 203 events
# tot event weight 46.50233901806999
#
# Finding DYJetsToLL_M-50_HT-100to200 samples and should combine them under DYJets
# ---> Applying preselection.
# applying lep_fj_dr selection on 211 events
# applying n_bjets_M selection on 139 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the DYJets dataframe with the remaining 139 events
# tot event weight 8511.343941229841
# Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# ---> Applying preselection.
# applying lep_fj_dr selection on 1423 events
# applying n_bjets_M selection on 1051 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the WJetsLNu dataframe with the remaining 1001 events
# tot event weight 1.2491724926920913
#
# Finding ttHToNonbb_M125 samples and should combine them under ttH
# ---> Applying preselection.
# applying lep_fj_dr selection on 15667 events
# applying n_bjets_M selection on 14545 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the ttH dataframe with the remaining 10941 events
# tot event weight 37.83791241069634
#
# Finding ZJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# ---> Applying preselection.
# applying lep_fj_dr selection on 562 events
# applying n_bjets_M selection on 402 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the WZQQ dataframe with the remaining 372 events
# tot event weight 28.27131361759681
#
# Finding SingleElectron_Run2017F samples and should combine them under Data
# Finding QCD_Pt_800to1000 samples and should combine them under QCD
# ---> Applying preselection.
# applying lep_fj_dr selection on 1806 events
# applying n_bjets_M selection on 1101 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the QCD dataframe with the remaining 1073 events
# tot event weight 55.65904423785176
#
# Finding WJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# ---> Applying preselection.
# applying lep_fj_dr selection on 52 events
# applying n_bjets_M selection on 38 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the WZQQ dataframe with the remaining 37 events
# tot event weight 87.17494407739014
#
# Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# ---> Applying preselection.
# applying lep_fj_dr selection on 2062 events
# applying n_bjets_M selection on 1511 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the WJetsLNu dataframe with the remaining 1498 events
# tot event weight 737.528358247249
#
# Finding QCD_Pt_470to600 samples and should combine them under QCD
# ---> Applying preselection.
# applying lep_fj_dr selection on 1054 events
# applying n_bjets_M selection on 616 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the QCD dataframe with the remaining 594 events
# tot event weight 626.4387015310753
#
# Finding HZJ_HToWW_M-125 samples and should combine them under VH
# ---> Applying preselection.
# applying lep_fj_dr selection on 30270 events
# applying n_bjets_M selection on 26165 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the VH dataframe with the remaining 25667 events
# tot event weight 15.073610302715782
#
# Finding WZ samples and should combine them under Diboson
# ---> Applying preselection.
# applying lep_fj_dr selection on 5496 events
# applying n_bjets_M selection on 4287 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the Diboson dataframe with the remaining 4276 events
# tot event weight 586.3621973488014
#
# Finding QCD_Pt_1400to1800 samples and should combine them under QCD
# ---> Applying preselection.
# applying lep_fj_dr selection on 1302 events
# applying n_bjets_M selection on 829 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the QCD dataframe with the remaining 807 events
# tot event weight 1.902389356912467
#
# Finding DYJetsToLL_M-50_HT-200to400 samples and should combine them under DYJets
# ---> Applying preselection.
# applying lep_fj_dr selection on 58765 events
# applying n_bjets_M selection on 45384 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_iso_muon weight
# Applying weight_trigger_noniso_muon weight
# Applying weight_isolation_muon weight
# Applying weight_id_muon weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the DYJets dataframe with the remaining 45181 events
# tot event weight 81145.59191392938
#
# Finding SingleMuon_Run2017F samples and should combine them under Data
# ---> Applying preselection.
# applying lep_fj_dr selection on 96410 events
# applying n_bjets_M selection on 68903 events
# ---> Done with preselection.
# Will fill the Data dataframe with the remaining 66768 events
# tot event weight 66768.0
#
# Finding DYJetsToLL_M-50_HT-600to800 samples and should combine them under DYJets
# ---> Applying preselection.
# applying lep_fj_dr selection on 353542 events
# applying n_bjets_M selection on 333291 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the DYJets dataframe with the remaining 327365 events
# tot event weight 5453.784718066315
#
# Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# Finding DYJetsToLL_M-10to50 samples and should combine them under DYJets
# ---> Applying preselection.
# applying lep_fj_dr selection on 250 events
# applying n_bjets_M selection on 234 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the DYJets dataframe with the remaining 232 events
# tot event weight 3701.6768759608644
#
# Finding VBFHToWWToLNuQQ_M-125_withDipoleRecoil samples and should combine them under VBF
# Finding HWminusJ_HToWW_M-125 samples and should combine them under VH
# ---> Applying preselection.
# applying lep_fj_dr selection on 2421 events
# applying n_bjets_M selection on 1902 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the VH dataframe with the remaining 1896 events
# tot event weight 1.1719185074536862
#
# Finding DYJetsToLL_M-50_HT-70to100 samples and should combine them under DYJets
# ---> Applying preselection.
# applying lep_fj_dr selection on 7 events
# applying n_bjets_M selection on 1 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the DYJets dataframe with the remaining 1 events
# tot event weight 67.50812413948913
#
# Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# ---> Applying preselection.
# applying lep_fj_dr selection on 242 events
# applying n_bjets_M selection on 160 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the WJetsLNu dataframe with the remaining 156 events
# tot event weight 7.6794469860189185
#
# Finding TTToSemiLeptonic samples and should combine them under TTbar
# ---> Applying preselection.
# applying lep_fj_dr selection on 3379 events
# applying n_bjets_M selection on 3089 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the TTbar dataframe with the remaining 2476 events
# tot event weight 208.5796994636404
#
# Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# ---> Applying preselection.
# applying lep_fj_dr selection on 312 events
# applying n_bjets_M selection on 274 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the SingleTop dataframe with the remaining 245 events
# tot event weight 6.892056481825648
#
# Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# Finding DYJetsToLL_M-50_HT-400to600 samples and should combine them under DYJets
# ---> Applying preselection.
# applying lep_fj_dr selection on 251194 events
# applying n_bjets_M selection on 234229 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the DYJets dataframe with the remaining 231244 events
# tot event weight 18106.473695947745
#
# Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# ---> Applying preselection.
# applying lep_fj_dr selection on 250 events
# applying n_bjets_M selection on 166 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the WJetsLNu dataframe with the remaining 157 events
# tot event weight 1.8483330766783959
#
# Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# ---> Applying preselection.
# applying lep_fj_dr selection on 326 events
# applying n_bjets_M selection on 188 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the WJetsLNu dataframe with the remaining 187 events
# tot event weight 77.21526941355577
#
# Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# ---> Applying preselection.
# applying lep_fj_dr selection on 2549 events
# applying n_bjets_M selection on 1386 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the SingleTop dataframe with the remaining 1249 events
# tot event weight 257.26645735396596
#
# Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under HWW
# ---> Applying preselection.
# applying lep_fj_dr selection on 1142 events
# applying n_bjets_M selection on 1120 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the HWW dataframe with the remaining 1108 events
# tot event weight 7.945605159971488
#
# Finding WJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# ---> Applying preselection.
# applying lep_fj_dr selection on 2468 events
# applying n_bjets_M selection on 1353 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the SingleTop dataframe with the remaining 1235 events
# tot event weight 250.4545490253227
#
# Finding ZJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# Finding SingleElectron_Run2017E samples and should combine them under Data
# ---> Applying preselection.
# applying lep_fj_dr selection on 22376 events
# applying n_bjets_M selection on 17339 events
# ---> Done with preselection.
# Will fill the Data dataframe with the remaining 16840 events
# tot event weight 16840.0
#
# Finding SingleElectron_Run2017B samples and should combine them under Data
# ---> Applying preselection.
# applying lep_fj_dr selection on 10363 events
# applying n_bjets_M selection on 8049 events
# ---> Done with preselection.
# Will fill the Data dataframe with the remaining 7805 events
# tot event weight 7805.0
#
# Finding DYJetsToLL_M-50_HT-800to1200 samples and should combine them under DYJets
# ---> Applying preselection.
# applying lep_fj_dr selection on 28446 events
# applying n_bjets_M selection on 26740 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# Applying weight_vjets_nominal weight
# ...
# tot event weight 2706.3357415113987
#
# Finding QCD_Pt_3200toInf samples and should combine them under QCD
# Finding HWplusJ_HToWW_M-125 samples and should combine them under VH
# ---> Applying preselection.
# applying lep_fj_dr selection on 2658 events
# applying n_bjets_M selection on 2040 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the VH dataframe with the remaining 2035 events
# tot event weight 2.0294999012501083
#
# Finding SingleElectron_Run2017C samples and should combine them under Data
# ---> Applying preselection.
# applying lep_fj_dr selection on 24175 events
# applying n_bjets_M selection on 18908 events
# ---> Done with preselection.
# Will fill the Data dataframe with the remaining 18363 events
# tot event weight 18363.0
#
# Finding SingleElectron_Run2017D samples and should combine them under Data
# ---> Applying preselection.
# applying lep_fj_dr selection on 10947 events
# applying n_bjets_M selection on 8457 events
# ---> Done with preselection.
# Will fill the Data dataframe with the remaining 8175 events
# tot event weight 8175.0
#
# Finding WJetsToLNu_HT-70To100 samples and should combine them under WJetsLNu
# Finding SingleMuon_Run2017C samples and should combine them under Data
# Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# ---> Applying preselection.
# applying lep_fj_dr selection on 101 events
# applying n_bjets_M selection on 92 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the SingleTop dataframe with the remaining 87 events
# tot event weight 0.30694376639976023
#
# Finding SingleMuon_Run2017D samples and should combine them under Data
# Finding QCD_Pt_1800to2400 samples and should combine them under QCD
# Finding SingleMuon_Run2017E samples and should combine them under Data
# Finding SingleMuon_Run2017B samples and should combine them under Data
# Finding WW samples and should combine them under Diboson
# ---> Applying preselection.
# applying lep_fj_dr selection on 1461 events
# applying n_bjets_M selection on 544 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the Diboson dataframe with the remaining 543 events
# tot event weight 101.82931654979372
#
# Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# ---> Applying preselection.
# applying lep_fj_dr selection on 144 events
# applying n_bjets_M selection on 121 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the SingleTop dataframe with the remaining 102 events
# tot event weight 3.210581963053763
#
# Finding TTTo2L2Nu samples and should combine them under TTbar
# ---> Applying preselection.
# applying lep_fj_dr selection on 437193 events
# applying n_bjets_M selection on 357451 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the TTbar dataframe with the remaining 308936 events
# tot event weight 8276.460379663931
#
# Finding QCD_Pt_2400to3200 samples and should combine them under QCD
# ATTENTION: GluGluHToTauTau will be skipped
# Finding ZJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# Finding ZZ samples and should combine them under Diboson
# ---> Applying preselection.
# applying lep_fj_dr selection on 2011 events
# applying n_bjets_M selection on 1602 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the Diboson dataframe with the remaining 1534 events
# tot event weight 249.55347847981682
#
# Finding TTToHadronic samples and should combine them under TTbar
# Finding GluGluZH_HToWW_ZTo2L_M-125 samples and should combine them under Diboson
# ---> Applying preselection.
# applying lep_fj_dr selection on 385125 events
# applying n_bjets_M selection on 345762 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the Diboson dataframe with the remaining 342372 events
# tot event weight 3.300646203542872
#
# Finding DYJetsToLL_M-50_HT-2500toInf samples and should combine them under DYJets
# ---> Applying preselection.
# applying lep_fj_dr selection on 118373 events
# applying n_bjets_M selection on 109020 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the DYJets dataframe with the remaining 104765 events
# tot event weight 13.470185824389645
#
# Finding QCD_Pt_1000to1400 samples and should combine them under QCD
# ---> Applying preselection.
# applying lep_fj_dr selection on 8 events
# applying n_bjets_M selection on 6 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the QCD dataframe with the remaining 6 events
# tot event weight 0.07489202429367554
#
# Finding QCD_Pt_600to800 samples and should combine them under QCD
# Finding QCD_Pt_300to470 samples and should combine them under QCD
# Finding WJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# ---> Applying preselection.
# applying lep_fj_dr selection on 5 events
# applying n_bjets_M selection on 4 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the WZQQ dataframe with the remaining 4 events
# tot event weight 0.40560473900815375
#
# Finding DYJetsToLL_M-50_HT-1200to2500 samples and should combine them under DYJets
# ---> Applying preselection.
# applying lep_fj_dr selection on 342279 events
# applying n_bjets_M selection on 317081 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the DYJets dataframe with the remaining 308405 events
# tot event weight 691.7646153314745
#
# Finding ZJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# Finding QCD_Pt_170to300 samples and should combine them under QCD
# ---> Applying preselection.
# applying lep_fj_dr selection on 2 events
# applying n_bjets_M selection on 1 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the QCD dataframe with the remaining 1 events
# tot event weight 129.92803901086637
#
# Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# ---> Applying preselection.
# applying lep_fj_dr selection on 231 events
# applying n_bjets_M selection on 146 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the WJetsLNu dataframe with the remaining 143 events
# tot event weight 13.899697999367305
#
# Finding WJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# Finding DYJetsToLL_M-50_HT-100to200 samples and should combine them under DYJets
# ---> Applying preselection.
# applying lep_fj_dr selection on 130 events
# applying n_bjets_M selection on 92 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the DYJets dataframe with the remaining 92 events
# tot event weight 4902.982359758875
#
# Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# ---> Applying preselection.
# applying lep_fj_dr selection on 66 events
# applying n_bjets_M selection on 49 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the WJetsLNu dataframe with the remaining 46 events
# tot event weight 0.049987919471072895
#
# Finding ttHToNonbb_M125 samples and should combine them under ttH
# ---> Applying preselection.
# applying lep_fj_dr selection on 6582 events
# applying n_bjets_M selection on 5998 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the ttH dataframe with the remaining 4472 events
# tot event weight 13.803619856475525
#
# Finding ZJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# Finding SingleElectron_Run2017F samples and should combine them under Data
# ---> Applying preselection.
# applying lep_fj_dr selection on 30065 events
# applying n_bjets_M selection on 23026 events
# ---> Done with preselection.
# Will fill the Data dataframe with the remaining 22360 events
# tot event weight 22360.0
#
# Finding QCD_Pt_800to1000 samples and should combine them under QCD
# Finding WJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# ---> Applying preselection.
# applying lep_fj_dr selection on 163 events
# applying n_bjets_M selection on 104 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the WJetsLNu dataframe with the remaining 103 events
# tot event weight 43.889715753347964
#
# Finding QCD_Pt_470to600 samples and should combine them under QCD
# Finding HZJ_HToWW_M-125 samples and should combine them under VH
# ---> Applying preselection.
# applying lep_fj_dr selection on 17078 events
# applying n_bjets_M selection on 15252 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the VH dataframe with the remaining 15010 events
# tot event weight 8.126252929867977
#
# Finding WZ samples and should combine them under Diboson
# ---> Applying preselection.
# applying lep_fj_dr selection on 3146 events
# applying n_bjets_M selection on 2536 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the Diboson dataframe with the remaining 2522 events
# tot event weight 314.9208632785011
#
# Finding QCD_Pt_1400to1800 samples and should combine them under QCD
# ---> Applying preselection.
# applying lep_fj_dr selection on 6 events
# applying n_bjets_M selection on 4 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# weight_vjets_nominal weight is not stored in parquet
# ---> Done with accumulating event weights.
# Will fill the QCD dataframe with the remaining 4 events
# tot event weight 0.009527769323734935
#
# Finding DYJetsToLL_M-50_HT-200to400 samples and should combine them under DYJets
# ---> Applying preselection.
# applying lep_fj_dr selection on 31052 events
# applying n_bjets_M selection on 25515 events
# ---> Done with preselection.
# ---> Accumulating event weights.
# Applying weight_genweight weight
# Applying weight_L1Prefiring weight
# Applying weight_pileup weight
# Applying weight_trigger_electron weight
# Applying weight_reco_electron weight
# Applying weight_id_electron weight
# Applying weight_vjets_nominal weight
# ---> Done with accumulating event weights.
# Will fill the DYJets dataframe with the remaining 25375 events
# tot event weight 40748.45430869585
# Finding SingleMuon_Run2017F samples and should combine them under Data

# %% [markdown]
# # Plot histograms

# %% [markdown]
# ## 1d-hists

# %%
zll_axis_dict = {
    "fj_pt": hist2.axis.Regular(30, 200, 1000, name="var", label=r"Jet $p_T$ [GeV]", overflow=True),
    "fj_msoftdrop": hist2.axis.Regular(35, 20, 250, name="var", label=r"Jet $m_{sd}$ [GeV]", overflow=True),    
    "lep1_pt": hist2.axis.Regular(40, 30, 300, name="var", label=r"Leading lepton $p_T$ [GeV]", overflow=True),
    "lep2_pt": hist2.axis.Regular(40, 30, 300, name="var", label=r"Second lepton $p_T$ [GeV]", overflow=True),
    "mll": hist2.axis.Regular(40, 0, 160, name="var", label=r"Zmass [GeV]", overflow=True),
}

samples_to_plot = [
    "HWW", 
#     "VH",
#     "VBF",
#     "ttH",
    "QCD",
#     "DYJets",
    "WJetsLNu",
    "TTbar",
]

### Example of a 1-d histogram
# make simple 1d-histogram of `lep_pt`
plt.rcParams.update({"font.size": 20})

var = "lep1_pt"

h = hist2.Hist(
    zll_axis_dict[var],
)

fig, ax = plt.subplots(figsize=(9, 7))

for sample in samples_to_plot:
    for ch in channels:

        df = events_dict[ch][sample]
        
        # tagger cut
#         df = df[df["inclusive_score"]>0.9]
#         df = df[df["fj_bjets"]<0.3]
#         df = df[(df["rec_W_lnu_pt"]/df["rec_W_qq_pt"])<4.8]

        h.fill(
            var=df[var],
            weight=df["event_weight"]
        )

    hep.histplot(
        h,
        ax=ax,
        label=sample,
        linewidth=3,
        density=True
    )

ax.legend(title=f"Semi-Leptonic Channel")
ax.set_ylabel("Events");

# %% [markdown]
# ## Stacked hists

# %%
# plot histograms
color_by_sample = {
    "HWW": "pink",
    "VH": "tab:brown",
    "VBF": "tab:gray",
    "ttH": "tab:olive",
    
    "DYJets": "tab:purple",
    "QCD": "tab:orange",
    "Diboson": "orchid",    
    "WJetsLNu": "tab:green",
    "TTbar": "tab:blue",
    "WZQQ": "salmon",
    "SingleTop": "tab:cyan",
    
#     "WplusHToTauTau": "tab:cyan",
#     "WminusHToTauTau": "tab:cyan",
#     "ttHToTauTau": "tab:cyan",
#     "GluGluHToTauTau": "tab:cyan",
#     "ZHToTauTau": "tab:cyan",
#     "VBFHToTauTau": "tab:cyan",
}

plot_labels = {
    "HWW": "ggH(WW)-Pt200",    
    "VH": "VH(WW)",
    "VBF": r"VBFH(WW) $(qq\ell\nu)$",
    "ttH": "ttH(WW)",
    
    "DYJets": r"Z$(\ell\ell)$+jets",    
    "QCD": "Multijet",
    "Diboson": "VV",
    "WJetsLNu": r"W$(\ell\nu)$+jets",
    "TTbar": r"$t\bar{t}$+jets",
    "WZQQ": r"W/Z$(qq)$",
    "SingleTop": r"Single Top",
    
#     "WplusHToTauTau": "WplusHToTauTau",
#     "WminusHToTauTau": "WminusHToTauTau",
#     "ttHToTauTau": "ttHToTauTau",
#     "GluGluHToTauTau": "GluGluHToTauTau",
#     "ZHToTauTau": "ZHToTauTau",
#     "VBFHToTauTau": "VBFHToTauTau"
}

label_by_ch = {
    "mu": "Muon",
    "ele": "Electron"
}

# %%
def plot_hists(year, channels, hists, vars_to_plot, add_data = True, logy = True, add_soverb = True, only_sig = False, mult=100, tag="test"):

    # luminosity
    luminosity = 0
    for ch in channels:
        with open("../fileset/luminosity.json") as f:
            lum = json.load(f)[ch][year]
            luminosity += lum / 1000.0

    luminosity = luminosity/len(channels)
        
    for var in vars_to_plot:
        if var not in hists.keys():
            print(f"{var} not stored in hists")
            continue

        print(f"Will plot {var} histogram")

        # get histograms
        h = hists[var]

        if (h.shape[0] == 0):  # skip empty histograms (such as lepton_pt for hadronic channel)
            print("Empty histogram ", var)
            continue

        # get samples existing in histogram
        samples = [h.axes[0].value(i) for i in range(len(h.axes[0].edges))]
        signal_labels = [label for label in samples if label in utils.signals]
        bkg_labels = [
            label
            for label in samples
            if (label and label not in signal_labels and (label not in ["Data"]))
        ]

        # get total yield of backgrounds per label
        # (sort by yield in fixed fj_pt histogram after pre-sel)        
        order_dic = {}
        for bkg_label in bkg_labels:
            if "fj_pt" in hists.keys():
                order_dic[plot_labels[bkg_label]] = hists["fj_pt"][{"samples": bkg_label}].sum()
            else:
                order_dic[plot_labels[bkg_label]] = hists[var][{"samples": bkg_label}].sum()
            
        # data
        if add_data:
            data = h[{"samples": "Data"}]

        # signal
        signal = [h[{"samples": label}] for label in signal_labels]
        # scale signal for non-log plots
        if logy:
            mult_factor = 1
        else:
            mult_factor = mult
        signal_mult = [s * mult_factor for s in signal]

        # background
        bkg = [h[{"samples": label}] for label in bkg_labels]

        if add_data and data and len(bkg) > 0:
            if add_soverb and len(signal) > 0:
                fig, (ax, rax, sax) = plt.subplots(
                    nrows=3,
                    ncols=1,
                    figsize=(8, 8),
                    gridspec_kw={"height_ratios": (4, 1, 1), "hspace": 0.07},
                    sharex=True,
                )
            else:
                fig, (ax, rax) = plt.subplots(
                    nrows=2,
                    ncols=1,
                    figsize=(8, 8),
                    gridspec_kw={"height_ratios": (4, 1), "hspace": 0.07},
                    sharex=True,
                )
                sax = None
        else:
            if add_soverb and len(signal) > 0:
                fig, (ax, sax) = plt.subplots(
                    nrows=2,
                    ncols=1,
                    figsize=(8, 8),
                    gridspec_kw={"height_ratios": (4, 1), "hspace": 0.07},
                    sharex=True,
                )
                rax = None
            else:
                fig, ax = plt.subplots(figsize=(8,8))                
                rax = None
                sax = None

        errps = {
            "hatch": "////",
            "facecolor": "none",
            "lw": 0,
            "color": "k",
            "edgecolor": (0, 0, 0, 0.5),
            "linewidth": 0,
            "alpha": 0.4,
        }

        # sum all of the background
        if len(bkg) > 0:
            tot = bkg[0].copy()
            for i, b in enumerate(bkg):
                if i > 0:
                    tot = tot + b

            tot_val = tot.values()
            tot_val_zero_mask = tot_val == 0
            tot_val[tot_val_zero_mask] = 1

            tot_err = np.sqrt(tot_val)
            tot_err[tot_val_zero_mask] = 0

        if add_data and data:
            data_err_opts = {
                "linestyle": "none",
                "marker": ".",
                "markersize": 10.0,
                "elinewidth": 1,
            }
            hep.histplot(
                data,
                ax=ax,
                histtype="errorbar",
                color="k",
                capsize=4,
                yerr=True,
                label="Data",
                **data_err_opts,
            )

            if len(bkg) > 0:
                from hist.intervals import ratio_uncertainty

                data_val = data.values()
                data_val[tot_val_zero_mask] = 1

                yerr = ratio_uncertainty(data_val, tot_val, "poisson")

                hep.histplot(
                    data_val / tot_val,
                    tot.axes[0].edges,
                    yerr=yerr,
                    ax=rax,
                    histtype="errorbar",
                    color="k",
                    capsize=4,
                )

                rax.axhline(1, ls="--", color="k")
                rax.set_ylim(0.2, 1.8)

        # plot the background
        if len(bkg) > 0 and not only_sig:
            hep.histplot(
                bkg,
                ax=ax,
                stack=True,
                sort="yield",
                edgecolor="black",
                linewidth=1,
                histtype="fill",
                label=[plot_labels[bkg_label] for bkg_label in bkg_labels],
                color=[color_by_sample[bkg_label] for bkg_label in bkg_labels],
            )
            ax.stairs(
                values=tot.values() + tot_err,
                baseline=tot.values() - tot_err,
                edges=tot.axes[0].edges,
                **errps,
                label="Stat. unc.",
            )

        # plot the signal (times 10)
        if len(signal) > 0:
            tot_signal = None
            for i, sig in enumerate(signal_mult):
                lab_sig_mult = f"{mult_factor} * {plot_labels[signal_labels[i]]}"
                if mult_factor == 1:
                    lab_sig_mult = f"{plot_labels[signal_labels[i]]}"
                hep.histplot(
                    sig,
                    ax=ax,
                    label=lab_sig_mult,
                    linewidth=3,
                    color=color_by_sample[signal_labels[i]],
                )

                if tot_signal == None:
                    tot_signal = signal[i].copy()
                else:
                    tot_signal = tot_signal + signal[i]

            # plot the total signal (w/o scaling)
            hep.histplot(
                tot_signal, ax=ax, label=f"ggF+VBF+VH+ttH", linewidth=3, color="tab:red"
            )
            # add MC stat errors
            ax.stairs(
                values=tot_signal.values() + np.sqrt(tot_signal.values()),
                baseline=tot_signal.values() - np.sqrt(tot_signal.values()),
                edges=sig.axes[0].edges,
                **errps,
            )

            if sax is not None:
                totsignal_val = tot_signal.values()
                # replace values where bkg is 0
                totsignal_val[tot_val == 0] = 0
                soverb_val = totsignal_val / np.sqrt(tot_val)
                hep.histplot(
                    soverb_val,
                    tot_signal.axes[0].edges,
                    label="Total Signal",
                    ax=sax,
                    linewidth=3,
                    color="tab:red",
                )

                # integrate soverb in a given range for fj_minus_lep_mass (which, intentionally, is the first variable we pass)
                if var == "fj_minus_lep_m":
                    bin_array = tot_signal.axes[0].edges[
                        :-1
                    ]  # remove last element since bins have one extra element
                    range_max = 150
                    range_min = 0

                    condition = (bin_array >= range_min) & (bin_array <= range_max)

                    s = totsignal_val[
                        condition
                    ].sum()  # sum/integrate signal counts in the range
                    b = np.sqrt(
                        tot_val[condition].sum()
                    )  # sum/integrate bkg counts in the range and take sqrt

                    soverb_integrated = round((s / b).item(), 2)
                    sax.legend(title=f"S/sqrt(B) (in 0-150)={soverb_integrated:.2f}")
                # integrate soverb in a given range for fj_minus_lep_mass (which, intentionally, is the first variable we pass)
                if var == "rec_higgs_m":
                    bin_array = tot_signal.axes[0].edges[
                        :-1
                    ]  # remove last element since bins have one extra element
                    range_max = 200
                    range_min = 50

                    condition = (bin_array >= range_min) & (bin_array <= range_max)

                    s = totsignal_val[
                        condition
                    ].sum()  # sum/integrate signal counts in the range
                    b = np.sqrt(
                        tot_val[condition].sum()
                    )  # sum/integrate bkg counts in the range and take sqrt

                    soverb_integrated = round((s / b).item(), 2)
                    sax.legend(title=f"S/sqrt(B) (in 50-200)={soverb_integrated:.2f}")

        ax.set_ylabel("Events")
        if sax is not None:
            ax.set_xlabel("")
            if rax is not None:
                rax.set_xlabel("")
                rax.set_ylabel("Data/MC", fontsize=20)
            sax.set_ylabel(r"S/$\sqrt{B}$", fontsize=20)
            sax.set_xlabel(f"{h.axes[-1].label}")   # assumes the variable to be plotted is at the last axis
            
        elif rax is not None:
            ax.set_xlabel("")
            rax.set_xlabel(f"{h.axes[-1].label}")    # assumes the variable to be plotted is at the last axis
            
            rax.set_ylabel("Data/MC", fontsize=20)

        # get handles and labels of legend
        handles, labels = ax.get_legend_handles_labels()

        # append legend labels in order to a list
        summ = []
        for label in labels[: len(bkg_labels)]:
            summ.append(order_dic[label])
        # get indices of labels arranged by yield
        order = []
        for i in range(len(summ)):
            order.append(np.argmax(np.array(summ)))
            summ[np.argmax(np.array(summ))] = -100

        # plot data first, then bkg, then signal
        hand = [handles[-1]] + [handles[i] for i in order] + handles[len(bkg) : -1]
        lab = [labels[-1]] + [labels[i] for i in order] + labels[len(bkg) : -1]

        if len(channels) == 2:
            ax.legend(
                [hand[idx] for idx in range(len(hand))],
                [lab[idx] for idx in range(len(lab))],
                bbox_to_anchor=(1.05, 1),
                loc="upper left",
                title=f"Semi-Leptonic Channel",
            )        
        else:
            ax.legend(
                [hand[idx] for idx in range(len(hand))],
                [lab[idx] for idx in range(len(lab))],
                bbox_to_anchor=(1.05, 1),
                loc="upper left",
                title=f"{label_by_ch[ch]} Channel",
            )
        
        if logy:
            ax.set_yscale("log")
            ax.set_ylim(1e-1)

        hep.cms.lumitext(
            "%.1f " % luminosity + r"fb$^{-1}$ (13 TeV)", ax=ax, fontsize=20
        )
        
        dir_ = f"/Users/fmokhtar/Desktop/hww/zll/{tag}"
        if not os.path.exists(dir_):
            os.makedirs(dir_)
        
        hep.cms.text("Work in Progress", ax=ax, fontsize=15)
        plt.savefig(f"{dir_}/{var}.pdf", bbox_inches='tight')

# %%
vars_to_plot = [
    "fj_pt",
#     "fj_msoftdrop",    
    "lep1_pt",
    "lep2_pt",
    "mll",
]

samples_to_plot = [
    "HWW", 
    "VH",
#     "VBF",
    "ttH",
    "QCD",
    "DYJets",
    "WJetsLNu",
    "WZQQ",
    "TTbar",
    "SingleTop",
    "Diboson",
    "Data",
]

zll_axis_dict = {
    "fj_pt": hist2.axis.Regular(30, 200, 1000, name="var", label=r"Jet $p_T$ [GeV]", overflow=True),
    "fj_msoftdrop": hist2.axis.Regular(35, 20, 250, name="var", label=r"Jet $m_{sd}$ [GeV]", overflow=True),    
    "lep1_pt": hist2.axis.Regular(40, 30, 300, name="var", label=r"Leading lepton $p_T$ [GeV]", overflow=True),
    "lep2_pt": hist2.axis.Regular(40, 30, 300, name="var", label=r"Second lepton $p_T$ [GeV]", overflow=True),
    "mll": hist2.axis.Regular(40, 0, 160, name="var", label=r"Zmass [GeV]", overflow=True),
}

# %%
channels = ["ele", "mu"]
# channels = ["ele"]

# fill histograms
hists = {}
for var in vars_to_plot:
            
    hists[var] = hist2.Hist(
        hist2.axis.StrCategory([], name="samples", growth=True),
        zll_axis_dict[var],
    )
        
    for sample in samples_to_plot:
        for ch in channels:
            df = events_dict[ch][sample]
            
#             df = df[df["lep_fj_dr"]>0.03]        
#             df = df[df["n_bjets_M"]<2]
            
            hists[var].fill(
                samples=sample,
                var=df[var],
                weight=df["event_weight"]
            )

hists["fj_pt"][{"samples": "HWW"}]
# Out:
# Hist(Regular(30, 200, 1000, name='var', label='Jet $p_T$ [GeV]'), storage=Double()) # Sum: 27.395933707760918

# %%
plt.rcParams.update({"font.size": 20})
plot_hists(year, channels, hists, vars_to_plot, logy = True, add_data=True, add_soverb=False, tag=samples_dir[3:])
# Out:
# Will plot fj_pt histogram
# Will plot lep1_pt histogram
# Will plot lep2_pt histogram
# Will plot mll histogram
